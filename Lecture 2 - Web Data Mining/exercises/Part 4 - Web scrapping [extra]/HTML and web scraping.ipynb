# %% [markdown]
# *Luca Furlanetto [s161890@student.dtu.dk]*

# %% [markdown]
# # HTML and web scraping

# %% [markdown]
# Reference:
# - Advanced Business Analytics course by Stanislav Borysov, DTU Management.
# - https://www.w3schools.com/html/default.asp
# - https://towardsdatascience.com/5-strategies-to-write-unblock-able-web-scrapers-in-python-5e40c147bdaf

# %% [markdown]
# Web crawling and scraping represent a very flexible way to get the content from the Internet. Essentially, it imitates a user who visits different webpages and views their content. The only difference is that Internet companies usually love real users and hate scraping bots. So be prepared to be blocked. **In the worst case, you can get into serious troubles so please always read Terms & Conditions and follow the company's policy about automatic data collection (or ask them directly if you are not sure)!**
#
# Additionally, you can always read the **Robot.txt** file to know what you are allowed or not to do. In a nutshel **Robots.txt** is a text file webmasters create to instruct web robots (typically search engine robots) how to crawl pages on their website. In practice, robots.txt files indicate whether certain user agents (web-crawling software) can or cannot crawl parts of a website. These crawl instructions are specified by “disallowing” or “allowing” the behavior of certain (or all) user agents. The basic format is:
#
# User-agent: [user-agent name]
#
# Disallow: [URL string not to be crawled]
#
#
# It follows an example with comments of the Robot.txt file of Buzzfeed (reference: https://moz.com/learn/seo/robotstxt )
#
# ![Robot.txt](https://moz-static.s3.amazonaws.com/learn/seo/Robots.txt-and-Robots-meta-directives/_large/Robots.txt.png?mtime=20170427090304)

# %% [markdown]
# ## 1. HTML
#
# Hypertext Markup Language (HTML) is the standard markup language for documents designed to be displayed in a web browser.

# %% [markdown]
# #### 1.1 Basic structure
#
# - All HTML documents must start with a document type declaration: $<!DOCTYPE html>$.
# - The HTML document itself begins with $<html>$ and ends with $</html>$.
# - The visible part of the HTML document is between $<body>$ and $</body>$.
#
# Let's see an example ( _%%HTML_ is only needed to run HTML code in Jupyter)

# %%
# %%HTML
#
# <!DOCTYPE html>
# <html>
# <body>
#
# <h3>My First Heading</h3>
# <p>My first paragraph.</p>
#
# </body>
# </html>

# %% [markdown]
# #### 1.2 Elements Tags
#
# An HTML element usually consists of a start tag and an end tag, with the content inserted in between. The HTML element is everything from the start tag to the end tag.
#
# HTML tags are the hidden keywords within a web page that define how your web browser must format and display the content. Most tags must have two parts, an opening and a closing part. For example, <html> is the opening tag and </html> is the closing tag. Note that the closing tag has the same text as the opening tag, but has an additional forward-slash ( / ) character. Ii can be interpreteted as the "end" or "close" character.
#
# Common tags are:
# - __Headings__  defined with $<h >$ and a number from 1 to 6. $<h1>$ defines the most important heading, $<h6>$ defines the least important.
# - __Paragraphs__  defined with the $<p>$ tag.
# - __Links__  defined with the $<a>$ tag. Where the link's destination is specified in the $href$ attribute.
# - __Images__  defined with the $<img>$ tag. Where the source file $(src)$, alternative text $(alt)$, $width$, and $height$ are provided as attributes.
# - __Buttons__  defined with the $<button>$ tag.
# - __Lists__  defined with the $<ul>$ (unordered/bullet list) or the $<ol>$ (ordered/numbered list) tag, followed by $<li>$ tags (list items).
#
# List of Elements Tag: https://www.w3schools.com/tags/ref_byfunc.asp

# %% [markdown]
# #### 1.2 Elements container
#
# As a "pure" container, the $<div>$ or $<span>$ element does not inherently represent anything. Instead, it's used to group content so it can be easily styled using the class or id attributes, marking a section of a document as being written in a different language (using the lang attribute), and so on.
#
# Main container elements:
# - The __$<div>$ element__ is often used as a container for other HTML elements.
# - The __$<span>$ element__ is often used as a container for some text.
#
# Keep in mind that HTML elements can be nested (elements can contain elements). For example, the <body> element of an HTML document can contain paragraph and headings. (See the first example)

# %% [markdown]
# #### 1.3 Elements Attributes
#
# Attributes provide additional information about an element. Attributes are always specified in the start tag. For example,
# - $href$ specifies the link address.
# - $src$ specifies filename of the image source.
# - $width$ and $height$ specifies the width and height of the image.
# - $alt$ attribute specifies an alternative text to be used, if an image cannot be displayed.
# - $style$ is used to specify the styling of an element, like color, font, size etc.
# - The language is declared with the $lang$ attribute.
# - $title$ attribute is added to the $<p>$ element. The value of the title attribute will be displayed as a tooltip when you mouse over the paragraph.
# - $class$ attribute is used to define equal styles for elements with the same class name.
# - $id$ attribute specifies a unique id for an HTML element (the value must be unique within the HTML document).
#
# Complete list of attributes: https://www.w3schools.com/tags/ref_attributes.asp
#
# To get a better idea look at the example below.

# %%
# %%HTML
#
# <!DOCTYPE html>
# <html lang="en-US">
# <div style="background-image: url('img_girl.jpg');">
# <body>
#
# <a href="https://www.w3schools.com">This is a link</a>
#
# <img src="img_girl.jpg" width="50" height="60" alt="Girl with a jacket">
#
# <p style="color:red; font-family:courier;font-size:160%;">This is the first paragraph.</p>
#
# <p title="It really happens">
# This is the second paragraph.
# </p>
#
# </body>
# </html>

# %% [markdown]
# Class example:

# %%
# %%HTML
#
# <style>
# .cities {
#   background-color: black;
#   color: white;
#   margin: 20px;
#   padding: 20px;
# }
# </style>
# </head>
# <body>
#
# <div class="cities">
#   <h2>London</h2>
#   <p>London is the capital of England.</p>
# </div>

# %% [markdown]
# #### 1.4 Tables
#
# An HTML table is defined with the $<table>$ tag.
#
# Each table row is defined with the $<tr>$ tag. A table header is defined with the $<th>$ tag. By default, table headings are bold and centered. A table data/cell is defined with the $<td>$ tag.

# %%
# %%HTML
#
# <table style="width:100%">
#   <tr>
#     <th>Firstname</th>
#     <th>Lastname</th>
#     <th>Age</th>
#   </tr>
#   <tr>
#     <td>Jill</td>
#     <td>Smith</td>
#     <td>50</td>
#   </tr>
#   <tr>
#     <td>Eve</td>
#     <td>Jackson</td>
#     <td>94</td>
#   </tr>
# </table>

# %% [markdown]
# ## 2. Web Scraping
# Web scraping, web harvesting, or web data extraction is data scraping used for extracting data from websites.

# %% [markdown]
# ### 2.1 DTU News
#
# In this exercise, we will implement a web scraper that get news headlines together with the date and short description from https://www.dtu.dk/english/news. We are gonna use Scrapy (https://scrapy.org/) however, keep in mind that exist many other framework available.

# %% [markdown]
# #### 2.1.1 Navigating the website

# %% [markdown]
# In this case, the webpage shows 10 recent news items by default; however, it is possible to get the 100 most recent news modifying the URL structure properly.
#
# It is very important to get familiar with the website where we are working. We need to know what can and cannot be obtained and we need to understand the URL structure.
#
# In the example below we want the 200 most recent. Since only the maximum of news that can be displayed is 100, we construct 2 urls: the first the get the 100 most recent news and the second to get from the 101st to the 200th most recent news.

# %%
url_base = "https://www.dtu.dk/english/news"

import math

urls = []
n_items = 200
start = 1
items_to_show = 100 # The webpage cannot show more then 100 items at once
for i in range(math.ceil(n_items / items_to_show)):
    parameters = [
        "fr={}".format(start), 
        "mr={}".format(items_to_show)
    ]
    url = url_base + "?" + "&".join(parameters)
    urls.append(url)
    start += items_to_show

print(urls)

# %% [markdown]
# ### 2.1.2 Scraping the webpage content
#
# Let's retrieve the information we are interested in and save it in a file.

# %%
import urllib.request

for url in urls:
    contents = urllib.request.urlopen(url).read()
    with open("dtu_news.html", "wb") as f:
        f.write(contents)

# %% [markdown]
# Note, that all markup and images are missing since we saved only the HTML content.

# %% [markdown]
# ### 2.1.3. Extracting the data
#
# Let's load the data from the file. Once the web content is loaded, we want to extract information wanted. To do that it can be used regular expressions or HTML parser (e.g., PyQuery, BeautifulSoup) that allows to save the content to a JSON file.
#
# To extract any kind of information from a HTML document is very important to understand the structure of the webpage. This can be done directly from your browser. Try:
# - Chrome: right click -> inspect
# - Safari, Firefox, Edge: right click -> inspect element
#
# Once we have clear the webpage structure, we create a PyQuery object that store all the element we are interested in. To do that we find the information we need inspecting the webpage in our browser and we specify an attribute that identify each single element. Note that often the information are stored in containers and has a particular class. Then, we can iterate through the list of elements and retrieve the needed information specify the attribute name or $.text()$ if the information is stored as text. If the the information is stored in a sub-element, we can use the function $find$. To access sub element we can also use the ">" symbol (this depends on the web-scraper framework (PyQuery) and can be different for other framework).

# %%
# with open("dtu_news.html", "r", encoding='utf8') as f:
#     contents = f.read()
    
from pyquery import PyQuery 

# Let's take the first 100 most recent news

news = []
for url in urls:
    # Request the content of the website
    contents = urllib.request.urlopen(url).read()

    # load the document
    pq = PyQuery(contents)

    # Get all the element that has 'div.newsItem' as tag.
    # We know that from inspecting the webpage. 
    newsItems = pq('div.newsItem')
    
    #
    for i in range(len(newsItems)):
        # one news
        item = newsItems.eq(i)
        # url
        item_url = item.find('h2>a').attr('href')
        # title
        item_title = item.find('h2>a').text()
        # desc
        item_desc = item.find('p').text()
        # date
        item_date = item.find('span.date').text()
        # 
        new_item = {
            'url': item_url,
            'title': item_title,
            'desc': item_desc,
            'date': item_date
        }
        
        print(new_item)
        news.append(new_item)
# Out:
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={0DB56848-A70C-4584-9486-D36BFA326369}', 'title': 'Students get huge workshop for prototyping and 3D printing', 'desc': 'The inauguration of a new prototype lab in Ballerup gives DTU students 600 m2 of state-of-the-art experimental facilities and a playground for product development and prototype...', 'date': '14 OCT'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={DE4FFF77-4F09-4D41-89FA-6E2F4B977199}', 'title': 'DKK 144.5 million from the EU for health technology projects', 'desc': 'On 11 October, the European Research Council (ERC) awarded new ERC Synergy grants. DTU participates in two of these, which have each been granted more than DKK 70 million...', 'date': '11 OCT'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={643EC12B-8773-4528-BFF4-917069373B7D}', 'title': 'DTU destroys building to check computer program', 'desc': 'Loading a two-storey building will clarify whether numerical models in computer programs ensure sufficient strength and load-carrying capacity.', 'date': '11 OCT'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={01A682EE-0B74-4C2B-952F-2A6A051D01CE}', 'title': 'Stable occurrence of antimicrobial resistance in animals and meat', 'desc': 'The occurrence of antimicrobial resistance in food-producing animals and meat in Denmark is relatively stable, according to the annual DANMAP report.', 'date': '09 OCT'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={7CCB5E33-F953-436E-B1A2-579886128C59}', 'title': 'Researchers investigate new green fuel for ships', 'desc': 'Gas produced from bio-waste and wind may make future shipping traffic more climate-friendly.', 'date': '08 OCT'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={C7B8EC50-6546-4A87-A6B4-704F1E24CBB0}', 'title': 'Q&A: Next generation of robots get situation awareness', 'desc': 'Robots that can read their surroundings and adapt their actions thereafter are currently being developed, says Professor Ole Ravn.', 'date': '08 OCT'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={6F11D8C5-FB28-42BD-98EC-C202B0483DFD}', 'title': 'Clear recommendations from EnergyLab Nordhavn for the sustainable energy solutions...', 'desc': 'After four and a half years, the ambitious EnergyLab Nordhavn project presents a number of recommendations to politicians and public authorities for how to ensure a faster...', 'date': '08 OCT'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={CEF51AC4-86F1-4722-AAE6-A15050CBA56B}', 'title': 'Microwaves pave the way for PET recycling', 'desc': 'PET can be degraded by microwaves and chemistry, so the components of the plastic can be recycled into new PET products.', 'date': '07 OCT'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={827F1151-F01F-403B-88A6-CB530DCCC71E}', 'title': 'DTU Innovators develop the world’s thinnest eyeglasses', 'desc': 'Even very high power prescription glasses can become ultra thin when\xa0nanostructure features are laser printed onto its lenses.', 'date': '04 OCT'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={12537BED-112F-4618-BEAF-D2B2D85342EC}', 'title': 'DTU inspiring girls to become engineers', 'desc': 'In connection with Girls’ Day in Science, DTU opened its doors to 336 girls from high schools and lower secondary schools (Years 7-9) on 2 October.', 'date': '04 OCT'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={28F606B8-8EA1-48C3-A827-FA1ACA97D9DB}', 'title': 'New EU project on sustainable mesopelagic fisheries', 'desc': 'Researchers look into whether organisms living deep in the oceans can be exploited in an ecologically and economically sustainable way.', 'date': '03 OCT'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={82CC755A-FB8E-49B0-A056-B70E170BB914}', 'title': 'Young entrepreneurs will solve climate challenges', 'desc': '100 young people from all over the world present new innovative ideas for solving urban climate challenges.', 'date': '02 OCT'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={505FAF03-404B-4A60-9401-094011D253D4}', 'title': 'Newly developed Danish technology put to the test in China', 'desc': 'A Danish-Chinese collaboration on river monitoring that will enable the issuing of flood warnings and other incident alerts is based on new Danish technology...', 'date': '01 OCT'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={A6BA8E27-8656-427D-A170-F77EBFA3FA37}', 'title': 'Millions in funding for development of new turbulence theory', 'desc': 'A DTU researcher has received DKK 12.9 million in funding from the Poul Due Jensen Foundation to build a laboratory that will contribute to the development of a new turbulence...', 'date': '30 SEP'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={AFA835A7-EB08-4F05-A5EE-9212464DCF26}', 'title': 'Bacteria can break down plastic', 'desc': 'In 2016, Japanese scientists discovered a bacterium that can break down PET plastic, which is primarily known from plastic bottles and clothing fibres. Now, Danish researchers...', 'date': '30 SEP'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={3375DB95-FFA6-4A00-9E04-AE5D929B11BE}', 'title': 'New centre to strengthen society’s competitiveness', 'desc': 'DTU Learn for Life wants to accommodate society’s growing demand for continuing education and lifelong learning.', 'date': '27 SEP'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={F4D48030-2835-4415-8487-4496DA3DB6D5}', 'title': 'Preben Jørgensen is the new Head of DTU Electrical Engineering', 'desc': 'DTU’s new Head of Department has strong competences within the energy field.', 'date': '26 SEP'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={12E5D256-7BA1-4801-A37D-14845A984091}', 'title': 'Prudent use of antimicrobials in Danish animals continues', 'desc': 'The use of antimicrobials in animals has been declining for five consecutive years. This is one of the findings of the annual DANMAP report for 2018. Particularly significant...', 'date': '25 SEP'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={38E7A3F0-BBBB-4AFD-AD65-446046228A04}', 'title': 'DTU contributes to the science behind climate action', 'desc': 'Research from UNEP DTU Partnership is part of the science behind the policy decisions, as world leaders meet to increase the ambition for climate action in New York...', 'date': '23 SEP'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={A5277A8F-024A-430B-85D6-C29355910073}', 'title': 'Bornholm leading the way for future energy consumption', 'desc': 'An experiment with 800 households on Bornholm shows how consumers’ energy consumption can be remotely controlled for the benefit of the green transformation.', 'date': '23 SEP'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={9BB3628A-997F-4E84-B89D-87783C40BA41}', 'title': 'Tech conference on digitization and green solutions', 'desc': 'DTU is hosting the DTU High Tech Summit\xa0 – the largest university-driven tech conference in the Nordic region, focusing this year on digitization and sustainable solutions...', 'date': '20 SEP'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={4FEAFCD3-BF1D-4E02-80EA-EA018BFC6CAF}', 'title': 'New route to carbon-neutral fuels from carbon dioxide discovered by Stanford-DTU...', 'desc': 'A new way to convert carbon dioxide into the building block for sustainable liquid fuels was very efficient in tests and did not have the reaction that destroys the conventional...', 'date': '17 SEP'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={EF58F529-07D7-4206-BFF2-007464BC261F}', 'title': 'DKK 40 million for bold research ideas', 'desc': '21 of 52 projects which receive grants from VILLUM FONDEN under the Villum Experiment programme are from DTU.', 'date': '11 SEP'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={67789D72-0918-41A2-B6CD-D2487E8D8282}', 'title': 'FOSS and DTU enter partnership around innovation within food and agriculture', 'desc': 'FOSS and DTU join forces around common interests within research, development and education.', 'date': '11 SEP'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={2EB032C6-037C-4A9E-8C54-A67B245F8B86}', 'title': 'DTU opens its doors to the Education and Research Policy Summit', 'desc': 'DTU’s annual summit on education and research will offer a debate with a new minister and many new political spokespersons.', 'date': '10 SEP'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={4901DCB9-421A-4EE1-BE89-5ED03E6140EB}', 'title': 'DTU professor in materials research wins dual internation-al recognition', 'desc': 'Professor Marcel A.J. Somers has been awarded the dual honour of both receiving a rarely bestowed medal and giving a commemorative lecture at the 26th Congress of Heat...', 'date': '09 SEP'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={DE6056AE-79D5-4F3D-A91B-303597D92295}', 'title': 'New type of catalysts can pave the way for greater sustainability', 'desc': 'Catalysts of one or two atoms may become essential to the green transition in future. It is hoped that they can be used for environmentally friendly purification of water...', 'date': '07 SEP'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={49091E7B-2D0E-4C47-9CCF-D456DBA06A5C}', 'title': 'Danish quantum key distribution technology to create secure communication channels', 'desc': 'DTU researchers have developed a prototype for a quantum key distribution system which is now to be tested in a realistic fibre network.', 'date': '07 SEP'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={27EB9BC7-F7A6-40EB-B726-00A27B0ED2E5}', 'title': 'Heat pumps to use more climate-friendly coolant', 'desc': 'Researchers will investigate how to replace the current coolant used in heating systems for single-family houses with new coolants with reduced climate footprint.', 'date': '07 SEP'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={9A133744-C5FE-43AE-AC52-BD25C92DC75C}', 'title': 'The solar cells of tomorrow come in all colours and patterns', 'desc': 'Ugly solar energy systems on roofs are to be a thing of the past. Tomorrow’s solar cells must be integrated in the roof or façade of the buildings so that they are not...', 'date': '05 SEP'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={A36013B6-6BD6-4BED-A93A-815BA3894069}', 'title': 'Transportproteins provide key to improve infant formula', 'desc': 'Researchers identify and functionally describe key transport proteins, which contribute to creating a healthy early life gut microbiota.', 'date': '04 SEP'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={76B7BA8D-0314-4092-A1C9-C7BAACEB9DF8}', 'title': 'Why transporters really matter for cell factories', 'desc': 'Scientists discover the secret behind some protein transporters’ superiority. One transporter, MAE1, can export organic acids out of yeast spending close-to-zero...', 'date': '03 SEP'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={6D552F62-022B-41EE-AAA5-F9B548773967}', 'title': 'BrainCapture - Diagnosing epilepsy in 3rd world countries', 'desc': "Around 1 percent of the world population is suffering from epilepsy. Many patients in 3rd world countries aren't getting the correct treatment even though the medicine...", 'date': '03 SEP'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={CD21EB90-B792-4517-962C-D6EAD37ED1FC}', 'title': 'DKK 34 million for young researchers', 'desc': 'Three young DTU researchers have each received one of the coveted European Research Council grants for independent basic research of EUR 1.5 million or just over DKK 11...', 'date': '03 SEP'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={8759F82F-87EB-4B0C-8FDF-1BFA66C84D8A}', 'title': 'Marine ecological forecasts are a new tool for climate adaptation', 'desc': 'DTU researcher develops short-term forecasts for marine life that can help the fishing industry to adapt to climate change.', 'date': '03 SEP'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={77BF471F-6473-4A2A-BCE8-9498DC26BE10}', 'title': 'Do you want to be a mentor?', 'desc': 'Do you want to help the next generation of DTU students prepare for the world outside of academia? Become a mentor!', 'date': '02 SEP'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={1D86B762-D104-4DCC-A281-4EACF5722922}', 'title': 'DTU professor awarded Carlsberg Foundation Research Prize 2019', 'desc': 'Thomas Kiørboe, Professor of Ocean Ecology at DTU, receives research prize for his groundbreaking work.', 'date': '02 SEP'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={715866DB-8AE2-4796-A8C3-A4698C73398F}', 'title': 'Synklino will join BII’s Creation House Programme', 'desc': 'DTU-KU Spinout Synklino is among the three companies that will join the next session of BII’s Creation House programme. The programme runs for up to 18 months and sets...', 'date': '29 AUG'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={68E4EB33-E736-43CA-AA20-13C6F482C3A0}', 'title': 'Bio industry must accelerate green transition', 'desc': 'The Novo Nordisk Foundation makes large grant to the development of new biopharmaceutical processes, as well as education and training of students and employees in the...', 'date': '29 AUG'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={5935794B-1BA6-4853-8465-A80E466D18CA}', 'title': 'This year’s tuna tagging project under way in the Skagerrak', 'desc': 'Once again, DTU researchers are tagging bluefin tuna to find out why the huge fish have returned to Denmark as summer visitors. Thirty-two tuna have been tagged in four...', 'date': '28 AUG'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={6A9795EE-8571-4D07-B1B1-E5B99AE0C9D1}', 'title': 'DTU welcomed a record number of students', 'desc': 'A total of 2,414 new students were welcomed to DTU on Friday, 23 August.', 'date': '27 AUG'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={5015EED0-0131-4A07-B649-975C05E14D05}', 'title': 'Meeting sustainable development goals requires research and innovation', 'desc': 'On 21 August, 86 Danish ambassadors went on a study trip to DTU to learn more about the Danish strengths within research and innovation.', 'date': '27 AUG'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={97560621-74AE-4C94-BFC5-AF5F56A691DF}', 'title': 'DTU and NASA to look for new planets from the Canary Islands', 'desc': 'Experts from DTU Space have been working in the Canary Islands this summer. They have upgraded the Nordic telescope on the island of La Palma, and it is now tuned to look...', 'date': '25 AUG'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={92579B39-1301-4634-BE62-08555E1D0126}', 'title': 'Mapping ghost nets in Danish waters', 'desc': 'How much derelict fishing gear is there in the sea around Denmark, and how can it be removed? DTU Aqua will now investigate this.', 'date': '23 AUG'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={690F1A5D-F365-4C4F-835F-487B6DEFDBB2}', 'title': 'Breath! Respiring microbes generate more energy', 'desc': 'Researchers have now shed light on how bacteria and baker’s yeast generate and use their energy to grow. Knowing about cells’ energy use is essential for industrial biotech...', 'date': '23 AUG'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={1792F0F0-F5BF-48C4-9497-B25EEDB7DDC3}', 'title': 'Biotech start-up targets billion-dollar market by producing superior cannabinoids...', 'desc': 'The young biotech start-up Octarine Bio seeks to commercialize the production of brand-new tailored cannabinoids in yeast. Around one thousand new molecules have already...', 'date': '19 AUG'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={140B1A27-00B2-4175-8F98-B7FAE7342C71}', 'title': 'High jumper Rikke wants to compete at Olympics after graduation', 'desc': 'Rikke Andersen is living proof that with the right amount of willpower, a person can both compete at the highest level and complete their studies within the prescribed...', 'date': '19 AUG'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={E9F4C94D-76C5-4CA3-80B1-C81EB884F911}', 'title': 'Start-up to challenge big guns with artificial cannabis substances', 'desc': 'With its tailored cannabis substances, the biotech start-up Octarine Bio is eyeing the growing market for pain relieving drugs.', 'date': '19 AUG'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={CDC59567-A8A1-4ACE-866A-7FD8D559D5FF}', 'title': 'New approach to evaluate the structural performance of rotor blades', 'desc': 'A team of researchers from DTU Wind Energy has developed and demonstrated an integrated and efficient approach to evaluate the structural performance of the critical region...', 'date': '14 AUG'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={D585F311-1849-4004-8227-41B519AC49A8}', 'title': 'New technology must be designed for all', 'desc': 'DTU will develop teaching, research, and entrepreneurship methods that live up to the Sustainable Development Goals principle of ‘Leaving no one behind’.', 'date': '13 AUG'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={9C9B28FA-FEB5-434C-B6BE-EE8C80CDC175}', 'title': 'Young Danes shine at Chemistry Olympics', 'desc': 'Uniquely, all four Danish participants were able to bring home medals from the 2019 Chemistry Olympics.', 'date': '12 AUG'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={47712609-B657-4DAF-8DF8-D7C7A808A8EC}', 'title': 'Hans Christian Ørsted Research Award 2019 goes to DTU space scientist', 'desc': 'Lightning scientist Torsten Neubert receives the Hans Christian Ørsted Research Award for his contribution to an understanding of how giant lightning bolts are created...', 'date': '12 AUG'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={76383054-70AA-474C-B30D-89B6818FEE5A}', 'title': 'EU grant for development of medical sensor', 'desc': 'Professor Anja Boisen from DTU Health Tech receives Proof of Concept grant of DKK 1.1 million from the European Research Council.', 'date': '08 AUG'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={309D2F9B-A663-49D4-9391-677F7710B0FE}', 'title': 'Dean of research to advise EU on climate-neutral cities', 'desc': 'Dean of research at DTU, Katrine Krogh Andersen, has been appointed member of the EU’s new ‘Mission Board for climate-neutral and smart cities.’', 'date': '05 AUG'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={69F514ED-2AD4-4A34-98A5-81E3D0ACE6CD}', 'title': 'DTU’s own tokamak for fusion energy research', 'desc': 'As the only university in Northern Europe, DTU can now perform fusion energy experiments using its own tokamak.', 'date': '05 AUG'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={13E686E1-DF82-497E-B2F3-6AA88BE63303}', 'title': 'DTU welcomes a growing number of female students', 'desc': 'DTU’s 38 study programmes have once again seen an increase in the number of admissions. 2,426 new students have been offered a place on one of DTU’s study programmes...', 'date': '30 JUL'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={CBAB8EB3-E2F9-4E12-AD34-8B6247AE7D25}', 'title': 'DTU awards DKK 2 million in PoC grants', 'desc': 'Six exciting DTU projects with significant commercial potential have been awarded DTU’s Proof of Concept grant of up to DKK 500.000 in this year’s second application...', 'date': '30 JUL'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={77C36F3D-D58B-4AEB-8EA4-022C1376CC0A}', 'title': 'Kites harvest energy like wind turbines', 'desc': 'A new generation of kite wind turbines can supplement land-based wind turbines and produce energy in rural areas without a power grid.', 'date': '29 JUL'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={9550E627-F652-4D79-8C5F-21F6206645AC}', 'title': 'Holiday homes with swimming pool can become more climate-friendly', 'desc': 'A research project shows that CO2 emissions can be reduced significantly by controlling the heating of indoor pools in accordance with the production of wind energy.', 'date': '16 JUL'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={B4C5541F-8E2F-4118-9DA5-07A2BA6E2407}', 'title': 'New study underlines sea level rise in the Arctic ocean', 'desc': 'Sea levels in the Arctic oceans have risen an average of 2.2 millimeters per year over the last 22 years.This is the conclusion reached by a Danish-German research team...', 'date': '16 JUL'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={369D5339-17D7-455D-85F1-A412B2D07ADD}', 'title': 'Researchers have created quantum sensor outside the laboratory', 'desc': 'Researchers at DTU Physics have succeeded in building a small portable quantum technology measuring instrument which may be of great importance to the diagnosis of diseases...', 'date': '15 JUL'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={F368921A-8584-4255-BE9C-E8A34CCA0E69}', 'title': 'Erasmus for Young entrepreneurs - Supporting entrepreneurship', 'desc': 'Erasmus for Young Entrepreneurs is a cross-border exchange programme, which aims to help new, and aspiring entrepreneurs acquire relevant skills to run and grow a small...', 'date': '15 JUL'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={441B93BE-E400-44FC-B49B-6FE8F1A1EA1A}', 'title': 'On the edge of the possible', 'desc': 'The Danish hearing aid manufacturers are among the world leaders in their field.', 'date': '15 JUL'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={2C89DA29-943A-480A-8FCB-4C4A10EB49A2}', 'title': 'DTU Roadrunners defends first place at Shell ECO-marathon', 'desc': 'Once again, a DTU student won the international student competition for fuel efficiency.', 'date': '10 JUL'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={4B40CB90-267F-4EBE-836A-0B33BB44E796}', 'title': 'Improvement of railway switches', 'desc': 'A collaboration between Banedanmark and DTU has identified several new opportunities for smarter monitoring and maintenance of switches.', 'date': '09 JUL'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={77A18071-CAC0-4685-B6BE-8601357113D0}', 'title': 'Roskilde Festival: Students examine food waste', 'desc': 'Food waste is a recurring theme at Roskilde Festival. Two teams of DTU students are working to determine the actual extent of the problem.', 'date': '09 JUL'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={B3DF01A4-0BAB-4B4D-A819-1F58289150E1}', 'title': 'Slight decline in applications—but more women apply', 'desc': 'Slightly fewer have sought admission to DTU this year—in turn, however, the proportion of female applicants has increased.', 'date': '09 JUL'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={E4F08E61-9381-4A1C-8D98-57654A22CA10}', 'title': 'Roskilde Festival: Stories create relations', 'desc': 'DTU students test prototype for shady space in refugee camps. A space that can create a setting for greater interaction and new relations among the residents of the camps...', 'date': '08 JUL'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={9B828682-BB68-4579-8CAC-6977B5416889}', 'title': 'Roskilde Festival: Mellow Pod provides peace in noisy environment', 'desc': 'A group of DTU students has developed a special room for the Roskilde Festival that gives festival-goers the opportunity to find some peace and quiet.', 'date': '05 JUL'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={91A6EA9C-BBD9-4560-93E0-3EBBD11A8165}', 'title': '2019 Green Challenge: 130 ideas for a more sustainable world', 'desc': 'The DTU student conference Green Challenge was held on Friday 28 June. Once again, the conference was a cornucopia of great ideas for a sustainable world.', 'date': '05 JUL'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={45CFAFAE-34FB-4AA1-B62C-B8520CB43719}', 'title': 'Roskilde Festival: Electric cars replace generators at Food Court', 'desc': 'Three electric cars at Roskilde Festival ’s Food Court ensure ample electricity to cope with peak loads without using generators.', 'date': '05 JUL'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={AB565398-C6A2-4D19-B284-E69F6957815D}', 'title': 'Students ensure greater accuracy of scanning images', 'desc': 'Thanks to two student projects, the MRI (magnetic resonance imaging) research unit at Hvidovre Hospital will be able to receive images of the liver and brain tissue in...', 'date': '04 JUL'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={6CE6F8E3-2532-4588-8409-1FE4F54FB120}', 'title': 'Focus on low trophic aquaculture in EU funded project', 'desc': 'New, large international research project will improve the cultivation and utilization of organisms at the bottom of the marine food chain.', 'date': '04 JUL'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={F47884BD-255E-487C-AD6C-189920A203ED}', 'title': 'Roskilde Music Festival: Mobile wind turbine version 2.0', 'desc': 'A group of Mechanical Engineering\xa0students have developed a mobile wind turbine, which they hope will end up as a competitive product that can be used by larger camps at...', 'date': '03 JUL'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={F93DF2E2-580C-4288-888B-670C80D2016A}', 'title': 'DTU delivers sustainable solutions to India', 'desc': 'Four Danish-Indian research projects focus on climate-friendly solutions.', 'date': '03 JUL'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={A0DD1A6F-AB8C-4F16-8709-274297ECA0CD}', 'title': 'BEng students battling against disposable plastic', 'desc': 'A team of BEng students from DTU have developed a new process which makes it easy and cheap to use recycled cups, and which can significantly reduce the use of disposable...', 'date': '03 JUL'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={2897036B-E075-473A-8BF3-596AC4ED1BA7}', 'title': 'Become a fisheries engineer in Greenland and Denmark', 'desc': 'DTU offers a new BEng programme: Fisheries Technology.', 'date': '03 JUL'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={6BAF948B-51D1-49DB-8CCA-7DA09A972524}', 'title': 'Roskilde Festival sustainability lab for students', 'desc': 'For the tenth time, a group of DTU students used Roskilde Festival as an outdoor laboratory for testing new technologies that can make the festival more sustainable and...', 'date': '02 JUL'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={9BC324B1-2225-4E7F-BA21-566C316C7DDD}', 'title': 'DTU Compute part of new Danish Hub for Cybersecurity', 'desc': 'DTU Compute is part of the new Danish Hub for Cybersecurity granted by The Danish Industry Foundation.', 'date': '02 JUL'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={F56EB2C0-F696-4AC3-8DA5-68FC3B28E217}', 'title': 'Fortified foods can alleviate vitamin D deficiency in Denmark', 'desc': 'Foods fortified with vitamin D have proved to be effective in avoiding vitamin D deficiency among Danish and Pakistani women during winter, according to a study from...', 'date': '02 JUL'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={20501B1F-F2B2-4478-84B1-5FBD389912C1}', 'title': 'DKK 2.4 Million to spread the enthusiasm for biotechnology', 'desc': 'The Novo Nordisk Foundation grants DKK 2.4 Million to ensure students in primary and secondary schools free educational materials in biotechnology from DTU.', 'date': '02 JUL'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={A2BF7BBA-5923-485D-95EB-64C68062DEF6}', 'title': 'Danish universities climbing global ranking list', 'desc': 'According to QS World University Rankings, DTU is ranked number 112 among the world’s top 1,000 universities.', 'date': '27 JUN'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={457E728C-6817-4A45-BD24-34D4C68FA916}', 'title': 'New European Wind Atlas finalized', 'desc': 'During the last four years, researchers from all over Europe have been working on creating a New European Wind Atlas. The results are being presented in Brussels today...', 'date': '27 JUN'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={12A911E9-D553-4A29-B66B-DDE17095BD5E}', 'title': 'New lab completes teaching in solar cell systems', 'desc': 'In June, 12 students from the three-week Applied Photovoltaics course were the first to use a new laboratory in which you can build and test full-sized solar panels.', 'date': '26 JUN'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={330B1609-520C-46DD-B94E-D4A11A2A15FD}', 'title': 'Tomorrow’s power grid should be intelligent', 'desc': 'A new Danish-Indian project will enable the power grid to sense and compensate for loss of electricity and fluctuating input from renewable energy sources.', 'date': '24 JUN'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={4A15B7C7-C690-4233-B0B6-3DE7867D292D}', 'title': 'Climate change can alter Greenland drastically', 'desc': 'If climate change continues unabated, all the ice in Greenland may melt away in the course of just a thousand years and will lead to significant changes in the environment...', 'date': '21 JUN'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={955906C4-4DAE-4B78-8A87-58FD7497B5AC}', 'title': 'International research teams will develop better crops', 'desc': 'The Novo Nordisk Foundation grants USD 30 million to an international research consortium which will uncover how bacteria can be exploited to create better crops.', 'date': '21 JUN'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={B544C1F3-C0F2-4170-9458-CCFD1BEA16DF}', 'title': 'Playware wins award as Most Outstanding Healthcare Innovator in the World in 2019', 'desc': 'The award as ‘The Most Outstanding Healthcare Innovator in the World in 2019’ was presented to Professor Henrik Hautop Lund at the gala for the 2019 at The Global Over...', 'date': '21 JUN'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={29EAE6D1-40CA-492C-BC19-5972D72340C2}', 'title': 'Caffeic acid can slow down oxidation of fish oil in foods', 'desc': 'New knowledge from the National Food Institute, Technical University of Denmark, can make it easier to add fish oil to fatty foods without them quickly going rancid...', 'date': '20 JUN'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={4E594BC4-8DE4-4D12-AF22-445D2A8C0920}', 'title': 'DTU enters in to a new partnership for climate technology', 'desc': 'Through UNEP DTU Partnership, DTU has created a new partnership with Green Technology Center - Korea to collaborate on the climate technology needs in developing countries...', 'date': '18 JUN'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={42925D10-6FDB-40E2-9143-6915D284E567}', 'title': 'Underwater robot can count starfish and measure biomass', 'desc': 'Specially developed smart sensors and underwater cameras can enable robots to handle monitoring tasks in the sea', 'date': '17 JUN'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={FA554C8D-D67C-4923-BE21-B7C3CE1FDEB5}', 'title': 'The mystery of the weeping walls', 'desc': 'Magnesium-oxide boards, or MgO boards, were used in construction from 2010-2015 as windbreak panels until it turned out that the boards had a frightening ability to absorb...', 'date': '17 JUN'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={07564F81-E47B-4256-9209-F99C7DFE7CD8}', 'title': 'DTU promotes health technology programmes', 'desc': 'With the Advanced Materials and Healthcare Engineering programme, due to start this autumn, DTU now offers seven master’s programmes focusing on health with a technological...', 'date': '14 JUN'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={4EF702EC-09CF-41DF-ABC7-46E8517EE6BE}', 'title': 'Denmark should focus on converting straw to biofuel', 'desc': 'New calculations from DTU indicate that there are both economic and environmental benefits from exploiting straw for biofuel for heavy transport instead of for district...', 'date': '14 JUN'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={5DB37391-574E-4674-A1A8-D1D97BD0C805}', 'title': 'Denmark to name planet discovered by DTU researcher', 'desc': 'Citizens of Denmark are invited to make suggestions for the names of an exoplanet and star discovered in 2008 some 1,000 light years from Earth.', 'date': '14 JUN'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={4671F574-3AB9-4D64-9453-54E82F702773}', 'title': 'Women need to have more self-belief', 'desc': 'Sara Shafiee is a postdoc at DTU Mechanical Engineering and holds an industrial PhD. She has now been appointed as an ambassador for the InnoWomen project, which aims...', 'date': '14 JUN'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={D5958191-DF64-453C-B440-A2541489852F}', 'title': 'DTU boosts its research in automation and robots', 'desc': 'The appointment of three researchers and the addition of a brand new Master of Science (MSc) programme significantly strengthens DTU’s work in automation and robot technology...', 'date': '12 JUN'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={CA9E4079-AC32-49EF-AACB-2A2557D8766D}', 'title': 'In 2020, we celebrate H.C. Ørsted’s discovery of electromagnetism', 'desc': 'Next year is the 200th anniversary of one of history’s major scientific discoveries. To celebrate, universities, institutions, companies, businesses, and organizations...', 'date': '11 JUN'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={BB1AB24E-DD4A-49DA-BC14-AF7D4C5740FA}', 'title': 'Recommendations for catalysis research in electrolysis', 'desc': 'Two leading Danish catalysis researchers have prepared a comment for the distinguished scientific journal Nature Energy with three clear recommendations for their colleagues...', 'date': '07 JUN'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={E4657D2D-20AC-433F-94E9-31A5418644B4}', 'title': 'EU launches new funding programme for DeepTech Innovators', 'desc': 'EU Commissioner for Research, Science and Innovation Carlos Moedas kicks off EU roadshow for new funding opportunities for start-ups with a visit to DTU.', 'date': '06 JUN'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={4DEEF47A-4C5D-4FD3-90FC-9B06D69E5F67}', 'title': 'Artificial cooling of Arctic soil safeguards global genetic material', 'desc': 'Artificial cooling and creative engineering solutions are key to taking good care of the backup copies of the world’s plant-based genetic material, which are stored in...', 'date': '04 JUN'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={E045F18E-6B68-48A7-8D35-EA16880CF181}', 'title': 'Associate professor Thomas Bolander receives H.C. Ørsted Medaljen', 'desc': 'The prestigious H.C. Ørsted Medalje is awarded to associate professor Thomas Bolander from DTU Compute for his excellent ability to disseminate research.', 'date': '29 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={A2A7EBB9-32D0-48F5-ACA7-F78EEBEF3499}', 'title': 'Lars Christoffersen new Dean of Undergraduate Studies and Student Affairs', 'desc': 'Head of DTU Diplom has been appointed new Dean of Undergraduate Studies and Student Affairs.', 'date': '29 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={39E857A8-1FC5-4C15-BCF8-856F0755DEB9}', 'title': 'DTU Professor Appointed Mission Innovation Champion', 'desc': 'Mission Innovation\xa0– a global initiative bringing together 24 countries and the EU to accelerate the development of clean energy technology – has recognized 19 exceptional...', 'date': '29 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={749083EE-D765-4F06-9279-725B45070B73}', 'title': 'DTU equipment on board NASA’s next big mission to Mars', 'desc': 'NASA will soon launch its Mars 2020 mission to the red planet with DTU equipment on board. Already now NASA is offering people across the planet a boarding pass for the...', 'date': '28 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={0CD4131D-97BE-4CC7-A8FA-08E562A9F108}', 'title': 'Students name DTU in image survey', 'desc': 'Engineering students see DTU as the most attractive workplace.', 'date': '28 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={E33C98C5-FCFE-4B08-BC5B-506F496241C4}', 'title': 'Irina Borodina wins 2019 EU Prize for Women Innovators', 'desc': 'Group Leader at DTU Biosustain and Co-founder of BioPhero, Irina Borodina, was awarded the prestigious 2019 EU Prize for Women Innovators at an official ceremony at the...', 'date': '28 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={468168F2-419C-4AE4-8512-9852BDF5C463}', 'title': 'Parasites hinder organic trout production', 'desc': 'Optimum water conditions, hiding places for fish, and the prevention and reduction of parasites and bacteria to secure organic trout fry.', 'date': '27 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={91C33FAC-B359-47D5-AB56-59FE11F0DACD}', 'title': 'Extremely compact reactor has potential to reduce global CO2 emissions significantly', 'desc': 'New paper in Science suggests that as much as one percent of global CO2 emissions can be saved if electrified, and significantly more compact, technology is applied across...', 'date': '27 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={0BAE030B-42C8-422F-ACC6-BBFD7010F6A5}', 'title': 'Fungal batteries will store alternative energy', 'desc': 'Researchers from DTU and Aalborg University receive donation from Novo Nordisk Foundation for the development of biodegradable batteries.', 'date': '27 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={4E94A160-5E87-458C-A910-908DFF6175C8}', 'title': 'Well-documented path from farm to fork', 'desc': 'A new project will develop technologies and methods that can both document a food product’s path from farm to fork and help prevent plagiarism. The National Food Institute...', 'date': '27 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={9FF1799A-7C84-4ABF-A39C-BADE9F582B7C}', 'title': 'Nanotechnologies are best developed in collaboration', 'desc': 'It is in the meeting between people that new realizations arise, new networks are established and failed projects can be avoided. Really that is the essence.', 'date': '24 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={1531F775-7B31-4FBC-B52A-AFE766FBBD0C}', 'title': 'Press release: Focus on research resolves the problem with the electricity network...', 'desc': '', 'date': '24 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={590BB0FB-B3FA-44FE-BA42-044788A54D85}', 'title': 'New study programme on autonomous robots', 'desc': 'From autumn 2019, DTU will be offering the MSc programme in Autonomous Systems with a primary focus on robots and automated devices.', 'date': '24 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={F06EA494-39BB-4112-8FD0-4452152A8DD5}', 'title': 'Two new test stands are ready for wind turbines in Østerild', 'desc': 'The expansion of Test Centre Østerild has now reached the point when it is possible for the manufacturers to start casting the foundations on the two new test stands.', 'date': '24 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={1524F5A9-4D45-4C60-9839-A7216512FC61}', 'title': 'Organic mussels ready to be served on the Danes’ dinner tables', 'desc': 'A longer harvest season, stable production and collaboration with the retail sector are to increase the Danes’ appetite for farmed mussels, which are being exported today...', 'date': '24 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={595546C2-1F07-42FF-8CA5-C14B2552BB80}', 'title': "DTU among the world's best at using open access", 'desc': 'When it comes to using open access, DTU is best in the Nordic region and number 31 in the world, according to a new ranking from Leiden University in the Netherlands.', 'date': '23 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={04794D78-529B-4CED-8EEC-F2F4F39CD7F0}', 'title': 'Organic and delicious, but unknown in Denmark', 'desc': 'Organic common mussels are easy to grow on ropes in Denmark. Nevertheless, few find their way to Danish consumers.', 'date': '23 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={26F63CBD-9388-4520-9B83-EE2DA38D8590}', 'title': 'Need for rigorous procedures within electrochemical production of ammonia', 'desc': 'Many experimental studies of electrochemical synthesis of ammonia are flawed—a new study in Nature highlights the need for rigorous protocols moving forward', 'date': '23 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={E999C890-A0E9-427C-ABC2-A6A6320C0202}', 'title': 'Danish and Korean students meet on sustainability', 'desc': 'An innovation event focusing on sustainability was held at the Korea Advanced Institute of Science and Technology (KAIST) during the visit by a Danish delegation to Korea...', 'date': '23 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={D594819C-0BAE-46F0-88AF-0885A5BD57EA}', 'title': 'EnergyLab Nordhavn wins Danish design award', 'desc': 'EnergyLab Nordhavn received the Danish Design Award 2019 in the Visionary Concepts category.', 'date': '22 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={AC5E3912-401E-4E11-9CE8-98EBB143660E}', 'title': 'Machine learning reveals a new bacterial weak spot to antibiotics', 'desc': 'Feeding lots of experimental data into an open machine learning algorithm revealed that antibiotics create certain metabolic stress in bacteria. This knowledge could...', 'date': '21 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={D8DC5CBD-5169-49CE-A9ED-87911E94042C}', 'title': 'Chickpea cooking water recycled to make a vegan dessert', 'desc': 'A vegan mousse based on chickpea cooking water—aquafaba—won the competition for innovative and sustainable foods.', 'date': '20 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={4F072914-4784-450B-A87E-24462D6FB872}', 'title': 'Human impact on indoor climate is being mapped', 'desc': 'Advanced climate chamber measurements provide new knowledge about human emissions and impact on indoor climate in buildings.', 'date': '20 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={219FDCAD-074A-459F-A60C-04FD0FCB26B0}', 'title': 'Cancer cell genomes identified using new technology', 'desc': 'Two cancer cells from the same tumour may have totally different DNA profiles. A new technique to identify them may lead to better treatments.', 'date': '16 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={E7B1C982-6028-4300-92A1-E6E33FD04B2A}', 'title': 'Danish IP Fair 2019 – opening doors between universities and industry', 'desc': 'The Confederation of Danish Industry hosted the third annual Danish IP Fair on May 8 2019. The event aimed to make patentable science and technology from university easily...', 'date': '16 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={1FF62714-D6EE-4EB5-BAFF-9ED86F65A305}', 'title': 'Cancer cell genomes identified using new technology', 'desc': 'Two cancer cells from the same tumour may have totally different DNA profiles. A new technique to identify them may lead to better treatments.', 'date': '16 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={504BDA57-3F0A-447F-9FB9-F2342B6E645B}', 'title': 'DTU helping high school students represent Denmark', 'desc': 'The winners of the Stockholm Junior Water Prize Special Prize in the Young Scientists competition will be coached by DTU researchers.', 'date': '15 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={4B00C10E-444D-4ED3-82D3-EA4E8AEE3454}', 'title': 'A substantial benefit from replacing steak with fish', 'desc': 'The average Dane will gain a health benefit from substituting part of the red and processed meat in their diet with fish, according to calculations from the National...', 'date': '15 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={21F8E58F-D7B9-48EB-887C-057D8665A465}', 'title': 'Laser trucks help maintain roads', 'desc': 'Pavement engineering company, Dynatest , has developed a truck in partnership with DTU which analyses the state of the road using laser technology.', 'date': '14 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={941DCC05-BEB0-4521-8835-87BF360E2D19}', 'title': 'New international hall of residence at Lyngby Campus', 'desc': 'A new hall of residence has shot up in record time in DTU’s northwestern corner, and 144 international students have taken occupancy.', 'date': '13 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={0710D675-0C4F-4BC2-A669-9A49544291FA}', 'title': 'Nobel Laureate to give lecture on quantum physics at DTU', 'desc': 'Nobel Laureate Professor Serge Haroche will visit DTU in May to give a lecture on quantum physics.', 'date': '13 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={FCA1D43D-9324-49BA-8650-B7AD8367C118}', 'title': 'EUR 12 million for independent research', 'desc': 'Independent Research Fund Denmark has granted a total of EUR 12 million to 24 DTU projects.', 'date': '10 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={A20FF4B3-D03A-4E3A-803F-DE41EEEEACCD}', 'title': 'Sleeve can warn of potentially deadly neurodegenerative diseases', 'desc': 'DTU awards Student Startup of the Year to Paragit Solutions for their sensor for early warning of Parkinson’s disease, ALS, and Alzheimer’s disease.', 'date': '10 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={BD5CD7DF-CF1F-47E1-B2A5-4BAFEC3EC948}', 'title': 'DTU President co-signs UN manifesto on gender equality', 'desc': 'Sixteen Danish top executives in the UN initiative Gender Diversity Roundtable recommend three focus areas to promote gender equality and diversity.', 'date': '09 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={40F72280-6292-4A11-86CF-0706D1A062A4}', 'title': 'DTU Biosustain joins Global Biofoundries Alliance', 'desc': 'The Novo Nordisk Foundation Center for Biosustainability (DTU Biosustain) joins the Global Biofoundries Alliance. This new initiative will strengthen international collaboration...', 'date': '09 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={A3808C04-3146-48F0-B725-8102519659D2}', 'title': 'Crown Prince and Princess attend DTU’s Commemoration Day 2019', 'desc': 'DTU’s Commemoration Day celebrations were attended by the Crown Prince and Princess. Following the presentation of a large number of prizes and awards to researchers, faculty...', 'date': '08 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={B5DE3F2E-986D-4A13-B2D1-B61DD801C853}', 'title': 'Disconnected power cable to Bornholm offers unique test option', 'desc': 'The island of Bornholm is on its own these days in terms of electricity supply, as the submarine cable to Sweden’s power grid has been disconnected. This is an interesting...', 'date': '08 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={98D7D5CC-AA81-4F93-8F20-CF2E8F2DE34B}', 'title': 'No risk of adverse health effects from pesticides in Danish food', 'desc': 'Pesticide residues in food on the Danish market do not pose a risk of adverse health effects, according to an assessment from the National Food Institute, Technical University...', 'date': '07 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={A2C3FA1F-51B0-46EB-9685-C5DEF300F542}', 'title': 'New technology behind the world’s smallest power converter', 'desc': 'Five young DTU researchers have developed a new technology for producing a power converter which is shaped like a small cube measuring only a couple of millimetres on each...', 'date': '07 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={1A3904D9-6E2D-476F-AA90-4EE75332D63E}', 'title': 'Lifecycle analyses of climate protection measures', 'desc': 'In future, it will be possible to assess the environmental impact of different types of climate protection solutions in urban areas.', 'date': '07 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={2593C51D-3E7E-442F-9DA6-FD89779B7706}', 'title': 'New Nordic network for artificial intelligence', 'desc': 'The five Nordic technical universities in Nordic Five Tech aim to make Scandinavia a global hub for research, education, and innovation within the field of artificial...', 'date': '07 MAY'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={E841F8F3-BBE5-40E0-905A-AC11C66CE878}', 'title': 'Digitization to prepare electricity grid for green transition', 'desc': 'Over the next four years, four Danish universities—headed by DTU—will conduct research into how increased digitization of the electricity grid and energy supply may promote...', 'date': '01 MAY'}
# ...
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={A93B70B1-F71B-41DE-B2F1-DF9BDD1807D1}', 'title': '“Dialogue is what makes all the difference in the world”', 'desc': 'With her distinctive voice and the ability to communicate clearly and comprehensibly, Professor at DTU Management Kirsten Halsnæs has for several decades influenced the...', 'date': '25 APR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={0875193C-4CF3-4F9F-9B8C-0D882C703D51}', 'title': 'Wind turbines to venture out into the deep sea', 'desc': 'Floating offshore wind turbines are gaining ground. A new Danish project aims to make it cheaper and easier to produce floating foundations for deep water.', 'date': '23 APR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={6281254C-CFDF-49BB-A832-2F0CFCC1BB26}', 'title': 'New doctorate will disseminate plasma technology', 'desc': 'Senior Researcher Yukihiro Kusano has collated many years’ research in a doctoral dissertation. Here he points to new applications of plasma technology—among other things...', 'date': '15 APR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={246BBED3-8683-4012-A294-20DB7F0015F4}', 'title': 'Abundance of information narrows our collective attention span', 'desc': 'New study in Nature Communications finds increasingly narrow peaks of collective attention over time, supporting a ‘social acceleration’ occurring across different domains...', 'date': '15 APR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={4FDC348A-A205-4F98-931B-98FE5BDFA11A}', 'title': 'New knowledge will change rail maintenance', 'desc': 'Danish research has solved the riddle of the large quantity of cracks observed in European rails in the past 10-15 years.', 'date': '12 APR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={33AFFFF7-E1FF-4EF8-A09B-5BAEBDDAB00A}', 'title': 'Intestinal bacteria and their genetics determine dietary advice', 'desc': 'Dietary advice should be more personalized and based on knowledge of the composition of the individual person’s intestinal bacteria.', 'date': '11 APR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={6064BD6A-1495-4039-984E-BA719ECCDB09}', 'title': 'Small underwater drone to help fishermen', 'desc': 'Young researcher contributes to the development of a small new autonomous underwater vehicle which is to help fishermen identify shoals of fish.', 'date': '11 APR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={1DEC4C79-CBAF-4F49-8373-7A535AD3B673}', 'title': 'Green Student Movement puts forward new Danish climate policy', 'desc': 'With the help of an energy modelling tool developed at DTU management, The Green Student Movement has created its own ambitious climate plan.', 'date': '11 APR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={A1E9CEF9-30DB-4039-8905-C3883EFD3551}', 'title': 'New computer model ensures faster development of hearing aids', 'desc': 'Young researcher has optimized the simulation models used for developing new hearing aids. The necessary calculations can now be made up to 20 times faster.', 'date': '10 APR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={99BB89DB-206B-4F1F-A9FF-2AB72F060253}', 'title': 'Realistic climate initiatives from political parties? DTU crunches the numbers', 'desc': 'A new DTU energy model has been used to reality-check the climate policy goals announced by the Danish government and six political parties.', 'date': '09 APR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={BBB6C6F0-7314-4DCD-8935-BBCDE795455A}', 'title': 'Spin-out sells technology to monitor cancer treatments', 'desc': 'Tetramer Shop has gone to market with technology that can colour and thereby track immune cells and, thus, measure whether a treatment is working correctly for the individual...', 'date': '08 APR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={FE2C2C11-67B1-49D9-A7DE-A4BA36BD2650}', 'title': 'PivotBuoy project receives €4m to unlock cost competitive floating wind', 'desc': 'DTU Wind Energy is part of the new project, PivotBuoy. The aim of the project is to\xa0reduce the cost of floating offshore wind.', 'date': '08 APR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={C06F179D-A51B-4B68-9A7C-BA57FDFA6A03}', 'title': 'New Sustainable Energy Systems collaboration with China', 'desc': '40 Danish and Chinese researchers committed to push collaborations\xa0forward within the framework of Sino-Danish Center for Education and Research - \xa0Sustainable Energy...', 'date': '05 APR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={76157F4A-5CD5-4320-965C-05DABE00199D}', 'title': 'Personalized medicine for children with cancer', 'desc': 'In a joint project involving Rigshospitalet and DTU, parents of all Danish children with cancer will be given the offer to have the genetic characteristics of their children...', 'date': '05 APR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={6F8EC9DE-4279-44CE-9E6A-719B805D0082}', 'title': 'How close are we to personalized medicine?', 'desc': 'Mapping patients’ genetic make-up could lead to better treatment for a wide range of diseases.', 'date': '05 APR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={D0E614C2-FFC0-4083-BC41-83ECD9261A09}', 'title': 'Copenhageners’ biowaste may become steaks', 'desc': 'A new project will develop technology for extracting protein from organic waste, which can subsequently be used as a protein supplement for humans or in animal...', 'date': '03 APR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={87C403A6-8EFD-4B4A-9BA9-AD1C829E4986}', 'title': 'Mathematics professor named VILLUM Investigator', 'desc': 'Professor Per Christian Hansen from DTU Compute receives a VILLUM Investigator grant of DKK 35 million. He will develop new algorithms that can describe the uncertainty...', 'date': '03 APR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={E645F46E-9DF1-4560-B949-386130CA0D8F}', 'title': 'Large-scale project to decarbonize European islands', 'desc': 'DTU is one of the 27 partners in a new large-scale European project. As responsible for one of the three demo islands (Bornholm) DTU will test a new storage technology...', 'date': '03 APR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={04F8D37C-AC4E-492B-AB63-79566670C2E3}', 'title': 'DTU appoints Head of DTU Health Technology', 'desc': 'Professor Thomas Andresen will become the new Head of Department of the newly created DTU Health Technology. (This story has been updated)', 'date': '02 APR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={7B196EDF-336F-4AB3-92C6-AB6535C40C2A}', 'title': 'Henrik Clausen new external member of DTU’s Board of Governors', 'desc': 'MSc in Engineering and MBA Henrik Clausen has been appointed new member of the Board of Governors.', 'date': '02 APR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={B0932173-208B-4EFA-AB81-3B6C2DCFD052}', 'title': 'DTU develops breast cancer scanning equipment', 'desc': 'DTU has entered into collaboration with the UK company Kromek aimed at developing a scanner that can improve breast cancer diagnostics.', 'date': '02 APR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={247B2ACB-8A21-4E79-B6FB-4F93D4741630}', 'title': 'Two DTU researchers receive EUR 5 million from the ERC for independent research', 'desc': 'Two DTU researchers have received the prestigious ERC Advanced Grants from the European Research Council.', 'date': '29 MAR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={60CE1ABE-93F1-4E12-B094-8A1B2BA8EA56}', 'title': 'New unique infrastructure to accelerate development of digital solutions for the...', 'desc': 'DTU has entered into collaboration on establishing a new digital infrastructure, which will, among other things, facilitate fast, easy and open access to data to be used...', 'date': '29 MAR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={6BC6DBD4-9186-4E2D-94A2-75C13BD6C5C3}', 'title': 'DTU Space to develop cancer scanner with English company', 'desc': 'DTU Space and UK company Kromek have started a collaboration to develop a new advanced scanner that have a huge potential for improving breast cancer diagnosis.', 'date': '29 MAR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={F6691075-22B1-4210-9CA2-519C20A31318}', 'title': 'Cameras and DNA tests to control discard fish', 'desc': 'Under new EU rules, fishermen must land previously discarded catches. New control methods are needed—for example video cameras and DNA analyses.', 'date': '27 MAR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={B69D7495-5AE4-4143-8320-6C6CFDFF6C3F}', 'title': 'Danish shipping must be autonomous', 'desc': 'Researchers must help Denmark develop the first autonomous ships.', 'date': '26 MAR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={3AA1F90B-3ECD-4093-AF56-420BD9F43D55}', 'title': 'Human protein produced in CHO-cells can save donor blood', 'desc': 'Researchers from DTU Biosustain have successfully produced mammalian cell lines (CHO) that can produce 1.2 g/L recombinant Alpha-1-antitrypsin proteins with human glycosylation...', 'date': '26 MAR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={8BB0E6EC-4756-4368-9469-77D47D17A044}', 'title': 'Six projects awarded DTU’s PoC grant', 'desc': 'Six exciting DTU projects with significant commercial potential have been awarded DTU’s Proof of Concept grant of up to DKK 500.000 in this year’s first application round...', 'date': '25 MAR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={64B3AFFA-2457-4263-892C-02374FF1EDC5}', 'title': 'Digitalization can drive new water technologies', 'desc': 'Research, innovation, education, and entrepreneurship can contribute to the development of new technologies in the water sector according to a new report.', 'date': '25 MAR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={D9943BFA-8EBC-4E58-976A-9B0176B14002}', 'title': 'From menace to resource: Starfish become animal feed', 'desc': 'The world’s first starfish meal factory will be inaugurated at the Limfjord on Friday, 29 March as a result of collaboration between universities and businesses.', 'date': '25 MAR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={1E509101-9C36-4EC9-BBD8-71F94A54DC3C}', 'title': 'Danish biotech company announces the completion of a €5.5 M seed investment', 'desc': 'The big Chinese fine chemical company Zhejiang NHU invests €5.5 M in the biotech start-up Cysbio to develop new and affordable biochemicals.', 'date': '25 MAR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={BFD57621-9180-471A-B417-FA0F9E4563D0}', 'title': 'UNEP DTU signs MoU with Argentinian network of municipalities for energy efficiency...', 'desc': '', 'date': '19 MAR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={C099156C-416C-45EC-9CBB-7A1C03F57B26}', 'title': 'DTU Wind Energy granted the secretariat of IEA Wind TCP', 'desc': 'DTU Wind Energy has been chosen to lead the secretariat of the International Energy Agency Wind Technology Collaboration Programme, also known as IEA Wind TCP.', 'date': '19 MAR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={F6599FB5-756E-41CA-8199-D2047AF22278}', 'title': 'Narcolepsy may be caused by the body attacking itself', 'desc': 'Researchers from DTU and the University of Copenhagen are now pointing out that narcolepsy is an autoimmune disease. This may be important to future treatment of this chronic...', 'date': '19 MAR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={52338DDD-E182-4B50-A288-F892D6E31962}', 'title': 'Students accelerate sustainable solutions at Folkemødet', 'desc': 'Students will receive funding of EUR 13,400 to develop and test sustainable concepts before and during the People’s Political Festival 2019.', 'date': '18 MAR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={91201F2B-977E-48BD-BB7A-61A38845683A}', 'title': 'EU strengthens cybersecurity research', 'desc': 'A new large research network will strengthen European cybersecurity capacity. DTU represents Denmark in CyberSec4Europe pilot project.', 'date': '18 MAR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={F2C013FE-685F-4B61-BBFD-FEE53CBBB5FB}', 'title': 'Focus on proteins', 'desc': 'Zero Hunger: The hunt for proteins', 'date': '15 MAR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={91B1170F-0A59-479A-AEF4-31928176485A}', 'title': 'Can insects feed the world', 'desc': 'Putting insects on the menu requires more than just good presentation, according to Roberto Flore, a renowned chef who has travelled far and wide to explore the world of...', 'date': '15 MAR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={E25077A0-DE8A-425B-9AB6-9560938E48C6}', 'title': 'Fish can be fed plant waste products', 'desc': 'Fish from fish farms are feeding more and more mouths. But what should the fish eat? Research shows that plant proteins may be the answer.', 'date': '15 MAR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={24C8B5B8-5ABC-4615-B93C-ABC15E885E7F}', 'title': 'From seaweed to proteins', 'desc': 'Food researchers have invented methods for extracting proteins from seaweed. One of them is now being tested in a pilot plant at ingredient producer CP Kelco .', 'date': '15 MAR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={BEF74092-1A50-4550-A1CD-36E0089BDDBC}', 'title': 'Healthy low-cost food for the third world', 'desc': 'Research plays a key role when dairy giant Arla Foods develops products for third-world countries.', 'date': '15 MAR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={F4818550-C273-46FE-BAF4-9057E37CA2F9}', 'title': 'New protein sources', 'desc': 'Cases for DTU’s research and innovation in relation to proteins for animal feed and food products.', 'date': '15 MAR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={B1CAFAA9-A836-4643-9F3F-9113B47842C1}', 'title': 'Largest battery in Denmark to be installed on Bornholm', 'desc': 'A new project led by DTU has been granted 19 million DKK by the Danish Energy Technology Development and Demonstration Program. The project will demonstrate the largest...', 'date': '14 MAR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={60C0C1B3-4080-4523-BE01-CD38BA9F2C03}', 'title': 'New mentor programme for pre-startups launched at DTU', 'desc': 'A new mentor programme for pre-startups was officially launched at DTU last month. The programme will help young DTU entrepreneurs turn their inventions into successful...', 'date': '12 MAR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={A1E601B6-926C-4957-8D3D-04E768856048}', 'title': 'Packed Open House event', 'desc': 'Inquisitive young people were already waiting in large groups when DTU opened its doors for the Open House 2019 event at 12 noon. And more than 600 students and staff wearing...', 'date': '11 MAR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={72AB1E47-6613-4828-8E81-2575AD327417}', 'title': 'Sustainable beer made from surplus sushi rice', 'desc': 'Research from the Technical University of Denmark allows excess rice intended for use in sushi to be converted into beer.', 'date': '11 MAR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={2D8786E3-F57A-40DC-AEE1-FC68696B01A6}', 'title': 'DTU strongly represented in the Danish Youth Climate Council', 'desc': 'Both the President and one other member of the Danish government’s new Youth Climate Council are DTU students.', 'date': '08 MAR'}
# {'url': 'https://www.dtu.dk/english/news/Nyhed?id={EC5B22D1-FC69-4366-A9BB-4B55330BA7E0}', 'title': 'Sewage reveals levels of antimicrobial resistance worldwide', 'desc': 'Sewage can reveal the occurrence of antimicrobial resistant bacteria among healthy populations, an international study led by the Technical University of Denmark shows...', 'date': '08 MAR'}

# %% [markdown]
# ### 2.2 Pictures links MLSM
#
# In this example, we want to get the picture link of the people of the MLSM group (http://mlsm.man.dtu.dk).
#
# Firstly, we need to specify the webpage url and request the page content.
#
# Second, we load the document in Scrapy
#
# Inspecting the page, we find that the picture link is stored as attribute $scr$ in image ($img$) elements which class is ".person-img.circle".

# %%
# specify the url
url = "http://mlsm.man.dtu.dk/people/"
# get the content
contents = urllib.request.urlopen(url).read()   
# load the document in PyQuery
pq = PyQuery(contents)
# Get all the elements with "img" tag inside the class "person-img.circle"
newsItems = pq('.person-img.circle > img')
# for each element print the source link.
for x in newsItems.items():
    print(x.attr('src'))
# Out:
# https://i2.wp.com/mlsm.man.dtu.dk/wp-content/uploads/2018/11/pereira_francisco-e1545259489853.jpg?resize=103%2C103
# https://i0.wp.com/mlsm.man.dtu.dk/wp-content/uploads/2019/08/cami.png?resize=150%2C150
# https://i0.wp.com/mlsm.man.dtu.dk/wp-content/uploads/2018/11/Rodrigues_Filipe.jpeg?resize=150%2C150
# https://i0.wp.com/mlsm.man.dtu.dk/wp-content/uploads/2019/01/ava_-square_400x400.jpeg?resize=150%2C150
# https://i1.wp.com/mlsm.man.dtu.dk/wp-content/uploads/2018/12/Bojan-Kostic-e1547027539712.jpg?resize=150%2C150
# https://i0.wp.com/mlsm.man.dtu.dk/wp-content/uploads/2018/12/Petersen_Niklas.jpg?resize=150%2C150
# https://i0.wp.com/mlsm.man.dtu.dk/wp-content/uploads/2018/11/peled_inon.jpg?resize=150%2C150
# https://i1.wp.com/mlsm.man.dtu.dk/wp-content/uploads/2018/11/Servizi_Valentino2.jpg?resize=150%2C150
# https://i2.wp.com/mlsm.man.dtu.dk/wp-content/uploads/2019/08/sergio.png?resize=150%2C150
# https://i2.wp.com/mlsm.man.dtu.dk/wp-content/uploads/2019/01/Daniele_picture-e1547036005444.jpg?resize=150%2C150
# https://i1.wp.com/mlsm.man.dtu.dk/wp-content/uploads/2019/05/Georges.png?resize=150%2C150
# https://i1.wp.com/mlsm.man.dtu.dk/wp-content/uploads/2019/01/428695_10150564469276372_763092875_n-e1547048419575.jpg?resize=150%2C150
# https://i1.wp.com/mlsm.man.dtu.dk/wp-content/uploads/2019/01/nibau-e1547046943452.png?resize=150%2C150
# https://i2.wp.com/mlsm.man.dtu.dk/wp-content/uploads/2019/01/lampros-e1547047817925.jpg?resize=150%2C150
# https://i1.wp.com/mlsm.man.dtu.dk/wp-content/uploads/2019/01/dongwoo_lee-e1547047072329.jpg?resize=150%2C150
# https://i1.wp.com/mlsm.man.dtu.dk/wp-content/uploads/2019/01/nassim-e1547046404612.jpeg?resize=140%2C140
# https://i1.wp.com/mlsm.man.dtu.dk/wp-content/uploads/2019/01/Alaska3-Yafei-Han.png?resize=150%2C150
# https://i1.wp.com/mlsm.man.dtu.dk/wp-content/uploads/2019/08/ioanna.png?resize=150%2C150
# https://i2.wp.com/mlsm.man.dtu.dk/wp-content/uploads/2019/08/renming.png?resize=150%2C150
# https://i1.wp.com/mlsm.man.dtu.dk/wp-content/uploads/2019/08/david_duran.png?resize=150%2C150
# https://i0.wp.com/mlsm.man.dtu.dk/wp-content/uploads/2019/10/vishnu_baburajan.png?resize=150%2C150
# https://i2.wp.com/mlsm.man.dtu.dk/wp-content/uploads/2019/10/mayara_moraes.png?resize=150%2C150

# %% [markdown]
# ### Weather

# %%
# Get the today temperature from 
url = "https://www.foreca.com/Denmark/Kongens_Lyngby"

# %% [markdown]
#     import urllib.request
#
#     url = "https://www.foreca.com/Denmark/Kongens_Lyngby"
#     contents = urllib.request.urlopen(url).read()
#     pq = PyQuery(contents)
#
#
#     # Here we can see multiple ways to get the same element
#
#     x = pq("div.left >span.warm.txt-xxlarge ")
#     print(x.text())
#
#     newsItems = pq("div.left")
#     x=newsItems.find("span.warm.txt-xxlarge")
#     print(x.text())
#
#     newsItems = pq("span.warm.txt-xxlarge")
#     print(newsItems.text())
#
#     newsItems = pq(".warm.txt-xxlarge")
#     print(newsItems.text())

# %% [markdown]
# ## 3. How to not get blacklisted
#
# When scraping it is possible to be blocked because website owner do not like much scrapers. Here there are some strategies to not be blocked.

# %% [markdown]
# ### 3.1 User agent
#
# One thing is to set a user-agent. User Agent is a tool that works on behalf of the user and tells the server about which web browser the user is using for visiting the website. Many websites do not let you view the content if the user-agent is not set.
# This can be easily done using the **request** package that works exatcly as **urllib.request**
#
# Try first to request the HTML page from H&M strore webpage first in the way we have seen before and, then, using User agent.

# %%
url="https://www2.hm.com/da_dk/herre/produkt/hoodies-og-sweatshirts.html"

# %%
# Non-User Agent
try:
    cntents = urllib.request.urlopen(url).read()
except:
    print("HTTP Error 403: Forbidden")
# Out:
# HTTP Error 403: Forbidden

# %%
import requests

headers = {
        'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36',
    }

# User Agent
r = requests.get(url,headers=headers)

print(r.text)
# Out:
# <!DOCTYPE HTML>
# <html lang="da" is-in-aem="false" class="no-js da-dk" ng-app="hmApp" >
#     <head>
#
#
#
# <script type="text/javascript" src="/dtagent_ICA23STVbpqr_7000100141019.js" data-dtconfig="agentUri=/dtagent_ICA23STVbpqr_7000100141019.js|rid=RID_1889581274|rpid=886243558|domain=hm.com|bandwidth=300_m|lastModification=1570150705405|lab=1|tp=500,50,0,1,10|reportUrl=dynaTraceMonitor|app=H&M Production Web"></script><script>
# var hm_deviceType="desktop";
# </script>
# <!--[if lt IE 9]>
# <link rel="stylesheet" href="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/desktop/ie8.min.css" type="text/css">
# <script type="text/javascript" src="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/desktop/ie8.min.js"></script>
# <![endif]-->
# <script type="text/javascript" src="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/jquery.min.js"></script>
# <script type="text/javascript" src="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/head.min.12.1.52.js"></script>
# <!-- to include grunticon -->
# <script>var clientlibsVersion = '.12.1.52';</script>
#    <!-- to include grunticon -->
# <link rel="stylesheet" href="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/desktop/general.min.12.1.52.css" type="text/css">
# <link rel="stylesheet" href="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/icons/svg.min.12.1.52.css" type="text/css">
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />
# 	<script type="text/javascript"></script><script src="https://cdn-pci.optimizely.com/public/2125530039/s/hm_dk.js"></script>
#     <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#
#     <meta name="viewport" content="width=1000">
#
# 	<meta name="contentPath" content="/da_dk/men/shop-by-product/hoodies-and-sweatshirts"/>
#     <meta name="keywords"/>
#     <meta name="description" content="Lækre hoodies og sweatshirts til et sporty, afslappet look. Find dine favoritter online: klassiske collegetrøjer, jakker med lynlås og hoodies."/>
#     <meta property="og:title" content="Hoodies og sweatshirts til den bedste pris | H&amp;M DK"/>
#     <meta property="og:description" content="Lækre hoodies og sweatshirts til et sporty, afslappet look. Find dine favoritter online: klassiske collegetrøjer, jakker med lynlås og hoodies."/>
# <meta property="og:site_name" content="H&amp;M">
# 	<meta property="og:type" content="website">
# 	<meta property="og:url" content="https://www2.hm.com/da_dk/herre/produkt/hoodies-og-sweatshirts.html">
#     <meta property="og:image" content="https://www2.hm.com/content/dam/courtesypageimages/down_for_maintenance.jpeg" >
# 	<meta property="fb:app_id" content="1433700643510498" >
#     <link rel="icon" type="image/vnd.microsoft.icon" href="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/resources/favicon/favicon.ico">
#     <link rel="shortcut icon" type="image/vnd.microsoft.icon" href="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/resources/favicon/favicon.ico">
# 	<link rel='stylesheet' href='https://s1-cdn.hm.com/global/hm-fonts/3.0.15/css/fonts_da_dk.css'><link rel="canonical" href="https://www2.hm.com/da_dk/herre/produkt/hoodies-og-sweatshirts.html"/>
#         		<link rel="alternate" media="only screen and (max-width: 640px)" href="https://m2.hm.com/m/da_dk/herre/produkt/hoodies-og-sweatshirts.html">
#
#     <title>Hoodies og sweatshirts til den bedste pris | H&amp;M DK</title>
# <script type="text/javascript" src="/da_dk/metrics/default/touchpoint.js"></script>
#
#
#         <meta property="og:open_graph_title"/>
# 	    <meta property="og:open_graph_description"/>
# 	    <meta property="og:open_graph_url"/>
# 	    <meta property="og:open_graph_image"/>
# 	    <meta property="og:open_graph_video"/>
#
#   <script>!function(){function o(n,i){if(n&&i)for(var r in i)i.hasOwnProperty(r)&&(void 0===n[r]?n[r]=i[r]:n[r].constructor===Object&&i[r].constructor===Object?o(n[r],i[r]):n[r]=i[r])}try{var n=decodeURIComponent("");if(n.length>0&&window.JSON&&"function"==typeof window.JSON.parse){var i=JSON.parse(n);void 0!==window.BOOMR_config?o(window.BOOMR_config,i):window.BOOMR_config=i}}catch(r){window.console&&"function"==typeof window.console.error&&console.error("mPulse: Could not parse configuration",r)}}();</script>
#   <script>!function(e){var n="https://s.go-mpulse.net/boomerang/";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,n="https://s2.go-mpulse.net/boomerang/";if(function(){function e(){if(!o){var e=document.createElement("script");e.id="boomr-scr-as",e.src=window.BOOMR.url,e.async=!0,i.parentNode.appendChild(e),o=!0}}function t(e){o=!0;var n,t,a,r,d=document,c=window;if(window.BOOMR.snippetMethod=e?"if":"i",t=function(e,n){var t=d.createElement("script");t.id=n||"boomr-if-as",t.src=window.BOOMR.url,BOOMR_lstart=(new Date).getTime(),e=e||d.body,e.appendChild(t)},!window.addEventListener&&window.attachEvent&&navigator.userAgent.match(/MSIE [67]\./))return window.BOOMR.snippetMethod="s",void t(i.parentNode,"boomr-async");a=document.createElement("IFRAME"),a.src="about:blank",a.title="",a.role="presentation",a.loading="eager",r=(a.frameElement||a).style,r.width=0,r.height=0,r.border=0,r.display="none",i.parentNode.appendChild(a);try{c=a.contentWindow,d=c.document.open()}catch(O){n=document.domain,a.src="javascript:var d=document.open();d.domain='"+n+"';void(0);",c=a.contentWindow,d=c.document.open()}if(n)d._boomrl=function(){this.domain=n,t()},d.write("<bo"+"dy onload='document._boomrl();'>");else if(c._boomrl=function(){t()},c.addEventListener)c.addEventListener("load",c._boomrl,!1);else if(c.attachEvent)c.attachEvent("onload",c._boomrl);d.close()}function a(e){window.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!window.BOOMR||!window.BOOMR.version&&!window.BOOMR.snippetExecuted){window.BOOMR=window.BOOMR||{},window.BOOMR.snippetStart=(new Date).getTime(),window.BOOMR.snippetExecuted=!0,window.BOOMR.snippetVersion=12,window.BOOMR.url=n+"EPMEN-VPFQ4-GM3WK-22BJD-TU9B7";var i=document.currentScript||document.getElementsByTagName("script")[0],o=!1,r=document.createElement("link");if(r.relList&&"function"==typeof r.relList.supports&&r.relList.supports("preload")&&"as"in r)window.BOOMR.snippetMethod="p",r.href=window.BOOMR.url,r.rel="preload",r.as="script",r.addEventListener("load",e),r.addEventListener("error",function(){t(!0)}),setTimeout(function(){if(!o)t(!0)},3e3),BOOMR_lstart=(new Date).getTime(),i.parentNode.appendChild(r);else t(!1);if(window.addEventListener)window.addEventListener("load",a,!1);else if(window.attachEvent)window.attachEvent("onload",a)}}(),"".length>0)if(e&&"performance"in e&&e.performance&&"function"==typeof e.performance.setResourceTimingBufferSize)e.performance.setResourceTimingBufferSize();!function(){if(BOOMR=e.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var n=""=="true"?1:0,t="",a="yatfusliphwgaxnf377a-f-c6613254d-clientnsv4-s.akamaihd.net",i={"ak.v":23,"ak.cp":"271055","ak.ai":parseInt("171241",10),"ak.ol":"0","ak.cr":15,"ak.ipv":4,"ak.proto":"","ak.rid":"30ff1dc8","ak.r":35163,"ak.a2":n,"ak.m":"b","ak.n":"essl","ak.bpcip":"192.38.90.0","ak.cport":1152,"ak.gh":"95.100.155.183","ak.quicv":"","ak.tlsv":"tls1.2","ak.0rtt":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1571151870"};if(""!==t)i["ak.ruds"]=t;var o={i:!1,av:function(n){var t="http.initiator";if(n&&(!n[t]||"spa_hard"===n[t]))i["ak.feo"]=void 0!==e.aFeoApplied?1:0,BOOMR.addVar(i)},rv:function(){var e=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t"];BOOMR.removeVar(e)}};BOOMR.plugins.AK={akVars:i,akDNSPreFetchDomain:a,init:function(){if(!o.i){var e=BOOMR.subscribe;e("before_beacon",o.av,null,null),e("onbeacon",o.rv,null,null),o.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script></head><body ng-controller="HmAppController" ng-class="{pre_shopping_sale_countdown:preshoppingStartingSoon}" class="subdepartment-page">
# 	<div id="abf-cover-main"></div>
# 	<div class="dictionary parbase"></div>
# <script type="text/javascript">
#
#         var hm = hm || {};
#         hm.options = hm.options || {};
#         hm.options.tealiumPageId = 'Men : Shopbyproduct : Hoodies&Sweatshirts : Viewall';
#
# </script><!-- Header -->
# <script>
#     var hm = hm || {};
#
#     (function(hm){
#
#     	hm.MultiCountry = function() {
#
#     		function readCookieValue(name) {
#
#     			var cookieAll = document.cookie.split(';'),
#     				cookieValue;
#     			if(cookieAll && cookieAll.length){
#     				cookieAll.some(function(entry){
#     					entry = entry.trim();
#     					var cookiePair = entry.split('=');
#     					if(cookiePair[0]==name){
#     						cookieValue = decodeURIComponent(cookiePair[1]);
#     						return true;
#     					}
#     				});
#     			}
#     			return cookieValue;
#     		};
#
#     		this.getCountryName = function getCountryCode(cookieName) {
#     			var cookieValue = readCookieValue(cookieName);
#     			return cookieValue;
#     		};
#
#     		this.getCountryCode = function getCountryCode(cookieName) {
#
#     			 var cookieValue = readCookieValue(cookieName),
#     				countryCode = "";
#     			if(cookieValue) {
#     				var match = /(?:^[a-z]{2}_)?([A-Z]{2})$/.exec(cookieValue);
#     				if(match) {
#     					countryCode = match[1];
#     				}
#     			}
#     			return countryCode;
#     		};
#
#     		this.getLocale = function getLocale(cookieName, language) {
#
#     		   var locale = "";
#     		   if(!language) {
#     				var cookieValue = readCookieValue(cookieName);
#     				if(cookieValue && cookieValue.search(/^[a-z]{2}_[A-Z]{2}$/) == 0) {
#     					locale = cookieValue;
#     				}
#     		   } else {
#     				var country = this.getCountryCode(cookieName);
#     				if(country.length) {
#     					locale =  language + "_" + country;
#     				}
#     		   }
#     		   return locale;
#     		};
#
#     		this.getLanguage = function getLanguage(cookieName) {
#     		   var language = this.getLocale(cookieName);
#     		   if(!language || !language.length) {
#     				return "";
#     		   }
#     		   else {
#     				return language.substring(0,2);
#     		   }
#     		};
#
#     		this.createCookie = function createCookie(cookieName, language, country) {
#     	        var d = new Date(),
#     			exdays = 182;
#     			d.setTime(d.getTime() + (exdays*24*60*60*1000));
#     			var expires = "expires="+ d.toUTCString();
#     	        var cookie = cookieName + "=" + language + "_" + country + "; " + expires + "; domain=.hm.com; path=/";
#     	        return cookie;
#     		};
#
#     	};
#
#     	hm.multiCountry = new hm.MultiCountry();
#     })(hm);
#
#
#     hm.options = hm.options || {};
#     hm.options.omnicredit = hm.options.omnicredit || {};
#     hm.options.klarna = hm.options.klarna || {};
#     var wpwlOptions = window.wpwlOptions || {};
#
#     var localeInfo ={};
#     localeInfo.locale = "da_DK";
# 	localeInfo.country = "DK";
#
#     hm.i18n = hm.i18n || {};
#
#     //MOBILEAPP INCIDENT
#     hm.options.forceUtagForAndroid = false;
#     hm.options.forceUtagForIOS = false;
#
#     hm.options.isLoyaltyMarket = 'true';
#
#     hm.options.product = {
#       removeFromCartServiceUrl: 'remove_from_cart_response.json', //why is it static? I think we should remove this hardcoded value
#       country: 'hm-denmark',
#       locale: 'da_dk', //here we put contextPath because dx team use it to create url
#       getFavoritesService: '/da_dk/favourites/productCodes',
#       addFavoriteService: '/da_dk/favourites/addItem',
#       removeFavoriteService: '/da_dk/favourites/removeItem',
# 	  addToCartServiceUrl: '/da_dk/cart/add',
# 	  esalesServicePathname: '/pra/panel/product-detail-page',
# 	  clubMemberPriceLabel: 'Medlemspris',
# 	  modelHeightGarmentSizePDPLabel: 'Modellen er {0} og har en størrelse {1} på',
# 	  sizePDPLabel: 'str.'
#     };
#
#     var productAvailabilityServiceUrl = '/hmwebservices/service/product/{site_code}/availability/{product_code}.json';
# 	var countryForAvailability = hm.options.product.locale;
# 	if(countryForAvailability.indexOf("_")>=0){
# 		countryForAvailability = hm.options.product.locale.split("_")[1];
# 	}
#     productAvailabilityServiceUrl = productAvailabilityServiceUrl.replace("{site_code}",countryForAvailability);
#     hm.options.product.productAvailabilityServiceUrl = productAvailabilityServiceUrl;
#
#     hm.options.clubSetup = {
#     		clubSetupCountry : 'hm-denmark',
#     		clubSetupTierLevelLimit : '5000',
#     		clubSetupCashBackEnabled : 'true',
#     		clubSetupAmount : '25',
#     		clubSetupCashBackCapYear : '20',
#     		clubSetupCashBackCapRolling : '5',
#     		clubSetupCashBackPoints : '1250',
#     		clubSetupRatingReviewEnabled : 'false',
#     		clubSetupRatingreview : '10',
#     		clubSetupReviewPointsCapRolling : '10'
#
#     };
#     hm.options.clubUpgrade = {
#     	confirmationMessage: 'Nu er du medlem!'
#     };
#
#     hm.options.esalesPra10 = {
#     		url: '/da_dk/pra/panel/pra10'
#     };
#
#     hm.options.praSlideNoText = {
#    		slideBulletText: '[slideNumberLabel]'
#   	};
#
#     hm.options.gdpr = {
#     	    enabled: 'false',
#     	    dateStart: '2018-05-14T00:00:00.000+02:00',
#     	    dateEnd: '2021-05-01T00:00:00.000+02:00',
#     	    url:'https://www2.hm.com/da_dk/customer-service/legal-and-privacy/privacy-link.html'
#     	  };
#
#     hm.options.orders = {
#     	    getOrders: '/mock/getOrders',
#     	    offset: '5',
#     	    missingImageUrl: '/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/resources/images/kaff.png'
#     	  };
#     hm.options.pra = {
#     		pra1: '/da_dk/pra/panel/product-detail-page', //PDP
#     	    pra6: '/da_dk/pra/panel/sub-department-page', //SDP
#    	     	pra10: '/da_dk/pra/panel/pra10', //Search
#     	   	pra11: '/da_dk/pra/panel/sale-department-page', //Sale
#     	    pra3: '/da_dk/pra/panel/shopping-bag-page', //Shopping bag
#     	    pra4: '/da_dk/pra/panel/shopping-bag-page' //Shopping bag
#          };
#     hm.options.omnicredit.isOmnicreditMarket = false;
#
#     hm.options.klarna.showAlerts = true;
#
#        hm.i18n = {
#    		 favorite: {
#    	   	        favoritesErrorText: 'Vi beklager, din vare kunne ikke flyttes til Favoritter … Prøv igen senere.',
#    	   	        addToFavoritesErrorHeading: 'Varen er ikke tilføjet til Favoritter',
#    	   	        removeFavoritesErrorHeading: 'FEJL VED SLETNING AF FAVORITTER',
#    	   	        moveToBagErrorHeading: 'Varen er ikke flyttet til din shoppingbag',
#    	   	     	moveToFavoritesErrorHeading: 'Ups … Favoritter er fuld',
#    	   	    	fullFavoritesListError: 'Vi beklager, Favoritter er fuld, og denne vare kan ikke tilføjes. Hvis du virkelig vil gemme denne vare, bedes du slette en anden vare og prøve igen.',
#    	   	        fullFavoritesListErrorHeading: 'Ups … Favoritter er fuld',
#    	   	    	activeText: 'Gemt i favoritter',
#    	  	      	inactiveText: 'Ikke gemt i favoritter'
#    	   	},
#    	 	quickbuy: {
#    	   	      viewMore: 'Vis flere',
#    	   	      add: 'TILFØJ',
#    	   	      selectSize: 'Vælg størrelse',
#    	   	      fewPiecesLeft: 'Få varer på lager',
#    	   	      soldOut: 'Udsolgt',
#     	 	  sizeGuide: 'Størrelsesguide'
#    	   	    },
#    	 	gdpr: {
# 	      	headerText: 'VI PASSER PÅ DINE PERSONLIGE OPLYSNINGER!',
#    	  		bodyText:'Dit privatliv er vigtigt for os, og derfor vil vi gerne informere dig om vores opdaterede Politik om beskyttelse af personlige oplysninger.   For at give dig mere klar og transparent information om, hvordan vi behandler dine personlige oplysninger, har vi inddelt vores Politik om beskyttelse af personlige oplysninger i forskellige afsnit. Afhængigt af om du er tilmeldt Fashion News, er H&amp;M Member eller har en H&amp;M-konto, gælder forskellige dele af politikken for dig. I hvert afsnit giver vi en nærmere beskrivelse af, hvilke personlige oplysninger vi har registreret om dig, og hvordan vi anvender dem. Vi har også tilføjet flere oplysninger om dine rettigheder, fx hvordan du får adgang til dine oplysninger, og hvordan du kan anmode om ophør af brugen af dine oplysninger.',
# 	      	linkText: 'Du kan læse vores Politik om beskyttelse af personlige oplysninger her',
# 	      	buttonText: 'OK'
#    		},
# 	    luminaires: {
# 	    		regulationText: 'Forordning (EU) nr. 874/2012',
# 	    		energyLabelling: 'ENERGIKLASSE',
# 	    		compatible: 'Til denne lampe kan lyspærer i følgende energiklasser anvendes:',
# 	    		energyDeclaration: 'ENERGIKLASSE',
# 	    		imageNumber: '874/2012'
#
# 	   	},
#     	turnTo: {
# 		    labels: {
# 		    	reviewesLabel: "ANMELDELSER",
# 		    	finishReview: "AFSLUT DENNE ANMELDELSE",
# 		    	submitReviewCTA: "SEND MIN ANMELDELSE",
# 		    	helpHeading: "Hjælp os med at rate dit seneste køb",
# 		    	greeting: "HEJ",
# 		    	shareExperienceCta: "Del din oplevelse,",
# 		    	shareExperienceCtaText: "og hjælp andre med at træffe gode beslutninger ved at rate dit seneste køb",
# 		    	productSatHeading: "Tilfredshed med varen",
# 		    	productSatText: "Fortæl os, hvor tilfreds du er med varen",
# 		    	ratingHeading: "Rating",
# 		    	sizeFitHeading: "STØRRELSE OG PASFORM",
# 		    	myProfileHeading: "Min profil",
# 		    	myProfileText: "Hjælp andre med at træffe gode valg. Fortæl dem lidt om dig selv.",
# 		    	reviewTextLong: "Hvad synes du? Om kvalitet, look, og hvordan det føles.",
# 		    	thankYouHeading: "TAK!",
# 		    	thankYouText: "Vi sætter stor pris på din feedback",
# 		    	moreReviewCta: "Dine anmeldelser betyder utroligt meget",
# 		    	moreReviewCta2: "Lad os tage en til!",
# 		    	othersLabel: "Hvad andre kunder mener baseret på",
# 		    	numberReviews: "{xx} anmeldelser",
# 		    	numberReviewsMenu: "Anmeldelser({xx})",
# 		    	numberComments: "{xx} kommentarer",
# 		    	othersHeading: "HVAD ANDRE KUNDER MENER",
# 		    	userProfileShort: 'i størrelse {size}',
# 		    	commentTitle: 'KOMMENTAR',
# 		    	commentText: 'Hvad synes du? Om kvalitet, look, og hvordan det føles.',
# 		    	basedText: "Baseret på",
# 		    	customerReviews: "kundeanmeldelser",
# 		    	boughtLabel: "Købt:",
# 		    	inSizeLabel: "i størrelse",
# 		    	aboutMeLabel: "Om mig:",
# 		    	showMoreLabel: "Vis flere",
# 		    	selectedBodyType: "{bodyType} kropstype",
# 		    	selectedSkinTone: "[skynTone]",
# 		    	selectedSkinType: "{skinType} hudtype",
# 		    	filterLabel: "[filter]",
# 		    	sortByLabel: "Sorter efter",
# 		    	sortOptionLables: [
# 		    		"Mest relevant",
# 		    		"Nyeste",
# 		    		"Mest populære",
# 		    		"Mindst populære"
# 		    	],
# 		    	reviewsDescriptionLabel: "[reviewDescription]",
# 		    	clearAllCta: "[clearAll]",
# 		    	noReviewesHeading: "[noMatchReview]",
# 		    	noReviewesText: "[noReviewText]",
# 		    	colorPurchased: "[purchasedColor]",
# 		    	sizePurchased: "[pushasedSize]",
# 		    	heightLabel: "Højde",
# 		    	bodyTypeLabel: "[bodyTypeLabel]",
# 		    	skinToneLabel: "[skinToneLabel]",
# 		    	SkinTypeLabel: "[skinTypeLabel]",
# 		    	labelAll: "Alle",
# 		    	doneCta: "[done]",
# 		    	clearCta: "[clear]",
# 		    	backCta: "Tilbage",
# 		    	unreviewedItemsPlaceholder: "De varer, du har købt, vises her, så du kan anmelde dem.",
# 		    	unreviewedItemsText: "Lad os anmelde varen!",
# 		    	itmesCount: "{x} varer",
# 		    	leaveReviewCta: "Anmeld en vare",
# 		    	gotohm: "Gå til hm.com",
# 		    	reviewHeading: "ANMELDELSE",
# 		    	shareThoughtsHeading: "DEL DIN MENING OM DENNE VARE!",
# 		    	dimensionText: "Hvad synes du? Folk taler om stil, lejlighed, og hvordan det føles.",
# 		    	ratingValidationText: "Din anmeldelse skal indeholde en rating.",
# 		    	maxLengthValidationText: "Dette er fantastisk – vi elsker lange romaner, og vi er glade for, at du er så generøs. Men for at teksten passer i anmeldelsesfeltet, skal du holde dig indenfor 5.000 tegn.",
# 		    	unfinishedReviewHeading: "Vi er virkelig glade for din anmeldelse.",
# 		    	unfinishedReviewtext: "Afslut, inden du forlader siden, ellers gemmes dine ændringer ikke.",
# 		    	unfinishedReviewCta: "JA, JEG VIL GERNE AFSLUTTE",
# 		    	unfinishedReviewExit: "AFSLUT",
# 		    	shopNowLabel: "SHOP NU",
# 		    	ratingStarTips: [
# 			    	'Dårlig',
# 			    	'Acceptabel',
# 			    	'Gennemsnitlig',
# 			    	'God',
# 			    	'Enestående'
# 			    ],
# 			    myhmReviewSection: {
# 		    		noReviewText: 'De varer, du har købt, vises her, så du kan anmelde dem.',
# 				    canReviewText: 'Du har {xx} vare(r), der venter på at blive anmeldt.',
# 					errorText: 'Serverfejl! Prøv igen senere.'
# 	        	},
# 			    headlines: {
# 			    	normal: {
# 			    	  title: "ANMELDELSER",
# 			    	  subTitle: "Fortæl os, hvad du synes om disse varer"
# 			    	  },
# 			    	validationError: {
# 			    	  title: "NÆSTEN KLAR!",
# 			    	  subTitle: "Udfyld tomme felter, inden du fortsætter:",
# 			    	  text:  "1. Tilføj rating. 2. Markér feltet ud for Vilkår og betingelser."
# 			    	},
# 			    	connectionError: {
# 			    	  title: "OH, SNAP!",
# 			    	  subTitle: "Det lader til, at du ikke kan skrive en anmeldelse i øjeblikket. Prøv igen senere. Tak for tålmodigheden!",
# 			    	  text:  "I mellemtiden kan du besøge vores butik!"
# 			    	},
# 			    	NotLoggedIn: {
# 			    	  title: "TAK!",
# 			    	  subTitle: "Dine anmeldelser betyder utroligt meget",
# 			    	  text:  ""
# 			    	},
# 			    	reviewFiltersError: {
# 			    	  title: "Beklager",
# 			    	  text: "Vi kan i øjeblikket ikke vise kommentarer om denne vare – prøv igen senere."
# 			    	},
# 			    	oldPurchasedProduct: {
# 			    	  title: "Beklager",
# 			    	  subTitle: "Varerne blev købt for mere end {x} dage siden og kan derfor ikke anmeldes.",
# 			    	  text: "Nedenfor kan du dog stadig anmelde andre varer, du har købt."
# 			    	},
# 			    	reviewError: {
# 			    	  title: "HEJ IGEN!",
# 			    	  subTitle: "DU HAR ALLEREDE ANMELDT DENNE VARE.",
# 			    	  text1: "Nedenfor kan du dog stadig anmelde andre varer, du har købt.",
# 			    	  text2: "Du kan dog altid besøge vores butik for at se, hvad der er trendy lige nu!"
# 			    	},
# 			    	start: {
# 			    	  title: "TAK!",
# 			    	  subTitle: "Dine anmeldelser betyder utroligt meget",
# 			    	},
# 			    	end: {
# 			    	  title: "DU ER BEDST!",
# 			    	  subTitle: "Dine anmeldelser betyder utroligt meget",
# 			    	},
# 			    	random: [
# 			    	  "JO MERE DESTO BEDRE!",
# 			    	  "BARE ÉN TIL!",
# 			    	  "JA! DET HER ER SUVERÆNT!",
# 			    	  "NU KØRER DET",
# 			    	  "PERFEKT!",
# 			    	  "DU STRÅLER!",
# 			    	  "MORE IS ALWAYS MORE – TAK!",
# 			    	  "DIAMANTER, DER VARER FOR EVIGT!",
# 			    	]
# 	    		},
# 	    		 pointsCommunication: {
# 	                 nonLoggedIn: {
# 	                     copy1: "Hvis du er medlem, får du dine point, når (og hvis) din bedømmelse bliver udgivet.",
# 	                     copy2: "Hvis du er medlem, får du dine point, når (og hvis) din bedømmelse bliver udgivet. Ikke medlem?{URL} Tilmeld dig nu!{/URL}",
# 	                     modalURL: 'join'
# 	                 },
# 	                 clubMember: {
# 	                     copy1: "Du får 10 point for hver vare, du bedømmer — op til 10 point per måned.",
# 	                     copy2: "Du får dine point, når (og hvis) din bedømmelse bliver udgivet.",
# 	                     copy3: "Du optjener point for hver bedømmelse!",
# 	                     copy4: "Du får dine point, når (og hvis) din bedømmelse bliver udgivet."
# 	                 },
# 	                 nonClubMember: {
# 	                     copy1: "Hvis du {URL}bliver medlem{/URL}, kan du optjene point, når du bedømmer en vare — hvis du samler point nok, modtager du en bonus til fremtidige køb.",
# 	                     copy2: "Husk at {URL}tilmelde dig{/URL} — du kan optjene point for dine bedømmelser! Hvis du samler point nok, modtager du en bonus til fremtidige køb!",
# 	                     copy3: "Vidste du, at H&amp;M Members optjener point ved at vurdere og bedømme deres onlinekøb og får 10% rabat i velkomstreward?",
# 	                     copy4: "BLIV H&amp;M-MEDLEM",
# 	                     modalURL: 'club-upgrade'
# 	                 }
# 	             },
# 		    	continueShoppingBtn: {
# 			    	text: "Fortsæt med at handle",
#                     urlLink: "/da_dk/index.html"
# 			    },
# 			    joinClubBtn: {
# 			        text: "BLIV H&amp;M-MEDLEM",
# 			        remodalTriggerId: "club-upgrade"
# 			    },
#     		},
# 		    showMoreBtn: {
# 	        	text: "Vis flere varer"
# 	      	}
#     	},
#     	notifyIfBack: {
#     		notifyMeButton: 'GIV MIG BESKED',
#     		notifyMeList: 'Giv mig besked',
# 	        outOfStock: 'Udsolgt',
# 	        moveToBag: '[moveToBag]',
# 	        modal: {
# 	          select: {
# 	            heading: 'HOLD MIG OPDATERET',
# 	            info: 'Vi sender dig en e-mail, hvis varen kommer på lager igen.',
# 	            pickSize: 'Str.',
# 	            selectSize: 'Vælg størrelse',
# 	            notify: 'VI GIVER DIG BESKED PÅ:',
# 	            disclaimer: 'Din anmodning gemmes i 3 måneder.',
# 	            button: 'GIV MIG BESKED'
# 	          },
# 	          success: {
# 	            heading: 'SÅ ER DET KLARET',
# 	            info: 'Vi sender dig en e-mail på {0}, hvis varen kommer på lager igen.',
# 	            button: 'Fortsæt med at handle'
# 	          },
# 	          error: {
# 	            heading: 'ÅH NEJ!',
# 	            info: 'Det var desværre ikke muligt at registrere din beskedanmodning.',
# 	            button: 'PRØV IGEN'
# 	          },
# 	          login: {
# 	            heading: 'Kun i dag!',
# 	            info: 'Få besked, hvis varen kommer på lager igen — det er nemt!',
# 	            text: 'Log ind og klik på &#039;Giv mig besked&#039;, så hører du fra os, hvis varen kommer på lager igen.',
# 	            button: 'Log ind/Ny kunde'
# 	          }
# 	        }
# 	      },
# 		video: {
# 			'playButtonText' : 'Afspil video',
# 			'pauseButtonText' : 'Sæt video på pause',
# 			'closeButtonText' : 'Luk video',
# 			'videoErrorTitle' : 'Ups!',
# 			'videoErrorText' : 'Vi har desværre problemer med at indlæse videoen',
# 			'videoReloadText' : 'Indlæs igen',
# 			'videoLoadingText' : 'Afspilning af video indlæses nu'
# 		},
#     	searchImgAlt: {
# 	    	washTag: 'Vaskemærke',
# 	    	priceTag: 'Prismærke'
#     	},
#     	confirm: 'OK',
# 	    general: {
# 	    	next: 'Næste',
# 	    	previous: 'Forrige',
# 	    	close: 'Luk',
# 	    	all: 'Alle',
# 	    	enableContrastMode: 'Aktivér &#034;høj kontrast&#034;',
# 	    	disableContrastMode: 'Deaktivér &#034;høj kontrast&#034;',
# 	    	hm: 'H&amp;M',
# 	    	hennes: 'Hennes &amp; Mauritz'
#     	},
#     	pdp: {
# 	    	artNo: 'Varenr.',
# 	    	soldOut: 'Udsolgt',
# 	    	fewPiecesLeft: 'Få varer på lager',
# 	    	comingSoon: 'Kommer snart',
# 	    	comingSoonButton: 'KOMMER SNART'
#     	},
#     	product: {
#     		newArrivalText: 'Nyhed'
#     	},
#     	completeRegistration: '[pleaseCompleteRegistration]',
#         giftCard: {
#         	servicedown: 'Gavekortnummeret er ugyldigt. Prøv igen.'
#         },
#         sustainability: {
#             starterButton: 'VARENS BÆREDYGTIGHED',
#             modalTitle: 'VARENS BÆREDYGTIGHED',
#             introText: 'Vi tror på, at en større gennemsigtighed kan skabe forandringer, der fører til en mere bæredygtig fremtid for modebranchen. Første skridt på vejen er, at vi deler så meget information som muligt om, hvordan vores produkter fremstilles. ',
#             introTextNoSuppliers: 'Vi tror på, at en større gennemsigtighed kan skabe forandringer, der fører til en mere bæredygtig fremtid for modebranchen. Første skridt på vejen er, at vi deler så meget information som muligt om, hvordan vores produkter fremstilles.',
#             materials: {
#               headerText: 'MATERIALER',
#               bodyText: 'Vores mål er at bruge 100% genanvendte materialer eller andre bæredygtige materialer senest i 2030.'
#             },
#             suppliers: {
#               headerText: 'VORES LEVERANDØRER',
#               bodyTextCountryList: 'Denne vare er fremstillet i et af disse lande:',
#               buttonSeeAllText: 'Her kan du se hvilke leverandører, der har fremstillet varen.',
#               introText: 'Alle vores varer er fremstillet af uafhængige leverandører, ofte i udviklingslande, hvor vores tilstedeværelse virkelig kan gøre en forskel. Vores forretning er med til at skabe arbejdspladser, særligt for kvinder — dette er med til at mindske fattigdom og bidrage til økonomisk vækst i lokalsamfundene. Vi samarbejder kun med partnere, som deler vores respekt for mennesker og miljøet og er villige til at forbedre deres praksis i samarbejde med os. Alle leverandører og fabrikker skal underskrive vores strenge Sustainability Commitment, som omfatter krav til rimelige lønninger og gode arbejdsforhold for alle. Vi ansætter dedikeret bæredygtighedspersonale i vores verdensomspændende produktion for at sikre, at vores Sustainability Commitment bliver overholdt.',
#               sorryText: 'Desværre er leverandøroplysningerne ikke tilgængelige for denne vare i øjeblikket. Vi arbejder på at kunne vise disse oplysninger for så mange H&amp;M-varer som muligt. Tak for din tålmodighed.',
#               modalTitle: 'LEVERANDØRLISTE',
#               workersAmount: 'Antal ansatte:',
#               disclaimerTop: 'Disse leverandører har fremstillet denne vare for H&amp;M. Den samme vare kan være produceret af flere forskellige leverandører.',
#               disclaimerLabelsupplierAndFactoryExplanationText: 'Vi ønsker at være transparente omkring hvordan og hvor vores varer fremstilles. Derfor gør vi disse informationer tilgængelige for alle ved hjælp af et nyt system.',
#               disclaimerLabelsupplierAndFactoryExplanationText_2: 'Hvis en vare er fremstillet, før vi begyndte at anvende vores nye system, kan vi dog ikke garantere, at alle leverandøroplysninger er tilgængelige. Vores mål er, at alle leverandøroplysninger fremadrettet skal fremgå ved alle varer.',
#               disclaimerLabelsupplierAndFactoryExplanationText_3: 'Hvis vi stopper samarbejdet med en leverandør, vil det kun være muligt at vise de seneste informationer, som vi havde på tidspunktet for samarbejdet.',
#               disclaimerLabelsupplierAndFactoryExplanationText_4: 'Tak for din tålmodighed, mens vi arbejder på at skabe større gennemsigtighed.'
#             },
#             fashionRecycler: {
#               headerText: 'BE A FASHION RECYCLER!',
#               bodyText: 'Du kan gøre en forskel for miljøet og være med til at gøre fashion mere bæredygtig. Aflever dit brugte tøj og boligtekstiler i din H&amp;M-butik, så det kan blive genbrugt, genanvendt eller genvundet.'
#             }
#           }
#    	};
#
#  hm.options.vkAppId = '5104831';
#  hm.options.baiduKey = 'swDgGnUXEsDc69fssH1PiFdMy0pqsq4y';
#  hm.options.rimd = {
# 		service: 'https://lp2.hm.com/hmgoepprod?set=width[{width}],quality[{quality}],options[limit]&source=url[{path}]&scale=width[global.width],height[15000],options[global.options]&sink=format[{ext}],quality[global.quality]',
# 		product: 'https://lp2.hm.com/hmgoepprod?source=url[{path}]&scale=width[{width}],height[{height}],options[{scale}]&sink=format[jpeg],quality[{quality}]&hmver={version}',
# 		serviceOverride: {
# 			gif: 'https://lp2.hm.com/hmgoepprod?source=url[{path}]&optimize&sink=format[{ext}]'
# 		}
# 	};
#  hm.options.googleMapApiKey = 'gme-hmhennesmauritzab';
#
#  hm.options.searchNumGuide = {
#  	    washTagImg: '/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/resources/images/tag-wash.svg',
#  	    pricetagImg: '/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared/resources/images/tag-price.svg'
#  };
#
#  hm.options.turnTo = {
# 		  enabled: true,
#  	      dateFrom: '56',
#  	      ugcSummary: '/da_dk/reviews/rrs/ugcsummary',
# 		  unreviewedPurchases: '/da_dk/reviews/rrs/unreviewed',
# 	      reviewList: '/da_dk/reviews/rrs/reviews',
# 	      createReview: '/da_dk/reviews/rrs/createreview',
# 	      reviewFormSubmission: '/da_dk/reviews/rrs/formsubmission',
#
#  	      	dimensionId: 1,
#
#  	      legal: [
#             {
#             	label: 'Jeg accepterer {URL1}vilkår og betingelser{/URL}',
#                 url1: '/da_dk/customer-service/legal-and-privacy/privacy-link.modal.html',
#              	validationText: "Godkend Vilkår og betingelser, inden du fortsætter. ",
#             	finePrint: 'De informationer, du oplyser til os, behandles i overensstemmelse med vores {URL2}politik om beskyttelse af personlige oplysninger{/URL}',
#                 url2: '/da_dk/customer-service/legal-and-privacy/reviews-terms-and-conditions.modal.html'
#             }
#  	      ]
#  	  };
#
#
#
# hm.options.truefit = {
# 	enabled: {"favorites":"true","myHM":"true","quick_buy":"false","PDP":"true"},
# 	environment: 'production',
# 	clientid: 'hms'
# };
#
# hm.options.truefit.enabled.thankyou = "true";
#
#
# hm.options.notifyIfBack = {
# 	enabled : false,
# 	apiUrl: '/da_dk/notify-back-in-stock'
# };
#
# hm.options.video = {
# 	'accountId' : '5985631876001',
# 	'playerId' : 'aKLjzHnEl'
# };
#
#  hm.options.trendingSearches = {
#     url: '/da_dk/pra/panel/top-searches',
#     errorTitle: '[trendingErrorTitle]' //This title will display icase server error but business user added link to the trending search
#   };
#
#  hm.options.ugc = {enabled: true};
#
#  hm.options.isPublishMode = true;
#
#
#  hm.options.preshopperData = {
# 	bookingsService: '/da_dk/loyalty/booking/bookings',
# 	memberService: '/da_dk/loyalty/getMember',
# 	offersService: ''
#  };
#
#  hm.options.useNewFilter = true;
#
#  hm.options.quickBuyBaseUrl = '/da_dk/productpage/_jcr_content/product.quickbuy.{{=it.articleCode}}.html';
#
#  hm.options.acceptableJoin = {};
#
#  	hm.options.acceptableJoin.popupTimes = 2;
#
#
#  hm.options.sustainability = {
#          getSuppliers: '/da_dk/supplierDetails/articles/'
#      }
#
#  $(document).ready(function(){
# 	 if(!hm.options.isPublishMode){
# 		 $('.preshopping-container').show();
# 	 }
# 	 else{
#  		$('.preshopping-container').has("article[data-preshopping-teaser=false]").show();
# 	 }
#  });
# </script><script>
# var hm_deviceType="desktop";
# </script>
# <!--AEMPUBPRDEU4P05.goep.hm.com-->
# 	<noscript>
# <div class="responsive status-message is-open notice">
#   <div class="message icon icon-banner-info-white">
#   		Velkommen! Hm.com fungerer bedst med JavaScript aktiveret. Aktivér det, og se den seneste fashion!
#   		</div>
# </div>
# </noscript><div class="warehousemessage"></div>
# <header class="header-global">
# 		<nav class="menu"  ng-init="isMobile=false;preshoppingOfferKey='';preshoppingCountdown='900000';preshoppingOfferPageUrl='';hmClubEnabled=true; timeInterval=5000; autorefreshCount=3;  offersSpace='rewardSpace'; hmClubServiceCacheDuration=5; hmRedirectPath='/da_dk/account'">
# 			<a class="hide-content focusable" href="#main-content" title="Spring over navigering">Spring over navigering</a>
# 			<a class="menu__hm" href="/da_dk/index.html">
# 				<span class="hide-content notranslate">STARTSIDE</span>
# 			</a>
# 			<button class="menu__trigger js-menu-trigger">Menu</button>
# 			<ul class="menu__session menu__session--hidden" >
# 		   		<li class="menu__session__item">
# 		   			<div class="account parbase">
# 	<a class="menu__myhm" href="#" data-remodal-trigger="signin" data-signin-state="guest">
# 		Log ind
# 	</a>
#     <a class="menu__myhm" href="/da_dk/account" data-signin-state="signedin">
# 		Mit H&amp;M
# 	</a>
# 	<div class="myhm-dropmenu" data-signin-state="guest">
#          <button class="button large" data-remodal-trigger="signin">
#             Log ind
#          </button>
#          <ul class="list">
#
#                <li class="list-item">
#                   <a class="link" href="/da_dk/account" data-remodal-trigger="signin-account">Mit H&amp;M</a>
#                </li>
#
#
#
#                <li class="list-item">
#                   <a class="link" href="/da_dk/member/info.html">Medlemsinfo</a>
#                </li>
#
#
#                <li class="list-item">
#                   <a class="link" href="#" data-remodal-trigger="join">Ikke medlem? Tilmeld dig her!</a>
#                </li>
#
#          </ul>
#     </div>
#     <div class="myhm-dropmenu" data-signin-state="signedin">
#          <ul class="list">
#
#
#                <li class="list-item">
#                   <a class="link" href="/da_dk/account">Mit H&amp;M</a>
#                </li>
#
#
#                <li class="list-item">
#                   <a class="link" href="/da_dk/member/info.html">Medlemsinfo</a>
#                </li>
#
#             	<li class="list-item">
#                   <a class="link" href="/da_dk/logout" onclick="trackLogout()">Log af</a>
#                </li>
#
#
#          </ul>
#     </div>
# </div>
# </li>
# 		   		<li class="menu__session__item">
# 			   			<button class="menu__search_toggle js-search-toggle">
# 			   				<span class="hide-content">Søg produkter</span>
# 			   			</button>
# 			   		</li>
# 		   		<li class="menu__session__item">
# 			        	<a href="/da_dk/favourites" class="menu__favorites">
# 			        		Favoritter</a>
# 			        </li>
# 		        <li class="menu__session__item shopping-bag rollover-popdown" data-cart="/da_dk/minicart/view">
# 		        	<span class="minicart parbase"><a href="/da_dk/cart" class="menu__bag goto-shopping-bag rollover-toggle">
# 	Shoppingbag(<span class="shoppingbag-item-count">0</span>)
# </a>
# <div class="shopping-bag-rollover row popdown"></div></span>
# </li>
# 			</ul><!-- /Session menu -->
# 			<div class="autosuggestsearch parbase"><section class="menu__search_wrapper ui-widget" id="search-field" aria-expanded="false">
# 		<form method="get" action="/da_dk/search-results.html" class="menu__search">
# 			<span role="status" aria-live="polite" class="ui-helper-hidden-accessible"></span>
# 				<input id="main-search" data-url="/content/hmonline/da_dk/jcr:content/header/autosuggestsearch.display.html" type="search" data-test="false" name="q" placeholder="Søg produkter" minlength="3" maxlength="200" data-autocomplete-disabled="false" class="ui-autocomplete-input menu__search_input" autocorrect="off" spellcheck="false" autocomplete="off" aria-label="Søg produkter">
# 			<button class="menu__search_submit" type="submit"><span class="hide-content">Søg produkter</span></button>
# 		</form>
# 	</section>
# </div>
# <ul class="menu__primary"><!-- Primary menu -->
#                     <li class="menu__sign-in">
#                             <a class="menu__sign-in-button" href="#" data-remodal-trigger="signin" data-signin-state="guest">Log ind</a>
# 		               		<a class="menu__sign-in-button" href="/da_dk/account" data-signin-state="signedin">Mit H&M</a>
#                         </li>
#                         <li class="menu__super menu__super--has-sub js-traverse-trigger">
#                             <a class="menu__super-link" href="/da_dk/dame.html" data-deparment-toggle-text="Toggle submenu for the Dame deparment" data-goto-text="Go to Dame home">
#                             	<span>Dame</span>
#                             </a>
#                             <button style="padding:0" class="menu__accessibility-trigger">
#                                 <span class="hide-content">Toggle submenu for the Dame deparment</span>
#                             </button>
#                             <ul class="menu__sub">
#                                     <li class="menu__title">
#                                         <button class="menu__title-button">Dame</button>
#                                     </li>
#                                        <li class="menu__block menu__block--has-sub js-traverse-trigger">
# 	        <span tabindex="0" class="menu__heading">Nyheder</span>
#             <ul class="menu__sub">
#             	<li class="menu__title">
#             		<button class="menu__title-button">Nyheder</button>
#             	</li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/nyheder/toj.html">
#                             Tøj</a>
#                     </li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/nyheder/lingerie.html">
#                             Lingeri</a>
#                     </li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/nyheder/sko-og-accessories.html">
#                             Sko og accessories</a>
#                     </li>
#                 </ul>
# 	   </li>
# 	<li class="menu__block menu__block--has-sub js-traverse-trigger">
# 	        <span tabindex="0" class="menu__heading">Trending Now</span>
#             <ul class="menu__sub">
#             	<li class="menu__title">
#             		<button class="menu__title-button">Trending Now</button>
#             	</li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/latest-trend/statement-knitwear.html">
#                             Key Knits</a>
#                     </li>
#                 </ul>
# 	   </li>
# 	<li class="menu__block menu__block--has-sub js-traverse-trigger">
# 	        <span tabindex="0" class="menu__heading">Shop efter Produkt</span>
#             <ul class="menu__sub">
#             	<li class="menu__title">
#             		<button class="menu__title-button">Shop efter Produkt</button>
#             	</li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/produkt/view-all.html">
#                             Vis alle</a>
#                     </li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/produkt/Jakker-og-frakker.html">
#                             Jakker og frakker</a>
#                     </li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/produkt/kjoler.html">
#                             Kjoler</a>
#                     </li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/produkt/toppe.html">
#                             Toppe</a>
#                     </li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/produkt/skjorter-og-bluser.html">
#                             Skjorter og bluser</a>
#                     </li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/produkt/blazere-og-veste.html">
#                             Blazere og veste</a>
#                     </li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/produkt/cardiganer-og-sweatere.html">
#                             Cardigans og strik</a>
#                     </li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/produkt/strik.html">
#                             Strik</a>
#                     </li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/produkt/hoodies-sweatshirts.html">
#                             Hoodies og sweatshirts</a>
#                     </li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/produkt/basics.html">
#                             Basics</a>
#                     </li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/produkt/bukser.html">
#                             Bukser</a>
#                     </li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/produkt/jeans.html">
#                             Jeans</a>
#                     </li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/produkt/nederdele.html">
#                             Nederdele</a>
#                     </li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/produkt/accessories.html">
#                             Accessories</a>
#                     </li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/produkt/sko.html">
#                             Sko</a>
#                     </li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/produkt/jumpsuits-playsuits.html">
#                             Jumpsuits &amp; Buksedragter</a>
#                     </li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/produkt/shorts.html">
#                             Shorts</a>
#                     </li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/produkt/lingeri.html">
#                             Lingeri</a>
#                     </li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/produkt/nattoj.html">
#                             Nattøj</a>
#                     </li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/produkt/stromper.html">
#                             Strømper</a>
#                     </li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/produkt/sportstoj.html">
#                             Sportstøj</a>
#                     </li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/produkt/badetoj.html">
#                             Badetøj</a>
#                     </li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/produkt/mama-ventetoj.html">
#                             Mama ventetøj</a>
#                     </li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/produkt/hm-plus-sizes.html">
#                             H&amp;M+ plus sizes </a>
#                     </li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/produkt/extended-sizes.html">
#                             Extended sizes</a>
#                     </li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/produkt/beauty.html">
#                             Beauty</a>
#                     </li>
#                 </ul>
# 	   </li>
# 	<li class="menu__block menu__block--has-sub js-traverse-trigger">
# 	        <span tabindex="0" class="menu__heading">Kampagner</span>
#             <ul class="menu__sub">
#             	<li class="menu__title">
#             		<button class="menu__title-button">Kampagner</button>
#             	</li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/Kampagner/1310a-pringle-of-scotland-x-hm.html">
#                             Pringle of Scotland x H&amp;M</a>
#                     </li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/Kampagner/1280-a-new-take-on-utility.html">
#                             A New Take On Utility</a>
#                     </li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/Kampagner/1330a-everyday-intimates.html">
#                             Everyday Intimates</a>
#                     </li>
#                 </ul>
# 	   </li>
# 	<li class="menu__block menu__block--has-sub js-traverse-trigger">
# 	        <span tabindex="0" class="menu__heading">Shop efter Koncept</span>
#             <ul class="menu__sub">
#             	<li class="menu__title">
#             		<button class="menu__title-button">Shop efter Koncept</button>
#             	</li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/shop-efter-koncept/trend.html">
#                             Trend</a>
#                     </li>
#                 <li class="menu__item">
#                         <a class="menu__sub-link" href="/da_dk/dame/shop-efter-koncept/modern-classic.html">
#                             Modern Classics</a>
#                     </li>
#                 <li class="menu__item">
# ...
#
#       {{?it.outOfStockText}}<div class="out-of-stock">{{=it.outOfStockText}}</div>{{?}}
# 	  {{?it.comingSoon}}<div class="coming-soon">{{=it.comingSoon}}</div>{{?}}
#     </div>
#   </article>
# </li>
#
# </script></div>
# </div>
# </div>
# 	</div>
# 	<div class="overlaycontainer parbase">
#
#
#
#
# </div>
#
# <button class="back-to-top js-back-to-top">
# 	Til toppen af siden
# </button></main><footer class="footer-global responsive"><!-- Footer -->
#         <div class="layout">
# 	<!--AEMPUBPRDEU4P04.goep.hm.com-->
#
# 	<div class="four modules footer-menu footer-content">
#
# 	        <nav class="footer-category"><h4 class="footer-heading">
# 	<button class="js-toggle-trigger toggle-button">SHOP</button>
# 	</h4>
# 	<div class="list">
# 			<div class="item"><a class="link" href="/da_dk/dame.html">Dame</a></div>
# 		            <div class="item"><a class="link" href="/da_dk/herre.html">Herre</a></div>
# 		            <div class="item"><a class="link" href="/da_dk/born.html">Børn</a></div>
# 		            <div class="item"><a class="link" href="/da_dk/home.html">H&amp;M HOME</a></div>
# 		            <div class="item"><a class="link" href="/da_dk/sale.html">Sale</a></div>
# 		            </div>
# 	</nav>
# <nav class="footer-category"><h4 class="footer-heading">
# 	<button class="js-toggle-trigger toggle-button">CORPORATE INFO</button>
# 	</h4>
# 	<div class="list">
# 			<div class="item"><a class="link" href="http://career.hm.com/content/hmcareer/da_dk.html" target="_blank">Job i H&amp;M</a></div>
# 		            <div class="item"><a class="link" href="https://hmgroup.com/about-us.html" target="_blank">Om H&amp;M Group</a></div>
# 		            <div class="item"><a class="link" href="https://hmgroup.com/sustainability.html" target="_blank">Sustainability</a></div>
# 		            <div class="item"><a class="link" href="https://about.hm.com/" target="_blank">Press</a></div>
# 		            <div class="item"><a class="link" href="https://hmgroup.com/investors.html" target="_blank">Investor relations</a></div>
# 		            <div class="item"><a class="link" href="https://hmgroup.com/about-us/corporate-governance.html" target="_blank">Corporate Governance</a></div>
# 		            </div>
# 	</nav>
# <nav class="footer-category"><h4 class="footer-heading">
# 	<button class="js-toggle-trigger toggle-button">HJÆLP</button>
# 	</h4>
# 	<div class="list">
# 			<div class="item"><a class="link" href="/da_dk/customer-service.html">Kundeservice</a></div>
# 		            <div class="item"><a class="link" href="http://www2.hm.com/da_dk/login">Min konto</a></div>
# 		            <div class="item"><a class="link" href="/da_dk/customer-service/shopping-at-hm/store-locator.html">Find butik</a></div>
# 		            <div class="item"><a class="link" href="/da_dk/customer-service/legal-and-privacy.html">Vilkår &amp; Betingelser</a></div>
# 		            <div class="item"><a class="link" href="/da_dk/customer-service/contact.html">Kontakt</a></div>
# 		            </div>
# 	</nav>
# <section class="footer-newsletter">
# 	        <div class="newsletter newslettersignupform parbase"><h4 class="footer-heading">BLIV MEDLEM NU</h4>
# <p class="text">Bliv H&M Member og få 10% rabat + fri standardlevering på dit næste køb!</p>
# <a href="/da_dk/member/info.html" class="button">LÆS MERE</a></div>
# </section>
# 	</div>
# 		<ul class="footer-social footer-content">
#         <li class="item">
# 			<a href="https://www.facebook.com/hmdenmark" target="_blank" title="Facebook" class="hidden-text icon icon-social-facebook-white">
# 			Facebook</a></li>
#         <li class="item">
# 			<a href="https://twitter.com/hmdanmark" target="_blank" title="Twitter" class="hidden-text icon icon-social-twitter-white">
# 			Twitter</a>
# 			</li>
#         <li class="item">
# 			<a href="https://www.instagram.com/hm" target="_blank" title="Instagram" class="hidden-text icon icon-social-instagram-white">
# 			Instagram</a>
# 			</li>
#         <li class="item">
# 			<a href="http://www.youtube.com/user/hennesandmauritz" title="YouTube" target="_blank" class="hidden-text icon icon-social-youtube-white">
# 			YouTube</a>
# 			</li>
#         <li class="item">
# 				<a href="https://www.pinterest.com/hm" target="_blank" title="https://www.pinterest.com/hm/" class="hidden-text icon icon-social-pinterest-white">
# 				https://www.pinterest.com/hm/</a>
# 			</li>
#         </ul>
# <div class="footer-copyright footer-content">
# 	    <p class="text">
# 			H&amp;M tilbyder mode og kvalitet til bedste pris på bæredygtig vis. Siden grundlæggelsen i 1947 har H&amp;M udviklet sig til en af verdens førende fashionvirksomheder. Indholdet på dette websted er ophavsretligt beskyttet og tilhører H &amp; M Hennes &amp; Mauritz AB.</p>
#
#
# 	    </div>
# 	<a href="/da_dk/index.html" class="footer-logotype icon icon-hm-white hidden-text">H&M</a>
#
# 	<div class="country-info"><div class="countrylanguage parbase"><a class="country-name overlay-trigger" data-layout="confirm" data-modal-scrollup="false" href="/da_dk/_jcr_content/footer/countrylanguage.changecountry.html">Danmark</a> | kr.</div>
# </div>
# 		<div data-remodal-content-id="signin" data-remodal-options="popup: true, ajaxContainer: .ajax-container, ajaxUrl:/content/hmonline/da_dk/_jcr_content/loginform.modal.html, additionalClasses: club-modal-forms">
#
#     </div>
#
#     <div data-remodal-content-id="signin-account" data-remodal-options="popup: true, ajaxContainer: .ajax-container, ajaxUrl:/content/hmonline/da_dk/_jcr_content/loginform.modal.account.html, additionalClasses: club-modal-forms">
#
#     </div>
#
# 	<div data-remodal-content-id="join" data-remodal-options="popup: true, ajaxContainer: .ajax-container, ajaxUrl:/content/hmonline/da_dk/_jcr_content/joinusform.modal.html, additionalClasses: club-modal-forms, closeAllButton: true">
#
#     </div>
#
#     <div data-remodal-content-id="club-upgrade" data-remodal-options="popup: true, hashtracking: true, additionalClasses: club-modal-forms club-upgrade-form, closeAllButton: true" class="remodal-content-wrapper">
# 		    <button class="remodal-close" data-remodal-action="closeall">Close Dialog</button>
# 		    <div class="remodal-content">
#
# <div class="hm-form">
# 	<header class="header">
# 		<h2 class="heading icon-hm-club-logo-light">BLIV H&amp;M MEMBER</h2>
# 		<p class="excerpt">Members get more!</p>
# 	</header>
# 	<form class="form js-form-clubjoin" method="POST" novalidate>
# 		<div class="content">
# 			<div class="inputwrapper required">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                            <div class="inputwrapper required">
#                                    <label class="label" for="club-dob" data-optional="(Optional)">Fødselsdato</label>
#                                    <div class="select-date">
#                                        <div class="merged-inputs">
#
#                                                <input type="tel" pattern="[0-9]*" inputmode="numeric" name="day" autocomplete="bday-day" class="input-day text-input" id="club-signin-day" placeholder="dd" size="2" maxlength="2"/>
#                                                <span class="divider">-</span>
#
#                                                <input type="tel" pattern="[0-9]*" inputmode="numeric" name="month" autocomplete="bday-month" class="input-month text-input" id="club-signin-month" placeholder="mm" size="2" maxlength="2"/>
#                                                <span class="divider">-</span>
#
#                                                <input type="tel" pattern="[0-9]*" inputmode="numeric" name="year" autocomplete="bday-year" class="input-year text-input" id="club-signin-year" placeholder="åååå" size="4" maxlength="4"/>
#
#
#                                        </div>
#                                        <input type="hidden" value="" required id="club-dob" name="birthDate" class="input-date " data-validation-required-text="Du skal indtaste en gyldig fødselsdato" data-min-age="15" data-min-age-text="Du skal være minimum {0} år for at blive H&amp;M-medlem" data-validation-minlength-text="Indtast dit fødselsår med fire cifre" data-format-text="Forkert format" data-show-text-after-this="true" data-validation-birthdate="true"/>
#                                    </div>
#                                    <div class="input-info">H&amp;M vil gerne forkæle dig lidt ekstra på din fødselsdag</div>
#                             </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				<div class="inputwrapper required full">
# 				<input class="checkbox-input" type="hidden" value="true" name="hmClubJoin"/>
# 				<input value="true" type="checkbox" class="checkbox-input" id="upgrade-create-account-fashion-news" name="hmNewsSubscription"/>
# 				<label class="checkbox-label " for="upgrade-create-account-fashion-news">
# 					Ja, send mig gerne e-mails med tilbud, fashionnyheder og særlige invitationer til SALE og events.
# 	           </label>
# 	           <p class="checkbox-description">Vil du have mere fashion direkte til din indbakke? Intet problem. Tilmeld dig vores Fashion News. Se, hvad der er hot inden for fashion, beauty og indretning. Du får desuden bonus-rewards, fødselsdagstilbud og særlige invitationer til SALE og events – direkte til din indbakke!</p>
# 			</div>
# 			<p class="text">Ved at klikke ‘Bliv medlem’ accepterer jeg <a data-remodal-trigger='terms-and-conditions' class='underline'>Vilkår og betingelser</a> for H&M Member.</p>
#      		<p class="text">For at give dig den bedste oplevelse som H&M Member behandler vi dine personoplysninger i overensstemmelse med H&M's <a data-remodal-trigger='privacy-notice' href='/da_dk/customer-service/legal-and-privacy/privacy-notice-hm-club-link.html' class='underline'>Politik om beskyttelse af personlige oplysninger</a>.</p>
# 			<button type="submit" class="button large js-submit-clubjoin">BLIV H&amp;M MEMBER</button>
#
# 			</div>
#
# 		</div>
# 	</form>
# </div>
# </div>
# 		</div>
# 		 <div data-remodal-content-id="terms-and-conditions-for-club" data-remodal-options="escape:false, popup: true, ajaxContainer: .ajax-container, ajaxUrl:/content/hmonline/da_dk/_jcr_content/clubtermsandconditions.modal.html, additionalClasses: popup-logo-header, closeButton: false" class="remodal-content-wrapper">
# 		</div>
# 	<div class="globalmodals parbase">
# 	  <div data-remodal-content-id="terms-and-conditions" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/da_dk/customer-service/club-terms-link.html, ajaxHTMLSelector:.article-contents, additionalClasses: popup-termsconditions">
#         <header class="remodal-header">
#
#         </header>
#     </div>
#     <div data-remodal-content-id="termsconditions-popup" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/da_dk/customer-service/club-terms-link.html, ajaxHTMLSelector:.article-contents, additionalClasses: popup-termsconditions">
#         <header class="remodal-header">
#
#         </header>
#     </div>
#     <div data-remodal-content-id="privacypolicy-popup" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/da_dk/customer-service/legal-and-privacy/privacy-notice-hm-club-link.modal.html, ajaxHTMLSelector:.article-contents">
#         <header class="remodal-header">
#
#         </header>
#     </div>
#     <div data-remodal-content-id="privacy-notice" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/da_dk/customer-service/legal-and-privacy/privacy-notice-hm-club-link.modal.html, ajaxHTMLSelector:.article-contents">
#         <header class="remodal-header">
#
#         </header>
#     </div>
#     <div data-remodal-content-id="privacy-policy" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/da_dk/customer-service/legal-and-privacy/privacy-link.modal.html, ajaxHTMLSelector:.article-contents, additionalClasses: popup-privacy">
#         <header class="remodal-header">
#
#         </header>
#     </div>
#     <div data-remodal-content-id="privacy-direct-marketing" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/da_dk/customer-service/legal-and-privacy/privacy-notice-direct-marketing-link.html, ajaxHTMLSelector:.article-contents">
#    <header class="remodal-header">
#    </header>
#    <div class="remodal-content"></div>
#     </div>
#     <div data-remodal-content-id="privacy-policy-fashion" data-remodal-options="popup: true, ajaxHeader: .heading, ajaxContainer: .ajax-container, ajaxUrl:/da_dk/customer-service/legal-and-privacy/privacy-notice-hm-account-link.html, ajaxHTMLSelector:.article-contents">
#         <header class="remodal-header">
#
#         </header>
#     </div>
#     <!-- Modal content for the account access   -->
# 	<div data-remodal-content-id="accountaccess-popup" data-remodal-options="ajaxUrl:/da_dk/customer-service/dontagreepage.modal.html, popup: true, additionalClasses: account-access">
# 	  <header class="remodal-header">
# 	      <h2 class="heading">
# 	      </h2>
# 	  </header>
# 	  <div class="remodal-content"></div>
# 	</div>
# </div>
# </div></footer><!-- /Footer -->
# <script type="text/javascript" src="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/shared.min.12.1.52.js"></script>
# <script type="text/javascript" src="/etc.clientlibs/settings/wcm/designs/hm/clientlibs/desktop.min.12.1.52.js"></script>
# <div class="tealiumPageviewtag pageview parbase"><script type="text/javascript">utag_data = {touchpoint : getTouchpoint() , page_id : "Men : Shopbyproduct : Hoodies&Sweatshirts : Viewall", category_id : "MEN_SHOPBYPRODUCT : HOODIES&SWEATSHIRTS_HOODIES&SWEATSHIRTS : VIEWALL_VIEW_ALL", category_path : "MEN_SHOPBYPRODUCT : HOODIES&SWEATSHIRTS_HOODIES&SWEATSHIRTS : VIEWALL_VIEW_ALL", selected_market : "DK", display_language : "da_DK", event_type  : "", customer_id : "", customer_email : "", customer_zip : "", customer_city : "", customer_state : "", customer_state : "", customer_country : "", customer_loyalty_level : "", customer_has_children : "", customer_fashion_news : "" }; utagTealiumTrack(function(a,b,c,d){var forceUtagLogic = (hm.device.iPhone() && hm.options.forceUtagForIOS) || (hm.device.android() && hm.options.forceUtagForAndroid);    if(!hm.device.app() || (hm.device.app() && forceUtagLogic ) ){a=getTealiumURL("DK");b=document;c='script';d=b.createElement(c);d.src=a;d.id='utagMainScript';d.type='text/java'+c;d.async=true;a=b.getElementsByTagName(c)[0];a.parentNode.insertBefore(d,a);}}); hm.Tracking.appPageView(utag_data);</script> </div>
# <div class="chatonline parbase">
# </div>
# <div class="nuancechat nuanceChat parbase"></div>
# <script type="text/javascript" >var _cf = _cf || []; _cf.push(['_setFsp', true]); _cf.push(['_setBm', true]); _cf.push(['_setAu', '/static/60eaa3589161785a55832b92d5bedb7']);</script><script type="text/javascript"  src="/static/60eaa3589161785a55832b92d5bedb7"></script></body></html>

# %% [markdown]
# ### 3.2 Delays
#
# When you want to make several request to the same website, a good way to mimic the human behaviour is to wait between requests. You can do that using time.sleep() and wait for a random number of seconds.

# %%
import numpy as np
import time
delay=np.random.randint(0,10)
time.sleep(delay)

# %% [markdown]
# ### 3.3 Other ways to not get blocked
#
# It exist many other trick to not get blocked. A general suggestion is to immitate as much as possible human behaviour:
# - Delays your requests;
# - Limit the amount of data downloaded at once;
# - Do not follow the same crawling pattern.
#
# It is also possible to make multiple requests using different IP, which somehow means pretenting to be different user. The sites can figure out the pattern of a certain IP or a pool of IP and simply block them. But, it is possible to buy IPs and use them to make requests. Similarly, you can rotate user agent. To do that you can use list of random User agent such as [Udger](https://udger.com/resources/ua-list).
