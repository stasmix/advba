# %% [markdown]
# *Stanislav Borysov [stabo@dtu.dk], DTU Management*
# # Advanced Business Analytics

# %% [markdown]
# ## Web Data Mining - Part 1: Social media

# %% [markdown]
# A lot of valuable data can be collected from online sources. It can be used to get insights, make predictions, etc. In this notebook, we're going to practice data collection from online sources using API. Particularly, we will collect social media data from Twitter and weather data from Weatherbit.

# %% [markdown]
# ### 1. Getting Twitter data
# *Based on https://www.toptal.com/python/twitter-data-mining-using-python*

# %% [markdown]
# **! WARNING !**
#
# **In order to make a developer account, you will need to use your email and phone number. The account can be deleted after class. However, if you do not want to use your personal data, you can go through Section 1 in the solutions notebook (Part 1 - Twitter-solutions.ipynb). After that, you can proceed with Section 2 "Twitter data analysis".**

# %% [markdown]
# #### 1.1. Creating developer account
#
# In order to use Twitter’s API, we have to create a developer account on the Twitter website.
#
# 1. Sign in or create a Twitter account and apply for a developer account at https://developer.twitter.com/.
#     1. Choose Academic / Student
#     2. You need to add and verify your phone number
#     3. Fill in the following answers:
#         1. "How will you use the Twitter API or Twitter data?": "In English, please describe how you plan to use Twitter data and/or APIs. For students and teachers, please include the name of the school, the name of the instructor and the course number (if available). The more detailed the response, the easier it is to review and approve."
#
#         > I am a student at the Technical University of Denmark. I would like to learn more about web data mining and data science. Currently, I am attending a Data Science course. I will use the data for educational purposes only in the class. The analysis involves very basic natural language processing. The collected data will not be published anywhere or displayed to anyone. No commercial use or product development is expected.
#
#         2. **"The specifics": switch to "No" everywhere.**
#     4. Accept terms and conditions
#     5. Confirm your email if asked
# 2. Create a new app
#      1. App name (required): Any name that not already taken (e.g., *testappxxx12345*)
#      2. Application description (required): *This is a test app.*
#      3. Website URL (required): (any fake website) *https://example.com*
#      4. Tell us how this app will be used (required): *This app will be used for education purposes only. No commercial use is expected. More characters to hit the 100-characters limit.*
# 3. Once your project has been created, click on the “Keys and Access Tokens” tab. You should now be able to see your consumer secret and consumer key.
#      1. Copy your API key and API secret key to the cell below.
#      2. Generate Access token and Access token secret and copy them to the cell below.

# %% [markdown]
# #### 1.2. Install tweepy
# Tweepy is a python library to make access to the Twitter data easier. You can install tweepy using several options:
# - Anaconda-Navigator: add chanel ```conda-forge```, press "update index...", search for ```tweepy```, install
# - pip: pip install tweepy

# %% [markdown]
# **For other languages, check https://developer.twitter.com/en/docs/developer-utilities/twitter-libraries.html**

# %% [markdown]
# #### 1.3. Authenticating
# Now that we have the necessary tools ready, we can start coding! The baseline of each application we’ll build today requires using Tweepy to create an API object which we can call functions with. In order to create the API object, however, we must first authenticate ourselves with our developer information.
#
# First, let’s import Tweepy and add our own authentication information.

# %%
import tweepy

# replace these values with yours
api_key = "xxxxxxxxxxxxxxxxxxxxxxxxx"
api_secret_key = "xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx"
access_token = "xxxxxxxxxxxxxxxxxxxxxxxxxxxxxx"
access_token_secret = "xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx"

# %% [markdown]
# Now it’s time to create our API object.

# %%
# Creating the authentication object
auth = tweepy.OAuthHandler(api_key, api_secret_key)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth)

# %% [markdown]
# #### 1.4. Example 1: Your Timeline
# In the first example, we’ll be pulling the ten most recent tweets from your Twitter feed. We’ll do this by using the API object’s ```home_timeline()``` function. We can then store the result in a variable, and loop through it to print the results.
#
# Hints:
# - use ```public_tweets = api.home_timeline()```
# - and then iterate through the pulled tweets
# ```
# for tweet in public_tweets:
#     ...
#     do something with the tweet (for example, print its text)
# ```
# - you can access the text of the tweet using ```tweet.text```
#
# WARNING! You won't get any results if you don't follow anyone.

# %%
# Using the API object to get tweets from your timeline, 
# and storing it in a variable called public_tweets
public_tweets = api.home_timeline()
# foreach through all tweets pulled
for tweet in public_tweets:
    # printing the text stored inside the tweet object
    print(tweet.text)
    print(80 * '-')
# Out:
# В цей день 1990 року народився Володимир Гнатуша — солдат ЗСУ 79 оамбр. Загинув 11.07.2014 біля с.Зеленопілля під ч… https://t.co/duPpsNBBJ6
# --------------------------------------------------------------------------------
# Today's Tokyo🗼 https://t.co/wlDaAiOYzw
# --------------------------------------------------------------------------------
# https://t.co/Ze7xleFqIQ
# --------------------------------------------------------------------------------
# Hamburg https://t.co/mkBrsbLYSF
# --------------------------------------------------------------------------------
# В цей день 1988 року народився Олег Шевченко - солдат ЗСУ 25 омпб 54 омбр. Загинув 23.12.2017 від кулі снайпера під… https://t.co/nGrpWUmE7X
# --------------------------------------------------------------------------------
# Understanding Renaud Laplanche’s next Upgraded act https://t.co/ig7hW7EdoU https://t.co/dAXOvdhODQ
# --------------------------------------------------------------------------------
# Enjoy the complete history of emoji, from the very first one to modern day: https://t.co/nsqHgcqM0u https://t.co/plCTMnXx98
# --------------------------------------------------------------------------------
# Ted Cruz framed Beto O’Rourke as a radical leftist, and O’Rourke made it clear that racial injustice is among his b… https://t.co/uFFqV8CW0y
# --------------------------------------------------------------------------------
# In the first half of this year, clashes between farmers and herders in Nigeria killed about 1,300, six times the nu… https://t.co/webMVmADlW
# --------------------------------------------------------------------------------
# По данным агентства, их эвакуировали в неизвестном направлении
# https://t.co/MmZ8Ta3i58
# --------------------------------------------------------------------------------
# Ученые выяснили, какое животное было самым первым на Земле. Вид появился около 560 миллионов лет назад… https://t.co/UAs1xaCpXu
# --------------------------------------------------------------------------------
# В цей день 1994 року народився Дмитро Шматко - солдат ЗСУ 72 омбр. Загинув 22.03.2017 під час обстрілу рос.окупанта… https://t.co/ECV8GbfXKn
# --------------------------------------------------------------------------------
# My money's on him using the `man` command. https://t.co/3orGiUQUgA
# --------------------------------------------------------------------------------
# NYT: Rod Rosenstein proposed taping Trump, using 25th Amendment https://t.co/xqW6M9qJRS
# --------------------------------------------------------------------------------
# https://t.co/eq0DdZ4hWO
# --------------------------------------------------------------------------------
# President Trump's upending of foreign policy has Europeans asking hard questions about the U.S.'s global role, and… https://t.co/891ITS2l1m
# --------------------------------------------------------------------------------
# Conservatives are skeptical of the New York Times’ Rod Rosenstein story https://t.co/Ibwzk9pL2M
# --------------------------------------------------------------------------------
# Ватикан і Пекін уклали історичну угоду щодо призначення єпископів https://t.co/NsiyAXmksL
# --------------------------------------------------------------------------------
# Неправильно: «теплі відчуття кохання». Правильно: «теплі почуття кохання».
# --------------------------------------------------------------------------------

# %% [markdown]
# The result should look like a bunch of random tweets, followed by the URL to the tweet itself. Following the link to the tweet will often bring you to the tweet itself.

# %% [markdown]
# #### 1.5. Example 2: Tweets from a Specific User
#
# In this example, we’ll simply pull the latest twenty tweets from a user of our choice.
#
# First, we’ll examine the Tweepy documentation at http://docs.tweepy.org/en/v3.5.0/api.html to see if a function like that exists. With a bit of research, we find that the ```user_timeline()``` function is what we’re looking for http://docs.tweepy.org/en/v3.5.0/api.html#API.user_timeline.
#
# We can see that the ```user_timeline()``` function has some useful parameters we can use, specifically id (the ID of the user) and count (the number of tweets we want to pull). Note that we can only pull a limited number of tweets per query due to the Twitter’s rate limits (15 calls every 15 minutes). See https://developer.twitter.com/en/docs/basics/rate-limiting and https://developer.twitter.com/en/docs/basics/rate-limits for further details.
#
# Let’s try to pull the latest twenty tweets from the twitter account ```NyTimes```.
#
# Hints:
# - use ```tweets = api.user_timeline(id=userName, count=tweetCount)``` and print text of the tweets using the ``for`` loop like in the previous example
# - the user name is "nytimes"

# %%
# The Twitter user who we want to get tweets from
name = "nytimes"
# Number of tweets to pull
tweetCount = 20

# Calling the user_timeline function with our parameters
tweets = api.user_timeline(id=name, count=tweetCount)

# foreach through all tweets pulled
for tweet in tweets:
    # printing the text stored inside the tweet object
    print(tweet.text)
    print(80 * '-')
# Out:
# President Trump's upending of foreign policy has Europeans asking hard questions about the U.S.'s global role, and… https://t.co/891ITS2l1m
# --------------------------------------------------------------------------------
# David Boies was one of America’s most admired lawyers. Then he represented Harvey Weinstein and Theranos. Which for… https://t.co/arrNJNY58V
# --------------------------------------------------------------------------------
# 6 times as many people in Nigeria died from clashes between herders and farmers in the first half of this year as f… https://t.co/kRcRYECa5M
# --------------------------------------------------------------------------------
# RT @NYTmag: The deafening roar of Iceland's Dettifoss waterfall.
# The crunch of lava flowing from the erupting Kilauea volcano in Hawaii.
# T…
# --------------------------------------------------------------------------------
# Pope Francis will recognize 7 bishops appointed by the Chinese government, ending a decades-old power struggle betw… https://t.co/zWxmvVKVoj
# --------------------------------------------------------------------------------
# Construction workers are addicted to opioids at nearly twice the rate for all working adults. And many addictions b… https://t.co/CQVD4c1bsw
# --------------------------------------------------------------------------------
# "It's very difficult for us to get a true sensing of the severity of the impact of the disaster," one emergency off… https://t.co/VZsQbjzptU
# --------------------------------------------------------------------------------
# Rod Rosenstein once proposed secretly taping President Trump and removing him via the 25th Amendment. Read more:… https://t.co/1FmYUfdIVG
# --------------------------------------------------------------------------------
# 12 more women say they were victims of a California couple charged with drugging and sexually assaulting women. One… https://t.co/3svZyU8O6E
# --------------------------------------------------------------------------------
# RT @sahiltner: “This is a profession for a lot of people now. And you can’t fill out a W-9 with your hacker handle.” An inside look at @def…
# --------------------------------------------------------------------------------
# This marathon runner was so fast that two of his three pacesetters had to drop out after the first 10 kilometers, w… https://t.co/FlbqZW6SRs
# --------------------------------------------------------------------------------
# Here is a simple, excellent one-pot recipe, full of rich flavor, with a sauce that you won't want to waste… https://t.co/bfIZtfCObB
# --------------------------------------------------------------------------------
# At least 24 soldiers and civilian onlookers were killed when gunmen opened fire on a military parade in a province… https://t.co/zLD8LRclOf
# --------------------------------------------------------------------------------
# The administrator of FEMA came under scrutiny for using government vehicles to commute between Washington and Hicko… https://t.co/gfSuSbHn5N
# --------------------------------------------------------------------------------
# When you come home and you just want to flop, you want a wine that is inexpensive and undemanding. Here are 20 grea… https://t.co/pNbDXoI66t
# --------------------------------------------------------------------------------
# RT @clairecm: Americans agree that there should be more women in leadership, that everyone's lives would improve and that women are as qual…
# --------------------------------------------------------------------------------
# Comcast and Fox (soon to be Disney) are settling their fight for control of Rupert Murdoch's Sky broadcasting servi… https://t.co/tPDiXY7vp0
# --------------------------------------------------------------------------------
# A detailed look at Americans' social lives online https://t.co/tPlt3FiR3D https://t.co/Uuja0wFLB4
# --------------------------------------------------------------------------------
# It’s easy to lose the larger narrative of the Trump-Russia story. Here's a detailed timeline. https://t.co/SOh2kaF8XW
# --------------------------------------------------------------------------------
# DC Universe, a new streaming platform dedicated entirely to DC Comics, offers movies, original series and more. We… https://t.co/bQAgWUeYHV
# --------------------------------------------------------------------------------

# %% [markdown]
# Some of the tweets are cut, probably, due to the old limit of 140 symbols (which is currently 280). To get full text of the tweets, you need to use the following command ```tweets = api.user_timeline(id=userName, count=tweetCount, tweet_mode='extended')```.
#
# WARNING! ```tweet.text``` is not available anymore and one needs to use ```tweet.full_text``` instead. It seems that this is not documented in the Tweepy documentation, so we'd have to figure it out ourselves by searching on the Internet.

# %%
# Calling the user_timeline function with our parameters
tweets = api.user_timeline(id=name, count=tweetCount, tweet_mode='extended')

# foreach through all tweets pulled
for tweet in tweets:
    # printing the text stored inside the tweet object
    print(tweet.full_text)
    print(80 * '-')
# Out:
# President Trump's upending of foreign policy has Europeans asking hard questions about the U.S.'s global role, and what Europe can or should do for its self-defense. https://t.co/xVEJTWDU4A
# --------------------------------------------------------------------------------
# David Boies was one of America’s most admired lawyers. Then he represented Harvey Weinstein and Theranos. Which forced him to defend … himself. https://t.co/21WbB3Gzxc
# --------------------------------------------------------------------------------
# 6 times as many people in Nigeria died from clashes between herders and farmers in the first half of this year as from the war with Boko Haram. Local leaders are trying mediation as a way to reduce conflict. https://t.co/BOMb8Vq9bs
# --------------------------------------------------------------------------------
# RT @NYTmag: The deafening roar of Iceland's Dettifoss waterfall.
# The crunch of lava flowing from the erupting Kilauea volcano in Hawaii.
# T…
# --------------------------------------------------------------------------------
# Pope Francis will recognize 7 bishops appointed by the Chinese government, ending a decades-old power struggle between China and the Vatican. https://t.co/SkdV3ogc92
# --------------------------------------------------------------------------------
# Construction workers are addicted to opioids at nearly twice the rate for all working adults. And many addictions began with a prescription for an on-the-job injury. https://t.co/9lluhJd3u4
# --------------------------------------------------------------------------------
# "It's very difficult for us to get a true sensing of the severity of the impact of the disaster," one emergency official in South Carolina said, "because the disaster is still occurring." https://t.co/goiEwe3IdI
# --------------------------------------------------------------------------------
# Rod Rosenstein once proposed secretly taping President Trump and removing him via the 25th Amendment. Read more: https://t.co/zsNd0OXEeV https://t.co/VOOvmphMtN
# --------------------------------------------------------------------------------
# 12 more women say they were victims of a California couple charged with drugging and sexually assaulting women. One suspect had hundreds of videos showing incapacitated women on his phone. https://t.co/Lsuz1DL1pk
# --------------------------------------------------------------------------------
# RT @sahiltner: “This is a profession for a lot of people now. And you can’t fill out a W-9 with your hacker handle.” An inside look at @def…
# --------------------------------------------------------------------------------
# This marathon runner was so fast that two of his three pacesetters had to drop out after the first 10 kilometers, which he covered in a jaw-dropping 29:21. Here's the week in good news. https://t.co/kQked6mA43
# --------------------------------------------------------------------------------
# Here is a simple, excellent one-pot recipe, full of rich flavor, with a sauce that you won't want to waste https://t.co/gLRC5XAJNT https://t.co/1feQQEP3hD
# --------------------------------------------------------------------------------
# At least 24 soldiers and civilian onlookers were killed when gunmen opened fire on a military parade in a province bordering Iraq. https://t.co/IROFc7JNhq
# --------------------------------------------------------------------------------
# The administrator of FEMA came under scrutiny for using government vehicles to commute between Washington and Hickory, N.C., where his wife and sons live. https://t.co/vS2wHjqKor
# --------------------------------------------------------------------------------
# When you come home and you just want to flop, you want a wine that is inexpensive and undemanding. Here are 20 great options under $20. https://t.co/MT7Fi4MOMU
# --------------------------------------------------------------------------------
# RT @clairecm: Americans agree that there should be more women in leadership, that everyone's lives would improve and that women are as qual…
# --------------------------------------------------------------------------------
# Comcast and Fox (soon to be Disney) are settling their fight for control of Rupert Murdoch's Sky broadcasting service in an auction this weekend. Here's how that works. https://t.co/rNYfmDXcNU
# --------------------------------------------------------------------------------
# A detailed look at Americans' social lives online https://t.co/tPlt3FiR3D https://t.co/Uuja0wFLB4
# --------------------------------------------------------------------------------
# It’s easy to lose the larger narrative of the Trump-Russia story. Here's a detailed timeline. https://t.co/SOh2kaF8XW
# --------------------------------------------------------------------------------
# DC Universe, a new streaming platform dedicated entirely to DC Comics, offers movies, original series and more. We dug through it to find the best of what's offered. https://t.co/Iu01TlYNpB
# --------------------------------------------------------------------------------

# %% [markdown]
# Popular applications of this type of data can include:
#
# - Running analysis on specific users, and how they interact with the world
# - Finding Twitter influencers and analyzing their follower trends and interactions
# - Monitoring the changes in the followers of a user

# %% [markdown]
# #### 1.6. Example 3: Finding Tweets Using a Keyword
#
# Let’s do one last example: Getting the most recent tweets that contain a keyword. This can be extremely useful if you want to monitor specifically mentioned topics in the Twitter world, or even to see how your business is getting mentioned. Let’s say we want to see how Twitter’s been mentioning Tesla.
#
# After looking through the Tweepy documentation, the ```search()``` function seems to be the best tool to accomplish our goal http://docs.tweepy.org/en/v3.5.0/api.html#API.search.
#
# The most important parameter here is ```q``` - the query parameter, which is the keyword we’re searching for. We can also set the language parameter so we don’t get any tweets from an unwanted language. Let’s only return English (“en”) tweets.
#
# We can now modify our code to reflect the changes we want to make. We first create variables to store our parameters (query and language), and then call the function via the API object. Let’s also print the screen name of the user that created the tweet in our loop.
#
# Hints:
# - use ```tweets = api.search(q=query, lang=language, tweet_mode='extended')``` to get the tweets
# - the query word is "tesla" and laguage is "en"
# - to access the name of a user, use ```tweet.user.screen_name```

# %%
# The search term you want to find
query = "tesla"
# Language code (follows ISO 639-1 standards)
language = "en"

# Calling the user_timeline function with our parameters
tweets = api.search(q=query, lang=language, tweet_mode='extended')

# foreach through all tweets pulled
for tweet in tweets:
    # printing the text stored inside the tweet object
    print(tweet.user.screen_name, "tweeted:", tweet.full_text)
    print(80 * '-')
# Out:
# RyanCaveman tweeted: @lizzie363 @reicurran @RickAnderson That research was flawed and debunked by Popular Mechanics: https://t.co/YcHd9Oegdg
# --------------------------------------------------------------------------------
# timremedy tweeted: RT @chrisccollins: Here's a @Tesla spec ad I cut for fun. @elonmusk @TeslaMotorsClub @SpaceX #tesla #specad #elonmusk #spacex https://t.co/…
# --------------------------------------------------------------------------------
# queenrende tweeted: I am from Delaware and therefore one of the least aggressive drivers in the tri-state area, but let me tell you I have never come closer to giving someone the finger than that dude today making rude gestures to me in a Tesla with the vanity plate: PROFESLA
# --------------------------------------------------------------------------------
# Shad_DaGod tweeted: She say GOD leave it all 🔛 #TESLA #CITYOFGOD ‼️🌃 @ City of God https://t.co/RlPLjk0JRg
# --------------------------------------------------------------------------------
# chihrig tweeted: A really good looking all-electric SUV hitting the market next year. So many long-range battery choices popping up. Not sure which one I’m going to get! 🤤2019 Audi E-Tron SUV- Consumer Reports https://t.co/22vhAa9adR
# --------------------------------------------------------------------------------
# MikePapoutsidis tweeted: RT @elonmusk: Tesla piece on the physics of car safety coming soon for those interested in technical details
# --------------------------------------------------------------------------------
# etrussell1 tweeted: @Aardvarkadillo @elonmusk @Tesla Thanks for the tip!
# --------------------------------------------------------------------------------
# riddlejT4 tweeted: @lazygetter @GerberKawasaki Maybe the most obvious example yet of Tesla's cult-like status
# --------------------------------------------------------------------------------
# AutoGlassDallas tweeted: RT @TeslaMotrsports: What do y’all think of this?🔌🔋 #Tesla https://t.co/aKLbVnLEoy
# --------------------------------------------------------------------------------
# Electric_circuz tweeted: #nowplaying  Hang Tough by Tesla Download the Live365 app and listen to us #np #music #rock #radio https://t.co/bGj7YGKxVq https://t.co/MMlv0lXhzn
# --------------------------------------------------------------------------------
# champagneaugust tweeted: RT @spectatorindex: Years in existence.
#
# Snapchat: 7
# Uber: 9
# Twitter: 12
# Facebook: 14
# Tesla: 15
# Google: 20
# Netflix: 21
# Amazon: 24
# Apple: 42…
# --------------------------------------------------------------------------------
# daverandLA tweeted: @GerberKawasaki Genius move for a company destined to be "medium-sized" at best; according to @mattdebord in this @businessinsider piece: https://t.co/mOYVojH4an The only thing medium about this company is, well, ...nothing!
# --------------------------------------------------------------------------------
# tedhu tweeted: Listen to the crazy sound of Tesla Semi electric truck prototype accelerating with a trailer https://t.co/pjB6OzOgzX
# --------------------------------------------------------------------------------
# elodioxygene_ tweeted: RT @GoldfieldMike: Tesla roadster in white, this really is the future https://t.co/KWVoC36sjk
# --------------------------------------------------------------------------------
# rich_teer tweeted: RT @chrisccollins: Here's a @Tesla spec ad I cut for fun. @elonmusk @TeslaMotorsClub @SpaceX #tesla #specad #elonmusk #spacex https://t.co/…
# --------------------------------------------------------------------------------

# %% [markdown]
# Here are some practical ways you can use this information:
#
# - Create a spatial graph on where your company is mentioned the most around the world
# - Run sentiment analysis on tweets to see if the overall opinion of your company is positive or negative
# - Create social graphs of the most popular users that tweet about your company or product
# - Estimate popularity of an event (e.g. sports game, music concert) to analyze its impact on a public transport system

# %% [markdown]
# #### 1.7. The JSON behind the results
#
# In the examples above, we printed the text from each tweet using ```tweet.text``` or ```tweet.full_text```. To refer to specific attributes of each tweet object, we have to look at the JSON returned by the Twitter API.
#
# The result you receive from the Twitter API is in a JSON format and has quite an amount of information attached. For simplicity, this lecture mainly focuses on the ```full_text``` attribute of each tweet and information about the tweeter (the user that created the tweet). For the above sample, you can see the entire returned JSON object here: https://developer.twitter.com/en/docs/api-reference-index.
#
# Here’s a quick look at some attributes a tweet has to offer. To access the JSON behind each tweet, we can use ```tweet._json```. To print this dictionary, another function called ```pprint``` can be helpful:
# >```
# from pprint import pprint
# pprint(tweet._json)
# ```
#
# Print JSON of the first tweet using this function.

# %%
from pprint import pprint
tweet = tweets[0]
pprint(tweet._json)
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sat Sep 22 16:55:00 +0000 2018',
#  'display_text_range': [36, 119],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [{'display_url': 'popularmechanics.com/cars/hybrid-el…',
#                         'expanded_url': 'https://www.popularmechanics.com/cars/hybrid-electric/news/a27039/tesla-battery-emissions-study-fake-news/',
#                         'indices': [96, 119],
#                         'url': 'https://t.co/YcHd9Oegdg'}],
#               'user_mentions': [{'id': 128174162,
#                                  'id_str': '128174162',
#                                  'indices': [0, 10],
#                                  'name': 'Lizzy',
#                                  'screen_name': 'lizzie363'},
#                                 {'id': 4192414240,
#                                  'id_str': '4192414240',
#                                  'indices': [11, 21],
#                                  'name': 'Rachel Curran',
#                                  'screen_name': 'reicurran'},
#                                 {'id': 16747307,
#                                  'id_str': '16747307',
#                                  'indices': [22, 35],
#                                  'name': 'Rick Anderson',
#                                  'screen_name': 'RickAnderson'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'full_text': '@lizzie363 @reicurran @RickAnderson That research was flawed '
#               'and debunked by Popular Mechanics: https://t.co/YcHd9Oegdg',
#  'geo': None,
#  'id': 1043544202892771329,
#  'id_str': '1043544202892771329',
#  'in_reply_to_screen_name': 'lizzie363',
#  'in_reply_to_status_id': 1043542199596548096,
#  'in_reply_to_status_id_str': '1043542199596548096',
#  'in_reply_to_user_id': 128174162,
#  'in_reply_to_user_id_str': '128174162',
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://www.tweetcaster.com" rel="nofollow">TweetCaster '
#            'for Android</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Fri Apr 03 18:22:51 +0000 2009',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': 'Husband; Father; Realtor/Co-Owner/Dir of Sales at '
#                          'The Cave Realty Team, Keller Williams Realty; '
#                          'Business coach, speaker & talent scout; '
#                          'https://t.co/bSuJWsPb7W instructor.',
#           'entities': {'description': {'urls': [{'display_url': 'KWKC.org',
#                                                  'expanded_url': 'http://KWKC.org',
#                                                  'indices': [136, 159],
#                                                  'url': 'https://t.co/bSuJWsPb7W'}]},
#                        'url': {'urls': [{'display_url': 'CaveRealty.com',
#                                          'expanded_url': 'http://www.CaveRealty.com',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/4hXnduDsD3'}]}},
#           'favourites_count': 5,
#           'follow_request_sent': False,
#           'followers_count': 107,
#           'following': False,
#           'friends_count': 100,
#           'geo_enabled': False,
#           'has_extended_profile': False,
#           'id': 28621751,
#           'id_str': '28621751',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 6,
#           'location': 'North Texas',
#           'name': 'Ryan Cave',
#           'notifications': False,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/28621751/1520182600',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/970343153814441986/rN-8MweX_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/970343153814441986/rN-8MweX_normal.jpg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'RyanCaveman',
#           'statuses_count': 476,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/4hXnduDsD3',
#           'utc_offset': None,
#           'verified': False}}

# %% [markdown]
# Each tweet contains a lot of data! Read the Twitter docs if you want to understand it better.
#
# The JSON is represented by a dictionary in Python. For example, if you wanted to find the date the tweet was created, you would query it with ```tweet._json['created_at']```

# %%
print(tweet._json['created_at'])
# Out:
# Sat Sep 22 16:55:00 +0000 2018

# %% [markdown]
# #### 1.8. Saving data into a JSON file

# %% [markdown]
# Let's save the retrieved tweets to a JSON file for further analysis.
#
# **Rule of thumb: It's better to save more (redundant at the first glance) data rather than collect the missing data later.**
#
# To work with the JSON data, we will use the ```json``` package. First, ```import json```

# %%
import json

# %% [markdown]
# Now, we are ready to save the data. We want the following format: each line in the file should be a JSON string.
#
# Hints:
# - to write one line to a file, one can use
# ```
# outfile = open(file_name, 'w')
# outfile.write(string_to_write + '\n')
# # remember to include the end of line character
# outfile.close()
# ```
# - use a loop after ```open``` (and before ```close```) to write multiple lines
# - to convert a json dictionary into a string, use ```json.dumps(tweet._json)```

# %%
outfile = open('tesla_tweets.txt', 'w')
for tweet in tweets:
    outfile.write(json.dumps(tweet._json) + '\n')
outfile.close()

# %% [markdown]
# Now check the number of lines in the file to make sure that it contains the correct number of tweets.
#
# Hint: Open the file, read the lines and find their number

# %%
infile = open('tesla_tweets.txt')
lines = infile.readlines()
print(len(lines))
infile.close()
# Out:
# 15

# %% [markdown]
# To collect the data to be used in this class, the following script was used. The script is given for the reference. Please do not run it as you might exceed the Twitter limits.

# %% [raw]
# # The search term you want to find
# query = "tesla"
# # Language code (follows ISO 639-1 standards)
# language = "en"
# max_tweets = 1000
#
# searched_tweets = []
# last_id = -1
# while len(searched_tweets) < max_tweets:
#     count = max_tweets - len(searched_tweets)
#     try:
#         new_tweets = api.search(q=query, count=count, lang=language,
#                                 max_id=str(last_id - 1), tweet_mode='extended')
#         if not new_tweets:
#             break
#         searched_tweets.extend(new_tweets)
#         last_id = new_tweets[-1].id
#     except tweepy.TweepError as e:
#         # depending on TweepError.code, one may want to retry or wait
#         # to keep things simple, we will give up on an error
#         print("Error")
#         break
#
# with open('tesla_tweets_1000.txt', 'w') as outfile:
#     for tweet in searched_tweets:
#         outfile.write(json.dumps(tweet._json) + '\n')
#
# print(len(searched_tweets))

# %% [markdown]
# ### 2. Twitter data analysis
# *Based on https://www.coursera.org/specializations/jhu-data-science*

# %% [markdown]
# #### 2.1. Load the data

# %% [markdown]
# Load the JSON data from 'tesla_tweets_1000.txt' into a list of JSON dictionaries and print the number of tweets and the first tweet.
#
# Hints:
# - the file has the following structure, where each line contains a string representation of a JSON dictionary, which you need to parse:
#
# > {...}\n
#
# > {...}\n
#
# > {...}\n
#
# > ...
#
# - use ```json.loads(string)``` to parse the string into a json dictionary
# - use ```pprint``` instead of ```print``` to get 'pretty' formatting

# %%
tweets = []
infile = open('tesla_tweets_1000.txt')
for line in infile.readlines():
    tweets.append(json.loads(line))
infile.close()
print(len(tweets))
pprint(tweets[0])
# Out:
# 1000
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sun Sep 23 06:55:47 +0000 2018',
#  'display_text_range': [0, 140],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 759251,
#                                  'id_str': '759251',
#                                  'indices': [3, 7],
#                                  'name': 'CNN',
#                                  'screen_name': 'CNN'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'full_text': 'RT @CNN: A garage in California is outfitting vintage cars with '
#               'state-of-the-art tech, swapping old electronics with Tesla '
#               'batteries and el…',
#  'geo': None,
#  'id': 1043755791574949888,
#  'id_str': '1043755791574949888',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'place': None,
#  'retweet_count': 98,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#                       'coordinates': None,
#                       'created_at': 'Sun Sep 23 06:31:00 +0000 2018',
#                       'display_text_range': [0, 168],
#                       'entities': {'hashtags': [],
#                                    'media': [{'display_url': 'pic.twitter.com/sk9FquMnac',
#                                               'expanded_url': 'https://twitter.com/CNN/status/1043749554368081920/video/1',
#                                               'id': 1042467234801704961,
#                                               'id_str': '1042467234801704961',
#                                               'indices': [169, 192],
#                                               'media_url': 'http://pbs.twimg.com/media/DneXYrlXoAICaw0.jpg',
#                                               'media_url_https': 'https://pbs.twimg.com/media/DneXYrlXoAICaw0.jpg',
#                                               'sizes': {'large': {'h': 1242,
#                                                                   'resize': 'fit',
#                                                                   'w': 1400},
#                                                         'medium': {'h': 1065,
#                                                                    'resize': 'fit',
#                                                                    'w': 1200},
#                                                         'small': {'h': 603,
#                                                                   'resize': 'fit',
#                                                                   'w': 680},
#                                                         'thumb': {'h': 150,
#                                                                   'resize': 'crop',
#                                                                   'w': 150}},
#                                               'source_user_id': 16184358,
#                                               'source_user_id_str': '16184358',
#                                               'type': 'photo',
#                                               'url': 'https://t.co/sk9FquMnac'}],
#                                    'symbols': [],
#                                    'urls': [{'display_url': 'cnn.it/2QJjTe8',
#                                              'expanded_url': 'https://cnn.it/2QJjTe8',
#                                              'indices': [145, 168],
#                                              'url': 'https://t.co/zK43yZ3cZ0'}],
#                                    'user_mentions': []},
#                       'extended_entities': {'media': [{'additional_media_info': {'description': '',
#                                                                                  'embeddable': True,
#                                                                                  'monetizable': True,
#                                                                                  'title': ''},
#                                                        'display_url': 'pic.twitter.com/sk9FquMnac',
#                                                        'expanded_url': 'https://twitter.com/CNN/status/1043749554368081920/video/1',
#                                                        'id': 1042467234801704961,
#                                                        'id_str': '1042467234801704961',
#                                                        'indices': [169, 192],
#                                                        'media_url': 'http://pbs.twimg.com/media/DneXYrlXoAICaw0.jpg',
#                                                        'media_url_https': 'https://pbs.twimg.com/media/DneXYrlXoAICaw0.jpg',
#                                                        'sizes': {'large': {'h': 1242,
#                                                                            'resize': 'fit',
#                                                                            'w': 1400},
#                                                                  'medium': {'h': 1065,
#                                                                             'resize': 'fit',
#                                                                             'w': 1200},
#                                                                  'small': {'h': 603,
#                                                                            'resize': 'fit',
#                                                                            'w': 680},
#                                                                  'thumb': {'h': 150,
#                                                                            'resize': 'crop',
#                                                                            'w': 150}},
#                                                        'source_user_id': 16184358,
#                                                        'source_user_id_str': '16184358',
#                                                        'type': 'video',
#                                                        'url': 'https://t.co/sk9FquMnac',
#                                                        'video_info': {'aspect_ratio': [1,
#                                                                                        1],
#                                                                       'duration_millis': 199700,
#                                                                       'variants': [{'bitrate': 832000,
#                                                                                     'content_type': 'video/mp4',
#                                                                                     'url': 'https://video.twimg.com/amplify_video/1042467234801704961/vid/480x480/IKKJhj8GQlXBCg83.mp4?tag=8'},
#                                                                                    {'bitrate': 1280000,
#                                                                                     'content_type': 'video/mp4',
#                                                                                     'url': 'https://video.twimg.com/amplify_video/1042467234801704961/vid/720x720/KUeNTw2ezvdWypGe.mp4?tag=8'},
#                                                                                    {'content_type': 'application/x-mpegURL',
#                                                                                     'url': 'https://video.twimg.com/amplify_video/1042467234801704961/pl/Gb121PrU_pGNqU0k.m3u8?tag=8'},
#                                                                                    {'bitrate': 288000,
#                                                                                     'content_type': 'video/mp4',
#                                                                                     'url': 'https://video.twimg.com/amplify_video/1042467234801704961/vid/240x240/Ws1OHCM0sAdhc4cj.mp4?tag=8'}]}}]},
#                       'favorite_count': 252,
#                       'favorited': False,
#                       'full_text': 'A garage in California is outfitting '
#                                    'vintage cars with state-of-the-art tech, '
#                                    'swapping old electronics with Tesla '
#                                    'batteries and electric engines '
#                                    'https://t.co/zK43yZ3cZ0 '
#                                    'https://t.co/sk9FquMnac',
#                       'geo': None,
#                       'id': 1043749554368081920,
#                       'id_str': '1043749554368081920',
#                       'in_reply_to_screen_name': None,
#                       'in_reply_to_status_id': None,
#                       'in_reply_to_status_id_str': None,
#                       'in_reply_to_user_id': None,
#                       'in_reply_to_user_id_str': None,
#                       'is_quote_status': False,
#                       'lang': 'en',
#                       'metadata': {'iso_language_code': 'en',
#                                    'result_type': 'recent'},
#                       'place': None,
#                       'possibly_sensitive': False,
#                       'retweet_count': 98,
#                       'retweeted': False,
#                       'source': '<a href="https://studio.twitter.com" '
#                                 'rel="nofollow">Media Studio</a>',
#                       'truncated': False,
#                       'user': {'contributors_enabled': False,
#                                'created_at': 'Fri Feb 09 00:35:02 +0000 2007',
#                                'default_profile': False,
#                                'default_profile_image': False,
#                                'description': 'It’s our job to #GoThere & tell '
#                                               'the most difficult stories. '
#                                               'Join us! For more breaking news '
#                                               'updates follow @CNNBRK  & '
#                                               'Download our app '
#                                               '📲https://t.co/Xgo5kjIt8c',
#                                'entities': {'description': {'urls': [{'display_url': 'cnn.it/apps',
#                                                                       'expanded_url': 'http://cnn.it/apps',
#                                                                       'indices': [136,
#                                                                                   159],
#                                                                       'url': 'https://t.co/Xgo5kjIt8c'}]},
#                                             'url': {'urls': [{'display_url': 'cnn.com',
#                                                               'expanded_url': 'http://www.cnn.com',
#                                                               'indices': [0,
#                                                                           22],
#                                                               'url': 'http://t.co/IaghNW8Xm2'}]}},
#                                'favourites_count': 1453,
#                                'follow_request_sent': False,
#                                'followers_count': 40415296,
#                                'following': False,
#                                'friends_count': 1116,
#                                'geo_enabled': True,
#                                'has_extended_profile': False,
#                                'id': 759251,
#                                'id_str': '759251',
#                                'is_translation_enabled': True,
#                                'is_translator': False,
#                                'lang': 'en',
#                                'listed_count': 134845,
#                                'location': '',
#                                'name': 'CNN',
#                                'notifications': False,
#                                'profile_background_color': '323232',
#                                'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                                'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                                'profile_background_tile': False,
#                                'profile_banner_url': 'https://pbs.twimg.com/profile_banners/759251/1508752874',
#                                'profile_image_url': 'http://pbs.twimg.com/profile_images/508960761826131968/LnvhR8ED_normal.png',
#                                'profile_image_url_https': 'https://pbs.twimg.com/profile_images/508960761826131968/LnvhR8ED_normal.png',
#                                'profile_link_color': '004287',
#                                'profile_sidebar_border_color': '000000',
#                                'profile_sidebar_fill_color': 'EEEEEE',
#                                'profile_text_color': '000000',
#                                'profile_use_background_image': False,
#                                'protected': False,
#                                'screen_name': 'CNN',
#                                'statuses_count': 203604,
#                                'time_zone': None,
#                                'translator_type': 'regular',
#                                'url': 'http://t.co/IaghNW8Xm2',
#                                'utc_offset': None,
#                                'verified': True}},
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Mon Jul 29 23:20:29 +0000 2013',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': '',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 17610,
#           'follow_request_sent': False,
#           'followers_count': 1135,
#           'following': False,
#           'friends_count': 2871,
#           'geo_enabled': False,
#           'has_extended_profile': False,
#           'id': 1631492510,
#           'id_str': '1631492510',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 174,
#           'location': '',
#           'name': 'Joshua Herold',
#           'notifications': False,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/522293396938194944/orblMOvJ_normal.jpeg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/522293396938194944/orblMOvJ_normal.jpeg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'HeroldJh',
#           'statuses_count': 86683,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}

# %% [markdown]
# Now print creation time, username and text for the first 10 tweets. To print each tweet, it's convenient to define a new function.

# %%
def print_tweet(tweet):
    print(tweet['created_at'], tweet['user']['name'], tweet['full_text'])
    print(80 * '-')

# %%
n_tweets_to_print = 10
for tweet in tweets[:n_tweets_to_print]:
    print_tweet(tweet)
# Out:
# Sun Sep 23 06:55:47 +0000 2018 Joshua Herold RT @CNN: A garage in California is outfitting vintage cars with state-of-the-art tech, swapping old electronics with Tesla batteries and el…
# --------------------------------------------------------------------------------
# Sun Sep 23 06:55:31 +0000 2018 🇮🇳 Nation 1st 🕉🚩 RT @Tweeter_wapsi: If I can make a car, can I make a Tesla as well?
#
# To make it simple for DUMBTARDS:
#
# Dassault said they are fine if Govt…
# --------------------------------------------------------------------------------
# Sun Sep 23 06:55:30 +0000 2018 TSLA_opinion Tesla family welcoming new family members. So much love... 😃😘 #Tesla $Tsla @elonmusk https://t.co/5LQMqqy5nT
# --------------------------------------------------------------------------------
# Sun Sep 23 06:55:25 +0000 2018 hännåh My Lyft driver pulled up in a mf TESLA and I was like “oooOooOoo you fancy” and he laughed for like 5 minutes 😂
# --------------------------------------------------------------------------------
# Sun Sep 23 06:55:16 +0000 2018 Ivanoiu Paul Hello. I saw the Tesla semi electric truck with the trailer and I think you should add some batteries to the trailer too. You would be able to run the truck for at least 1000 miles and Tesla will be able to sell not just trucks but also trailers. What do you think? @elonmusk
# --------------------------------------------------------------------------------
# Sun Sep 23 06:55:09 +0000 2018 Forever Transformed Have checked out the #Tesla showroom #3rdstreetpromenade #dantamonica in the past.
#
# Today was the first time I sat IN a Tesla and really looked it over. Universe, I am… https://t.co/rjNUZEMfSR
# --------------------------------------------------------------------------------
# Sun Sep 23 06:55:04 +0000 2018 EcoVehicleExchange German competitors own electric cars in catch-up race against Tesla - Arab News https://t.co/eQBF3a6mcf https://t.co/24n5yDuLhY
# --------------------------------------------------------------------------------
# Sun Sep 23 06:55:02 +0000 2018 letrouduQ RT @GoldfieldMike: Tesla roadster in white, this really is the future https://t.co/KWVoC36sjk
# --------------------------------------------------------------------------------
# Sun Sep 23 06:54:46 +0000 2018 I'm Andy  RT @harijay: Was great to meet @elonmusk  at the Tesla Delivery hub in Fremont today. https://t.co/ndWjf8gJfb
# --------------------------------------------------------------------------------
# Sun Sep 23 06:54:41 +0000 2018 Kaan Adsiz🏆 RT @CNN: A garage in California is outfitting vintage cars with state-of-the-art tech, swapping old electronics with Tesla batteries and el…
# --------------------------------------------------------------------------------

# %% [markdown]
# #### 2.2. Derive the sentiment of each tweet

# %% [markdown]
# In this task, you'll compute the sentiment of each tweet based on the sentiment scores of the terms in the tweet. For the simplicity, we assume that the sentiment of a tweet is equivalent to the sum of the sentiment scores for each term in the tweet.
#
# The file AFINN-111.txt contains a list of pre-computed sentiment scores. Each line in the file contains a word or phrase followed by a sentiment score. For example,
# >catastrophic	-4
#
# >breathtaking	5
#
# Each word or phrase that is found in a tweet but not found in AFINN-111.txt should be given a sentiment score of 0. See the file AFINN-README.txt for more information.
#
# To use the data in the AFINN-111.txt file, you may find it useful to build a dictionary. The dictionary should have the following format: ```sent_dictionary={'term': score}```. Note that the AFINN-111.txt file format is tab-delimited, meaning that the term and the score are separated by a tab character. A tab character can be identified a "\t".

# %%
def build_sent_dictionary(sent_filename):
    # initialize an empty dictionary
    sent_dictionary = {} 
    afinnfile = open(sent_filename)
    for line in afinnfile:
        # The file is tab-delimited. "\t" means "tab character"
        term, score  = line.split("\t")  
        # Convert the score to an integer.
        sent_dictionary[term] = int(score)
    afinnfile.close()  
    # Print every (term, score) pair in the dictionary
    #print sent_dictionary.items() 
    return sent_dictionary

# %% [markdown]
# Now, let's write a function to rate sentiments of the tweets. To parse the text of each tweet and get a list of words, the following code might be useful:
#
# ```
# import string
# words = [word.strip(string.punctuation) for word in text.split()]
# ```
#
# Here, ```word.strip(string.punctuation)``` is used to remove punctuation from each word.

# %%
import string

def rate_sentiments(tweets, sent_dictionary):
    scores = []
    for tweet in tweets:
        score = 0
        words = [word.strip(string.punctuation) for word in tweet['full_text'].split()]
        for word in words:
            if word in sent_dictionary: 
                score += sent_dictionary[word]
        scores.append(score)
    return scores

# %% [markdown]
# Now, use the functions to build the dictionary and get a list of scores for each tweet.

# %%
sent_dictionary = build_sent_dictionary('AFINN-111.txt')
scores = rate_sentiments(tweets, sent_dictionary)

# %% [markdown]
# Let's take a closer look at the scores. First, we can plot a histogram.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline   

n, bins, patches=plt.hist(scores, bins=10)
plt.ylabel("frequency")
plt.xlabel("score")
plt.show()

# %% [markdown]
# What insights can be got from it? Let's also calculate and print a mean score of all tweets.

# %%
import numpy as np
print(np.mean(scores))
# Out:
# 0.651

# %% [markdown]
# It's slightly positive! The time series of mean scores can be used, for example, to predict the stock price of a company. Can you come up with the other possible applications of the sentiment scores?

# %% [markdown]
# Let's check now the top 10 positive and 10 negative tweets.
#
# Hint: To get indices of the tweets when sorting the list of scores, you might want to add these indices into the list via ```scores_ind = enumerate(scores)``` and sort the list on the second value of each element.

# %%
scores_ind = enumerate(scores)
scores_ind = sorted(scores_ind, key=lambda x: x[1])

n_tweets = 10
for i in range(n_tweets):
    print_tweet(tweets[scores_ind[len(tweets) - i - 1][0]])
print(80 * '-')
for i in range(n_tweets):
    print_tweet(tweets[scores_ind[i][0]])
# Out:
# Sun Sep 23 06:43:25 +0000 2018 Patrick Frickel @HaydenGerson @GuyTesla @elonmusk @Tesla @ElonBachman @ElonsPromises @TeslaCharts @markbspiegel When life is great take advantage. Spoil yourself and get your mind off people like Musk and the rest of his enthusiastic volunteers. They seem to be having fun. You deserve some too.
# --------------------------------------------------------------------------------
# Sun Sep 23 05:02:13 +0000 2018 James Locke This hotel is great, the maintenance gentleman was watching spot for me after I called. We had a good chat. He is impressed with Tesla and says the charger has been working great since installed a couple years ago. Happy to hear Tesla growing &amp; said they should get more chargers
# --------------------------------------------------------------------------------
# Sun Sep 23 05:10:06 +0000 2018 San RT @GuyTesla: I delivered a #Model3 today, helping out @elonmusk and the @Tesla team. So fun to watch new owners delight in everything the…
# --------------------------------------------------------------------------------
# Sun Sep 23 05:13:01 +0000 2018 Fred Roberts RT @GuyTesla: I delivered a #Model3 today, helping out @elonmusk and the @Tesla team. So fun to watch new owners delight in everything the…
# --------------------------------------------------------------------------------
# Sun Sep 23 05:14:15 +0000 2018 Lars Hansen RT @GuyTesla: I delivered a #Model3 today, helping out @elonmusk and the @Tesla team. So fun to watch new owners delight in everything the…
# --------------------------------------------------------------------------------
# Sun Sep 23 05:03:59 +0000 2018 gee iam @GuyTesla @elonmusk @Tesla That is so awesome! I would too if I could. Every little bit helps to make the world a better place...
# --------------------------------------------------------------------------------
# Sun Sep 23 05:32:04 +0000 2018 John Himpe #Beakernight was so much fun tonight. Despite the cold weather, it was a great event!  While everything impressed, it was hard not to pay attention to those Tesla coils! #yyc #stem https://t.co/GDSbcBNsH4
# --------------------------------------------------------------------------------
# Sun Sep 23 06:30:56 +0000 2018 ScottyBadMoon @brawong @elonmusk @Tesla Great idea, or not...lol electric motors like #Tesla rule out big oil pollutants, Gas price gouging.  I like this. Hope we see lots more tesla vehicles on the road sooner then later. have greenhouse concerns?
# Environmental concerns? a tesla would be a most excellent choice.
# --------------------------------------------------------------------------------
# Sun Sep 23 06:42:57 +0000 2018 45SURF @alexkwolfe @markbspiegel @elonmusk Bro thank you thank you for helping Elon save humanity by funding his gas guzzling Gulf Stream bro Tesla 4ever
# --------------------------------------------------------------------------------
# Sun Sep 23 04:48:15 +0000 2018 و RT @_harukimurakami: “That amazing time in our lives is gone, and will never return. All the beautiful possibilities we had then have been…
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Sun Sep 23 06:09:44 +0000 2018 decryption @mattallen @michaelides_j @swan_legend Well it’s pretty obvious this bloke buys in to the Tesla myth. And I’m saying that’s a load of bullshit (I’m still a model 3 reservation holder btw, so I’m not an anti Tesla fucker) and he’s a warped individual for buying into it at that deep level
# --------------------------------------------------------------------------------
# Sun Sep 23 06:43:41 +0000 2018 OingoBoingo @kimpaquette @Tesla @PopMech Hmm, one reason for me not to buy that is the missing knobs. Touchscreens distract from the street. Very poor to handle while driving.
# --------------------------------------------------------------------------------
# Sun Sep 23 06:20:48 +0000 2018 Globe @RTUKnews @RT_com @elonmusk Sad if they do.  I'll never buy a Tesla if that's the case. It's bad enough they got an Israeli company to make that shitty autopilot system they put in Teslas.
# --------------------------------------------------------------------------------
# Sun Sep 23 05:48:34 +0000 2018 🧠 Elon’s Brain 🧠 RT @ICannot_Enough: Remind me who's got a debt problem?  Is it GM or Tesla?  Because this chart I made shows that GM's total debt keeps gro…
# --------------------------------------------------------------------------------
# Sun Sep 23 05:42:21 +0000 2018 Bill Sabo RT @kimpaquette: Anyone who thinks there is no demand for this car is either crazy or obstinate. #tesla #model3 $TSLA https://t.co/2jO6gmnM…
# --------------------------------------------------------------------------------
# Sun Sep 23 05:26:37 +0000 2018 Dan Cogswell @TheAdaptedMind Do you think any of these nitwits have read a balance sheet in their life, let alone Tesla’s? The sum of their knowledge seems to be from the steady stream of twitter bullshit Elon feeds them.
# --------------------------------------------------------------------------------
# Sun Sep 23 06:32:19 +0000 2018 sww1235 RT @RealTimeWWII: Tesla, now 84, is asking for $2,000,000 to build a prototype, but says he'll work alone &amp; will "suffer no interference fr…
# --------------------------------------------------------------------------------
# Sun Sep 23 06:03:55 +0000 2018 Tilman Winkler @MrMarkHandy @markbspiegel @Tesla My guess: they are that clueless, no ill intent behind it.
# --------------------------------------------------------------------------------
# Sun Sep 23 05:21:43 +0000 2018 Gilgamesh RT @ningiou: Tesla: why were you summoned as a humanoid lion
# Edison, hiding a furry commission drawn by DaVinci: are you the fucking cops
# --------------------------------------------------------------------------------
# Sun Sep 23 05:19:22 +0000 2018 Patrick Frickel @RobertDrenk @ravenvanderrave @elonmusk @Tesla Hi please be patient. This is a huge weekend for tesla and things will go back to normal shortly. Meanwhile you have opened the portal shorts hell and let out the hate demons.
# --------------------------------------------------------------------------------

# %% [markdown]
# Do they make any sense?
#
# Automatic sentiment detection is one of the hardest problems in natural language processing (NLP). It's not as simple as a sum of sentiments of separate words since one word can completely change the meaning of a sentence. Also, you can think of such things as subjectivity, tone, context, irony, sarcasm, and many others!

# %% [markdown]
# #### 2.3. Compute Term Frequency

# %% [markdown]
# Computing word frequency is one of the basic routine tasks in NLP. The frequency can be used to do document classification, retrieval, topic modeling. Let's compute frequency of each word in all tweets as ``freq=number_of_word_occurrences/total_number_of_words``.

# %%
def word_frequency(tweets):
    word_freq = {}
    word_count = 0
    for tweet in tweets:
        words = [word.strip(string.punctuation) for word in tweet['full_text'].split()]
        #print words
        for word in words:
            if word not in word_freq: 
                word_freq[word] = 0
            word_freq[word] += 1
            word_count += 1
    for word in word_freq:
        word_freq[word] /= word_count
    return word_freq

word_freq = word_frequency(tweets)

# %% [markdown]
# Now, plot the frequencies of the top 30 most frequent words.
#
# Hints:
# - dictionaries in python have no order, so it doesn't make sense to sort them. Convert the frequency dictionary into a list of tuples first: ```[(word, frequency)]```
# - to show labels on the x-axis of the plot vertically, you can use ```plt.xticks(rotation=90)```

# %%
word_freq_sorted = sorted(word_freq.items(), key=lambda x: x[1], reverse=True)
#print(word_freq_sorted)
n_plot = 30
y = [x[1] for x in word_freq_sorted[:n_plot]]
l = [x[0] for x in word_freq_sorted[:n_plot]]
plt.bar(l, y)
plt.ylabel("frequency")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# As you can see, such non-informative words as "the", "of" or "a" are among the most frequent ones. Removing these words, called "stop words", is one of the first steps in text preprocessing in NLP.

# %% [markdown]
# #### 2.4. Top hashtags

# %% [markdown]
# Let's us compute the most popular hashtags in a similar manner as word frequency. Print the top 10 hashtags and their counts.

# %%
def top_hashtags(tweets):
    hashtags = {}
    for tweet in tweets:
        tweet_hashtags = tweet['entities']['hashtags']
        for hashtag in tweet_hashtags:
            if hashtag['text'] not in hashtags:
                hashtags[hashtag['text']] = 0
            hashtags[hashtag['text']] += 1
    return hashtags

hashtags = top_hashtags(tweets)
hashtags_sorted = sorted(hashtags.items(), key=lambda x: x[1], reverse=True)
pprint(hashtags_sorted[:10])
# Out:
# [('Tesla', 59),
#  ('tesla', 49),
#  ('specad', 40),
#  ('elonmusk', 40),
#  ('spacex', 40),
#  ('Model3', 17),
#  ('IOTA', 12),
#  ('model3', 9),
#  ('CleanTechnica', 8),
#  ('ElectricVehicle', 7)]

# %% [markdown]
# #### 2.5. User location

# %% [markdown]
# Let's try to figure out where our tweets come from. There are several options to do it:
#
# 1. The most precise information is contained in ```tweet['coordinates']```. However, as you'll see, it's rare when users report geolocation directly in their tweets.
# 2. Another option is to use ```tweet['place']```.
# 3. Finally, you can try to use the location of the user: ```tweet['user']['location']```. However, this information can be potentially misleading.
#
# To check the availability of these data fields, we need to calculate the number of tweets where these attributes are non-empty.

# %%
tweets_place, tweets_coord, tweets_user_location = 0, 0, 0
for tweet in tweets:
    if tweet['coordinates']:
        tweets_coord += 1
    if tweet['place']:
        tweets_place += 1
    if tweet['user']['location']:
        tweets_user_location += 1
print("tweets_place", tweets_place)
print("tweets_coord", tweets_coord)
print("tweets_user_location", tweets_user_location)
print("tweets_total", len(tweets))
# Out:
# tweets_place 15
# tweets_coord 0
# tweets_user_location 700
# tweets_total 1000

# %% [markdown]
# Wow, it doesn't look promising :(
#
# Detecting location of the tweets is not so straightforward as ```tweet['coordinates']``` and ```tweet['place']``` are missing for the almost all tweets. Thus, we need to rely on the user location.
#
# Data science requires creativity. Can you think of the other approaches to get the place of a tweet? Discuss it with the other students or teacher.

# %% [markdown]
# As the most tweets come from the U.S.A. (you can check if you want), we can try to identify the state where a tweet comes from. We can get this information from the two attributes:
# 1. ```tweet['place']```
# 2. If the first is not available, then ```tweet['user']['location']```
#
# But let's first inspect the possible values of the two fields to find the best strategy to extract the state. Print these attributes for all tweets.

# %%
for tweet in tweets:
    if tweet['place']:
        print("place:", tweet['place'])
    elif tweet['user']['location']:
        print('location:', tweet['user']['location'])
# Out:
# location: Santa Monica, California
# location: London
# location: Park Forest, IL
# location: San Francisco, CA
# location: Johannesburg South Africa
# location: Nz
# location: usa
# location: Bengaluru, Karnataka
# location: Pune/Nasik
# location: London, England
# location: San Francisco, CA
# location: Frankfurt on the Main, Germany
# location: The Tangle
# location: France
# location: Los Angeles, CA
# location: Nyali, Kenya
# location: England, United Kingdom
# location: Floating in the Space
# location: Thoothukkudi, India
# location: Epsom, Surrey, UK
# location: Hell! Like the Pat Benatar song "Hell is for Children!" I am somebody's child!😎
# location: Uganda
# location: SpaceShip
# location: Calgary, AB
# location: Helena Montana
# location: Santiago Metropolitan Region.
# location: The Netherlands
# location: nah son
# location: Hyderabad
# location: ¯\(º o)/¯
# location: Wooburn, England
# location: nairobi
# location: The land of Freedom & Justice
# location: USA
# location: Alamo City
# location: Lagos, Nigeria.
# location: Sarasota, FL
# location: The land of Freedom & Justice
# location: Miami, FL
# location: Hillcrest, South Africa
# location: Global
# location: Pune/Nasik
# location: Singapore
# location: Santiago Metropolitan Region.
# location: Bedford Stuyvesant, Brooklyn
# location: Sacramento, CA
# location: Moscow
# location: Ukraine
# location: Amritsar, Punjab
# location: Brisbane
# location: 🌴🌊 Mombasa 🌊🌴
# location: Washington State
# location: Kuala Lumpur Malaysia
# location: Luxembourg
# location: ÜT: 35.954483,-83.941574
# location: Coast-Kenya
# location: England, United Kingdom
# location: Woodbridge, VA USA
# location: The land of Freedom & Justice
# location: Germany
# location: Lagos, Nigeria
# location: Geneva, Switzerland
# location: UK
# location: Houston, TX
# location: Egypt
# location: Globetrotting!!
# location: Switzerland
# location: Worldwide
# location: Oakland, CA
# location: Jaipur
# location: NYC, USA
# location: Durban  South Africa
# location: Washington, USA
# location: Hermosillo, Sonora, México
# location: IN FLUFFYS' WORLD
# location: Chico, CA
# location: Grand Canyon State
# location: Where Homeless Vikings Live!
# location: Germany
# location: Saranac Lake
# location: Belgium
# location: Karachi
# location: Perth, Western Australia
# location: Tehran, Iran
# location: AZ//UT
# location: California, USA
# location: The Internetz
# location: The land of Freedom & Justice
# location: uk
# location: Philadelphia pa
# location: France
# location: Philadelphia
# location: Cyperspace
# location: Germany, Wiesbaden
# location: مكة المكرمة, المملكة العربية السعودية
# location: Durban  South Africa
# location: 🇸🇦حفظ الله الوطن 🇦🇪
# location: Sonoran Desert
# location: Malibu, CA
# location: Reading
# location: New York, NY
# location: San Diego, CA
# location: ask why?
# location: Las Vegas, NV
# location: Principado de Asturias, España
# location: United States
# location: Dubai, United Arab Emirates
# location: Lagos, Sanfrancisco, London
# location: Ahmedabad
# location: Clovis, California
# location: La Concha De Tu Madre
# location: Capital, British Columbia
# location: Global
# location: Austin, TX
# location: Malaysia
# location: Karatina, Kenya
# location: Auckland, New Zealand
# location: 广东, 中华人民共和国
# location: Italy
# location: California, USA
# location: Trumbull, CT
# location: Atlanta, GA
# location: לוד
# location: Austin, TX
# location: Baja California, México
# location: Hyderabad, India
# location: some hellhole on mars
# location: Hyderabad
# location: Indianapolis, IN
# location: Santiago Metropolitan Region.
# location: Merced - Michoacan
# location: Bangkok, Thailand
# location: Bogotá D.C.
# location: Washington, DC
# location: jeddah
# location: New Delhi, India
# location: La Concha De Tu Madre
# location: planet zargus
# location: Botswana, Gaborone
# location: Kuala Lumpur
# location: DELFT
# location: Space
# location: Stellenbosch || Maseru
# location: Rome
# location: Hong Kong
# location: Arizona, USA
# location: anywhere you want me 2 be.
# location: Rome
# location: Oulu, Suomi
# location: Birmingham, England
# location: Always on the run....
# location: Bucuresti
# location: Malaysia
# location: London
# location: Houston, TX
# location: PLANET EARTH
# location: Seal Beach, CA
# location: Las Vegas, NV
# location: France
# location: Dhaka, Bangladesh
# location: Phoenix, AZ
# location: The Rockies
# location: Los Angeles, CA
# location: Hamburg, NY
# location: South Africa
# location: Penang,Malaysia
# location: Anchorage, AK
# location: En La Banana Republik
# location: Houston, TX
# location: La Rochelle, France
# location: Athens - Crete - Antwerpen
# location: Norman, OK
# location: United States
# location: Singapore
# location: John McAfee
# location: California, USA
# location: Zanzibar West, Tanzania
# location: Madrid, Spain
# location: West Hollywood, CA
# location: London, England
# location: somewhere in Adventureland
# location: GOOGLE ME MY LOCATION ON!!!!
# location: San Francisco, CA
# location: iPhone: 0.000000,0.000000
# location: 🇩Provinz
# location: Right Ascension 14h 03m 12.6s
# location: Bristol, England
# location: Abuja, Nigeria
# location: Barcelona
# location: Eden Prairie, MN
# location: Green Bay, WI, USA
# location: Nairobi, Kenya
# location: Berlin, Deutschland
# location: Machakos, Kenya
# location: Goiânia, Brazil
# location: Belgium
# location: California, USA
# location: Denver CO
# location: Denver CO
# location: Holographic Universe/Chgo
# location: Gävle, Sverige
# location: Palm Springs, CA
# location: Jakarta
# location: Milky Way
# location: Saguenay, Quebec
# location: New Jersey, USA
# location: Everywhere
# location: Clearwater, British Columbia
# location: IG: @jennytochimani
# location: Germany
# place: {'id': '68e99cfd0ac73fb1', 'url': 'https://api.twitter.com/1.1/geo/id/68e99cfd0ac73fb1.json', 'place_type': 'city', 'name': 'Strawberry', 'full_name': 'Strawberry, CA', 'country_code': 'US', 'country': 'United States', 'contained_within': [], 'bounding_box': {'type': 'Polygon', 'coordinates': [[[-122.523959, 37.877292], [-122.496004, 37.877292], [-122.496004, 37.912506], [-122.523959, 37.912506]]]}, 'attributes': {}}
# location: The land of Freedom & Justice
# location: Wooburn, England
# location: atl
# location: The wonderful land of Oz
# location: Missouri, USA
# location: California, USA
# location: California, USA
# location: Los Angeles, CA
# location: Tokyo
# location: Santa Cruz
# location: Denver, CO
# location: Nairobi
# location: 非中央集権と中央集権の狭間
# location: ÜT: 3.099457,101.681025
# location: Bohuslän
# location: Sangli, India
# location: Florida, USA
# location: LIVE FREE
# location: wester ross
# location: United Kingdom
# location: United States
# location: JORDAN
# location: 川崎市中原区
# location: Bengaluru South, India
# location: London
# location: Honolulu, HI
# location: everywhere
# location: United Kingdom
# location: England, United Kingdom
# location: Greater Seattle, Washington
# location: 广东, 中华人民共和国
# location: Worldwide
# location: iPhone: 52.019607,6.062171
# location: Madrid
# location: Poland
# location: Bangor, ME
# location: United States
# location: Calgary, Canada
# location: Malaysia
# location: A place for crypto codes !!!
# location: RSA
# location: Melbourne, Australia
# location: Utah, USA
# location: Monte Escobedo, Zacatecas
# location: everywhere
# location: Białystok
# location: am Rande des Pott
# location: Marseille, France
# location: Sydney
# location: İstanbul, Türkiye
# location: Noida, India
# location: worldwide
# location: Kuala Lumpur
# location: Suomi
# location: Existential Crisis
# location: Amsterdam
# location: Tulsa, OK
# location: Bengaluru, India
# location: Laguna Beach, CA
# location: worldwide
# location: Boulder CO
# location: New York, USA
# location: Australia
# location: Islamabad
# location: North Carolina, USA
# location: Islamabad
# location: PACA, France
# location: Melbourne, Victoria
# location: Georgia
# location: iPhone: 33.6694600, -117.82311
# location: Lebanon
# location: Bex, Suisse
# place: {'id': 'b49b3053b5c25bf5', 'url': 'https://api.twitter.com/1.1/geo/id/b49b3053b5c25bf5.json', 'place_type': 'city', 'name': 'Denver', 'full_name': 'Denver, CO', 'country_code': 'US', 'country': 'United States', 'contained_within': [], 'bounding_box': {'type': 'Polygon', 'coordinates': [[[-105.109815, 39.614151], [-104.734372, 39.614151], [-104.734372, 39.812975], [-105.109815, 39.812975]]]}, 'attributes': {}}
# location: Caraguatatuba, Brasil
# location: Little Shelford, England
# location: Melbourne, Victoria
# location: Seattle
# location: San Francisco, CA
# location: Santa Cruz, CA
# location: Albuquerque, NM
# location: ÜT: 28.584286,77.260546
# location: İstanbul, Türkiye
# location: Woodside, CA
# location: Texas, USA
# location: Photo: Barry Cornelius
# location: Owensboro, KY
# location: Australia
# location: London
# location: London
# location: Oakland, CA
# location: San Francisco, CA
# location: Brooklyn, NY
# location: Schijndel, Nederland
# location: Melbourne
# location: Peterborough
# location: San Francisco, CA
# place: {'id': '3b77caf94bfc81fe', 'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json', 'place_type': 'city', 'name': 'Los Angeles', 'full_name': 'Los Angeles, CA', 'country_code': 'US', 'country': 'United States', 'contained_within': [], 'bounding_box': {'type': 'Polygon', 'coordinates': [[[-118.668404, 33.704538], [-118.155409, 33.704538], [-118.155409, 34.337041], [-118.668404, 34.337041]]]}, 'attributes': {}}
# location: Scottsdale, AZ
# location: Sou'wezt
# location: Hunna AKr Hood
# location: Oxford
# location: Wolverhampton
# location: Hereford
# location: Kansas City
# location: No, I am not into astrology.
# location: Bangalore
# location: Singapore
# location: Ho Chi Minh City, Vietnam
# location: twitter
# location: New york
# location: Türkiye
# location: Los Angeles
# location: California, USA
# location: Dragonstone
# location: Olomouc
# location: Perpignan, France
# location: Opting out of Twitter Location
# location: Melbourne, Victoria
# location: Oakland, CA
# location: Melbourne, Victoria
# location: Melbourne, Victoria
# location: Calicadia
# location: Portland, Oregon
# location: Europe
# location: Sunnyvale, CA
# location: West Cork, Ireland
# location: Mexico
# location: Switzerland
# location: Republic of the Philippines
# location: SoCal
# location: Belgrade, Republic of Serbia
# location: London
# location: Land Of Moral Hazard, Elbonia
# location: Japonya
# location: Sydney Australia
# location: St. Petersburg, Missouri
# location: Melbourne, Australia
# location: (Brick Bity) Bandit Newark N.j
# location: Nice, France
# location: Nice, France
# location: Ras Al Khor UAE
# location: United States
# location: Orlando, Florida
# location: New York City / Florida
# location: London, England
# location: New York and the World
# location: Greece, UK
# location: India
# location: Seattle
# location: Japonya
# location: San Diego, CA
# location: Capital, British Columbia
# location: San Francisco, CA
# location: Seattle, wa
# location: Victoria, British Columbia
# location: South East Houston
# location: San Diego, CA
# location: Freiburg
# location: United States
# location: shanghai
# location: Hong Kong
# location: brazil
# location: France
# location: Nairobi || Kenya ya bish
# location: Central Bohemia,
# location: London & Glasgow
# location: Angleterre, Royaume-Uni
# place: {'id': '317fcc4b21a604d5', 'url': 'https://api.twitter.com/1.1/geo/id/317fcc4b21a604d5.json', 'place_type': 'city', 'name': 'New Delhi', 'full_name': 'New Delhi, India', 'country_code': 'IN', 'country': 'India', 'contained_within': [], 'bounding_box': {'type': 'Polygon', 'coordinates': [[[76.84252, 28.397657], [77.347652, 28.397657], [77.347652, 28.879322], [76.84252, 28.879322]]]}, 'attributes': {}}
# location: Portland, OR
# location: England, United Kingdom
# location: Washington, USA
# location: Хогвартс
# location: United Arab Emirates
# location: Reading
# location: Winters, CA
# location: Dragonstone
# location: Curaçao
# location: Los Gatos, CA
# location: Oakland, CA
# location: Houston, TX
# location: Washington, USA
# location: Spain
# location: Zambia
# location: ..
# location: Manchester, England
# location: Surrey, British Columbia
# location: United States
# location: Switzerland
# location: Chiraq✈️DubVeeCee
# location: Littoral, Cameroon
# location: Amsterdam, Istanbul, Tarifa
# location: Australia
# location: Incline Village, NV
# location: Germany
# location: Calgary, Alberta
# location: India
# location: United States
# location: Oslo, Norway
# location: United States
# location: Vancouver, BC
# location: konoha
# location: Victoria, British Columbia
# location: strasbourg
# location: Trumbull, CT
# location: Culiacán, Sinaloa
# location: Hovedstaden, Danmark
# location: United States
# location: Hovedstaden, Danmark
# location: San Francisco, CA
# location: Elon Musk, Earth 🌎
# location: London, England
# location: Medellín, Colombia
# place: {'id': '09f6a7707f18e0b1', 'url': 'https://api.twitter.com/1.1/geo/id/09f6a7707f18e0b1.json', 'place_type': 'city', 'name': 'Paris', 'full_name': 'Paris, France', 'country_code': 'FR', 'country': 'France', 'contained_within': [], 'bounding_box': {'type': 'Polygon', 'coordinates': [[[2.2241006, 48.8155214], [2.4699053, 48.8155214], [2.4699053, 48.9021461], [2.2241006, 48.9021461]]]}, 'attributes': {}}
# location: Stockholm, Sverige
# location: Germany
# location: Copenhagen, Denmark
# location: Utrecht
# location: Calgary, Canada
# location: sydney
# location: Singapore
# location: Brooklyn, NY
# location: Your brain
# place: {'id': 'a6c30cefdd39bd81', 'url': 'https://api.twitter.com/1.1/geo/id/a6c30cefdd39bd81.json', 'place_type': 'city', 'name': 'Ceres', 'full_name': 'Ceres, CA', 'country_code': 'US', 'country': 'United States', 'contained_within': [], 'bounding_box': {'type': 'Polygon', 'coordinates': [[[-120.993774, 37.561491], [-120.920472, 37.561491], [-120.920472, 37.620692], [-120.993774, 37.620692]]]}, 'attributes': {}}
# location: UK
# location: Germany
# location: Alameda, California
# location: Edgebrook
# location: Germany
# location: Mumbai, Maharashtra, India
# location: sydney
# location: Indonesia
# location: Kota Bandung, Jawa Barat
# location: Arizona
# location: Pale Blue Dot
# location: Toronto, Ontario
# location: Los Angeles
# location: United States
# location: In a fresh jar of SKIPPY
# location: Bloomington, Ind.
# location: NYC
# location: Sevilla, Spain
# location: Coimbatore
# location: Pale Blue Dot
# location: Tokyo, Japan
# location: New York, NY
# location: United States
# location: Autobot city Iacon, Cybertron
# location: Hlavní město Praha, Česká republika
# location: NoWhere
# location: München
# location: Seattle, Washington
# location: Lahore     (Santiago Berńăbĕū)
# location: Pefki, Attica, Greece
# location: HQ - Tucson, Arizona, USA
# location: Santa Monica, California
# location: Sandnes, Norway
# location: ÜT: 33.044534,-117.284245
# location: Rheinland-Pfalz, Deutschland
# location: Pale Blue Dot
# location: Selangor, Malaysia
# location: San Francisco, CA
# location: outerspace
# location: houston
# location: Berlin, Deutschland
# location: Dragonstone
# location: Bengaluru, Karnataka
# location: Dehradun, India
# location: United States
# location: Queens, NY
# location: Orbiting Sagittarius A*
# location: El Cerrito, CA
# location: Pale Blue Dot
# place: {'id': '53504716d445dcad', 'url': 'https://api.twitter.com/1.1/geo/id/53504716d445dcad.json', 'place_type': 'city', 'name': 'Calgary', 'full_name': 'Calgary, Alberta', 'country_code': 'CA', 'country': 'Canada', 'contained_within': [], 'bounding_box': {'type': 'Polygon', 'coordinates': [[[-114.3160379, 50.84278], [-113.859664, 50.84278], [-113.859664, 51.212548], [-114.3160379, 51.212548]]]}, 'attributes': {}}
# location: Durban  South Africa
# location: Orbiting Sagittarius A*
# location: Pale Blue Dot
# location: Orbiting Sagittarius A*
# location: Houston, TX
# location: Emerald Lake Hills, CA
# location: OccupyMars
# location: Pale Blue Dot
# location: SoCal
# location: Emerald Lake Hills, CA
# location: Syria
# location: United States of Smash
# location: Madrid, Spain
# location: West Coast, USA
# location: Huntington Beach, CA
# location: Emerald Lake Hills, CA
# location: Texcoco
# location: OccupyMars
# location: Selangor
# location: Irving, TX
# location: CA
# location: Stuttgart, Deutschland
# location: California, USA
# location: Brighton, Victoria, Australia
# location: A pale blue dot
# location: Ho Chi Minh City, Vietnam
# location: Los Angeles, CA
# location: West Africa
# location: World Behind My Wall
# location: Everywhere
# location: Dragonstone
# location: Perth, WA
# location: South Padre Island, TX
# location: Pale Blue Dot
# location: Calgary, Alberta
# location: Phoenix, AZ
# location: Earth, Sol
# location: Calgary, Alberta
# location: Lagos/Ibadan Nigeria
# location: United States
# location: Dragonstone
# location: Lagos/Ibadan Nigeria
# location: Everywhere
# location: Super Secret Snowy Mountain HQ
# location: paradise
# location: Pale Blue Dot
# location: United Kingdom
# location: Las Vegas
# location: magaville , America
# location: Henderson, NV
# location: NM|TX
# location: United Kingdom
# location: Carlisle, MA 01741
# location: Texas, USA
# location: Jersey Pine Barrens
# location: Fortress of Solitude
# location: Las Vegas
# location: Brisbane, Queensland
# location: Arizona
# place: {'id': '535f0c2de0121451', 'url': 'https://api.twitter.com/1.1/geo/id/535f0c2de0121451.json', 'place_type': 'city', 'name': 'Warsaw', 'full_name': 'Warsaw, Poland', 'country_code': 'PL', 'country': 'Poland', 'contained_within': [], 'bounding_box': {'type': 'Polygon', 'coordinates': [[[20.8525518, 52.0977088], [21.2710282, 52.0977088], [21.2710282, 52.3679617], [20.8525518, 52.3679617]]]}, 'attributes': {}}
# location: New York, NY
# location: Nairobi, Kenya
# location: Texas, the Free State
# place: {'id': '02215ae29a77567c', 'url': 'https://api.twitter.com/1.1/geo/id/02215ae29a77567c.json', 'place_type': 'city', 'name': 'Tustin', 'full_name': 'Tustin, CA', 'country_code': 'US', 'country': 'United States', 'contained_within': [], 'bounding_box': {'type': 'Polygon', 'coordinates': [[[-117.845301, 33.6941797], [-117.758969, 33.6941797], [-117.758969, 33.773387], [-117.845301, 33.773387]]]}, 'attributes': {}}
# location: Sarasota, FL
# location: San Francisco, CA
# location: Fortress of Solitude
# location: Durban  South Africa
# location: Woodside, CA
# location: Hampshire, UK
# location: Sarasota, FL
# location: Baton Rouge, LA
# location: Piraeus Hellas (Greece)
# location: Sarasota, FL
# location: Naumburg (Saale), Deutschland
# location: sweet home Alabama
# location: Earth, Sol
# location: United States
# location: Seattle
# location: Florida, USA
# location: Colorado
# location: Oak Park, IL
# location: Seattle
# location: Украина
# location: Bourgogne, France
# location: Vancouver, WA
# location: Clearwater, British Columbia
# location: Lapovo, Srbija
# location: 49.224764,-123.108159
# location: Hillsboro, OR
# location: Hanumangarh Rajasthan
# location: Californian Beach & Vienna
# location: Malibu, CA
# location: planet earth
# location: Serra - ES, Brasil
# location: United States
# location: California, USA
# location: Hollywood
# location: Californian Beach & Vienna
# location: Moore Haven, Florida, USA
# location: Dallas, TX
# location: United States
# location: ÜT: 38.675682,-77.278456
# location: 3rd Rock
# location: Chicago
# location: Gregg’s place
# location: Tlajomulco de Zúñiga, Jalisco
# location: Mumbai, India
# location: Everywhere
# location: Chicago
# location: Virginia (757 Area)
# location: South Florida
# location: Elon Musk, Earth 🌎
# location: NJ, USA
# location: Melbourne, Australia
# location: Sarasota, FL
# location: United States
# location: Новосибирская область, Россия
# location: Where Homeless Vikings Live!
# location: Perthshire, Scotland
# location: Flying around USA
# location: Durban  South Africa
# location: United States
# location: Manchester, England
# place: {'id': '535f0c2de0121451', 'url': 'https://api.twitter.com/1.1/geo/id/535f0c2de0121451.json', 'place_type': 'city', 'name': 'Warsaw', 'full_name': 'Warsaw, Poland', 'country_code': 'PL', 'country': 'Poland', 'contained_within': [], 'bounding_box': {'type': 'Polygon', 'coordinates': [[[20.8525518, 52.0977088], [21.2710282, 52.0977088], [21.2710282, 52.3679617], [20.8525518, 52.3679617]]]}, 'attributes': {}}
# location: Earth
# location: Nanaimo, British Columbia
# location: Flying around USA
# location: Latin America
# location: Charlottetown, Prince Edward Island
# place: {'id': '535f0c2de0121451', 'url': 'https://api.twitter.com/1.1/geo/id/535f0c2de0121451.json', 'place_type': 'city', 'name': 'Warsaw', 'full_name': 'Warsaw, Poland', 'country_code': 'PL', 'country': 'Poland', 'contained_within': [], 'bounding_box': {'type': 'Polygon', 'coordinates': [[[20.8525518, 52.0977088], [21.2710282, 52.0977088], [21.2710282, 52.3679617], [20.8525518, 52.3679617]]]}, 'attributes': {}}
# location: Post Falls, ID
# location: London, England
# location: Алматы
# location: Everywhere
# location: andy summer gracie
# place: {'id': '535f0c2de0121451', 'url': 'https://api.twitter.com/1.1/geo/id/535f0c2de0121451.json', 'place_type': 'city', 'name': 'Warsaw', 'full_name': 'Warsaw, Poland', 'country_code': 'PL', 'country': 'Poland', 'contained_within': [], 'bounding_box': {'type': 'Polygon', 'coordinates': [[[20.8525518, 52.0977088], [21.2710282, 52.0977088], [21.2710282, 52.3679617], [20.8525518, 52.3679617]]]}, 'attributes': {}}
# location: Houston, TX
# location: Kiev
# location: Elmwood Park, IL
# location: Wall St
# location: London, England
# location: Canada
# location: Global
# location: Pennsylvania, USA
# location: United States
# location: Oregon, USA
# location: Freiburg im Breisgau | Germany
# location: The Great Wide Open
# location: Pakistan
# location: Buffalo, NY
# location: Minnesota, USA
# location: Tokyo, Japan
# location: UK
# location: Planet Earth
# location: andy summer gracie
# location: Republic of Mauritius
# location: London, UK
# location: Houston, TX
# place: {'id': '045badf8fedd9c63', 'url': 'https://api.twitter.com/1.1/geo/id/045badf8fedd9c63.json', 'place_type': 'city', 'name': 'North Miami Beach', 'full_name': 'North Miami Beach, FL', 'country_code': 'US', 'country': 'United States', 'contained_within': [], 'bounding_box': {'type': 'Polygon', 'coordinates': [[[-80.2089316, 25.9141456], [-80.130673, 25.9141456], [-80.130673, 25.9571365], [-80.2089316, 25.9571365]]]}, 'attributes': {}}
# location: This crazy world.
# location: Vancouver Island, BC
# location: Bogotá, D.C., Colombia
# location: Sunnyvale, CA
# location: Earth and one day Mars
# location: Bergen, Norway
# location: United States
# location: Philippines
# location: Chicago, IL
# location: Australia
# location: Elmwood Park, IL
# location: In The 402
# location: United States
# location: USA
# location: Mies, Vaud
# location: Rio de Janeiro, Brasil
# location: South Africa
# location: chiilin chillin why wassup
# location: United States
# location: Durban, South Africa
# location: San Francisco, CA
# location: Colorado, USA
# location: Californian Beach & Vienna
# location: California, USA
# location: West Coast area, USA
# location: Omaha, NE
# location: California, USA
# location: Jerusalem, Israel
# location: Edmonton
# location: Inglewood-Finn Hill, WA
# location: Panwari ki dukaan
# location: NC
# location: Property on Mars & the moon
# place: {'id': '203838c6eac8a66a', 'url': 'https://api.twitter.com/1.1/geo/id/203838c6eac8a66a.json', 'place_type': 'city', 'name': 'Lone Tree', 'full_name': 'Lone Tree, CO', 'country_code': 'US', 'country': 'United States', 'contained_within': [], 'bounding_box': {'type': 'Polygon', 'coordinates': [[[-104.906552, 39.506906], [-104.8667509, 39.506906], [-104.8667509, 39.566504], [-104.906552, 39.566504]]]}, 'attributes': {}}
# location: Pocatello, ID
# location: San Francisco, CA
# location: Property on Mars & the moon
# location: Californian Beach & Vienna
# location: Portland, Oregon, USA
# location: Californian Beach & Vienna
# location: Kelowna BC
# location: Missouri, USA
# location: Vancouver, British Columbia
# location: San Francisco, CA
# location: Portland, OR
# location: Silicon Valley
# location: CAMBRIDGE, MA
# location: Porto Alegre, Brasil
# location: Foster City, CA
# location: Pleasant Hell, CA, USA
# location: Peterborough, Ontario CANADA
# location: Mongolia
# location: Surat
# location: Dindigul ,Tamil Nadu
# location: In your moms bed
# place: {'id': '003f4a527524b7ee', 'url': 'https://api.twitter.com/1.1/geo/id/003f4a527524b7ee.json', 'place_type': 'admin', 'name': 'Arusha', 'full_name': 'Arusha, Tanzania', 'country_code': 'TZ', 'country': 'Tanzania', 'contained_within': [], 'bounding_box': {'type': 'Polygon', 'coordinates': [[[34.7514439, -3.9477361], [37.3130197, -3.9477361], [37.3130197, -1.7015456], [34.7514439, -1.7015456]]]}, 'attributes': {}}
# location: San Francisco, CA
# location: Selangor

# %% [markdown]
# It seems that these two fields contain information in a natural language form. Both ```tweet['place']['full_name']``` and ```tweet['user']['location']``` can contain city, full name of a state or its code. To extract the state from a string, we'll use regular expressions.
#
# Regular expression is a powerful tool used in almost all programming languages to extract information from string data. Although it has its own sophisticated markup language, we're not going to use it here. You can search for a substring ```query``` in a string using the following code:
# ```
# import re
# searchObj = re.search(query, string)
# if searchObj:
#     # there is a match
# else:
#     # nothing was found
# ```
# For example, the following code will find matches of the string 'NY' in the string 'Brookville, NY' ignoring the case of the letters:
# ```
# searchObj = re.search('NY', 'Brookville, NY', re.IGNORECASE)
# if searchObj:
#     #this code will be executed as there is a match
# ```
#
# Hints:
# - don't forget to check ```tweet['place']['country_code']``` as well
# - search for the full name of a state first and then, if nothing was found, search for a state abbreviation
# - the dictionary below will help you

# %%
states_dict = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AS': 'American Samoa',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'GU': 'Guam',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MP': 'Northern Mariana Islands',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NA': 'National',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'PR': 'Puerto Rico',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VI': 'Virgin Islands',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
}

# %%
import re


def get_state_from_str(text, states_dict):
    state = None
    for k, v in states_dict.items():
        searchObj = re.search(v, text, re.IGNORECASE)
        if searchObj: 
            state = k
        else:
            searchObj = re.search(k, text)
            if searchObj: 
                state = k
    return state


states = []
for tweet in tweets:
    state = None
    if tweet['place'] and tweet['place']['country_code'] == 'US':
        state = get_state_from_str(tweet['place']['full_name'], states_dict)
    if state is None and tweet['user']['location']:
        state = get_state_from_str(tweet['user']['location'], states_dict)
    states.append(state)

print(states)
# Out:
# [None, None, None, None, None, 'CA', None, None, 'IL', None, 'CA', None, None, None, None, None, None, None, 'CA', None, None, None, 'CA', None, None, None, None, None, None, None, None, None, None, None, 'MT', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'FL', None, 'FL', None, None, None, None, None, None, None, None, None, None, None, 'CA', None, None, None, None, None, None, None, None, None, 'WA', None, None, None, None, None, None, None, None, None, 'VA', None, None, None, None, None, None, 'TX', None, None, None, None, None, None, None, 'CA', None, 'NY', None, None, 'WA', None, None, 'OR', 'CA', None, None, None, None, None, None, None, None, None, None, 'UT', 'CA', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'CA', None, 'NY', None, 'CA', None, None, 'NV', None, None, None, None, None, 'CA', None, None, None, 'TX', None, None, None, None, None, None, None, 'CA', None, None, None, 'CT', 'GA', None, None, None, None, 'TX', 'CA', None, None, None, None, 'IN', None, None, None, None, None, None, 'WA', None, None, None, None, None, None, None, None, None, None, None, 'DE', None, None, None, None, None, 'AZ', None, None, None, None, None, None, None, None, None, None, None, 'TX', 'NE', 'CA', None, 'NV', None, None, None, None, 'AZ', None, None, 'CA', None, None, 'NY', None, None, None, None, None, 'AK', None, 'TX', None, None, None, 'OK', None, None, None, None, 'CA', None, None, None, 'CA', None, None, 'ME', 'CA', None, None, None, None, None, None, None, None, None, 'MN', None, 'WI', None, None, None, None, None, 'CA', 'CO', None, 'CO', None, None, None, None, 'CA', None, None, None, None, None, 'NJ', None, None, None, None, None, None, None, None, 'CA', None, None, None, None, None, None, 'MO', 'CA', 'CA', None, 'CA', None, None, None, None, None, 'CO', None, None, None, None, None, None, None, 'FL', None, None, None, None, None, 'OR', None, None, None, 'HI', None, None, None, 'WA', None, None, None, None, None, None, None, 'ME', None, None, None, None, None, None, None, None, None, 'UT', None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'OK', None, 'CA', None, None, 'CO', 'NY', None, None, 'NC', None, 'PA', None, None, None, None, 'GA', None, None, None, None, None, 'CO', None, None, None, None, None, None, None, 'CA', None, 'CA', None, None, None, None, None, 'NM', None, None, None, None, 'CA', None, None, 'TX', None, None, None, None, 'KY', None, None, None, None, None, None, None, 'CA', 'CA', 'NY', None, None, None, 'CA', 'CA', 'AZ', None, 'AK', None, None, None, None, None, 'KS', None, None, None, None, None, None, None, None, 'NY', None, None, None, None, None, 'CA', None, None, None, None, None, None, None, 'CA', None, None, None, None, 'OR', None, 'CA', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'MO', None, None, None, None, None, None, None, None, 'FL', 'NY', None, None, 'NY', None, None, None, None, None, None, 'CA', None, None, 'CA', None, None, None, None, 'CA', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'OR', None, 'WA', None, None, None, None, 'CA', None, None, None, 'CA', 'CA', None, 'TX', 'WA', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'NV', None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'CT', None, None, None, None, None, None, 'CA', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'NY', None, 'CA', None, None, 'CA', None, None, None, None, None, None, None, None, None, 'AZ', None, None, None, None, None, None, None, None, None, None, None, None, None, 'NY', None, None, None, None, None, 'NY', None, None, None, None, None, Non ...

# %% [markdown]
# Now, let's iterate through the tweets again to find a mean value of sentiment scores for each state.
#
# Hint: don't compute scores again as you already have done it in the previous exercise.

# %%
scores_by_state = {}
for score_i, score in enumerate(scores):
    state = states[score_i]
    if state is not None:
        if state not in scores_by_state:
            scores_by_state[state] = []
        scores_by_state[state].append(score)

state_score_mean = {}
for k in scores_by_state:
    state_score_mean[k] = np.mean(scores_by_state[k])

# %% [markdown]
# Finally, let's print the sorted list of the mean sentiment scores for each state. In this case, it can help to get some knowledge about the states where people are positive or negative about Tesla. This can provide valuable insights for the marketing department!

# %%
state_score_mean_sorted = sorted(state_score_mean.items(), key=lambda x: x[1], 
                                 reverse=True)
for state, score in state_score_mean_sorted:
    print(states_dict[state], score)
# Out:
# Indiana 3.0
# Hawaii 3.0
# Rhode Island 3.0
# Oklahoma 2.5
# Massachusetts 2.0
# National 2.0
# Illinois 1.8
# Missouri 1.6666666666666667
# Arizona 1.5714285714285714
# Florida 1.4166666666666667
# Oregon 1.375
# Washington 1.2
# Virginia 1.0
# Connecticut 1.0
# New Jersey 1.0
# California 0.9090909090909091
# Utah 0.5
# New York 0.35714285714285715
# Nevada 0.25
# Montana 0.0
# Nebraska 0.0
# Maine 0.0
# New Mexico 0.0
# Kentucky 0.0
# Kansas 0.0
# Alabama 0.0
# Idaho 0.0
# Georgia -0.5
# Minnesota -0.5
# North Carolina -0.5
# Texas -0.75
# Wisconsin -1.0
# Pennsylvania -1.0
# Colorado -1.375
# Delaware -2.0
# Alaska -2.0
# Louisiana -4.0
